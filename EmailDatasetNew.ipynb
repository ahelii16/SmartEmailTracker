# %%
import pandas as pd
import numpy as np

# %%
From1=['@JPMorgan.com','@DEUTSCHEBANK.com','@BNYMellon.com','@HSBC.com','@CitiBankNewYork.com','@CitiBankLondon.com']

To2=['@CitiBankNewYork.com','@CitiBankLondon.com','@CitiBankPune.com','@CitiBankSingapore.com','@CitiBankHingKong.com']

Subject2=['Update on payment request', 'Payment Status', 'Urrgent: need transaction details','Transaction Complete','Transaction is in progress','Payment Failed','Payment is in progress','Waiting for amount pending','Transaction Failed','Payment Received']

name1=['Phillip','Mike','Jason','Adam','Morgan','Spike','Stacy']
name2=['Shai','Dipesh','Anthony','Isabella']
currency = ['USD','GBP','CAD','EUR']

# %%
data1=[[]]

# %%
import random
from random import randint

# %%
transacC=['The transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' related to investment funds has been successfully completed.',
'The transaction ' +''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' have been received.',
'Full payment for update ' +''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' is successfully received.']

transacP=['The transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' is taking too long to be completed',
'Fund transfer for ACC No. ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has partially stopped due to unknown technical error. We regret the inconvenience.',
'Due to server overflow transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' will be completed within seven to ten working days',
'Payment ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' will be completed within two days']

transacF=['Due to an unknown technical error, your transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' have been cancelled.',
'Payment ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' have been cancelled as per your request.',
'Lack of funds, check no. ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 24)]) + ' has been bounced.']

transacR=[
    'Kindly provide the details for Acc no.'+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ ' at the earliest',
    'Please find the details of your account '+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ ' attached',
    'We have received your request and will be sending you the details of acc '+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ 'soon.'
]

# %%
for i in range(len(From1)):
            for j in range(len(To2)):
                for k in range(len(Subject2)):
                    s1=random.choice(name1)+random.choice(From1)
                    s2=random.choice(name2)+random.choice(To2)
                    s3=random.choice(Subject2)
                    s4=""
                    s5=""
                    words = s3.split()
                    if(words[-1]=='Failed'):
                        s4=transac(3,temp)
                        s5='A'
                    elif(words[-1]=='pending' or words[-1]=='progress' or words[-1]=='Update' or words[-1]==temp):
                        s4=transac(2,temp)
                        s5='B'
                    elif(words[-1]=='Complete' or words[-1]=='Received'):
                        s4=transac(1,temp)
                        s5='C'
                    elif(words[-1]=='Status' or words[-1]=='request' or words[-1]=='details'):
                        s4=transac(4,temp)
                        s5='D'
                    m=[s1,s2,s3,s4,s5]
                    data1.append(m)

# %%
df1 = pd.DataFrame(data1, columns = ['From', 'To','Subject','Body','Class(output)'])

# %%
df1.head(100)
# Out:
#                            From                              To  \
# 0                          None                            None
# 87    Stacy@CitiBankNewYork.com       Isabella@CitiBankPune.com
# 88        Phillip@BNYMellon.com  Isabella@CitiBankSingapore.com
# 89      Mike@CitiBankLondon.com  Isabella@CitiBankSingapore.com
# 90                Mike@HSBC.com     Anthony@CitiBankNewYork.com
# 91     Spike@CitiBankLondon.com  Isabella@CitiBankSingapore.com
# 92     Stacy@CitiBankLondon.com    Isabella@CitiBankNewYork.com
# 93              Morgan@HSBC.com        Shai@CitiBankNewYork.com
# 94          Morgan@JPMorgan.com      Shai@CitiBankSingapore.com
# 95    Jason@CitiBankNewYork.com   Isabella@CitiBankHingKong.com
# 96             Phillip@HSBC.com    Dipesh@CitiBankSingapore.com
# 97  Phillip@CitiBankNewYork.com   Isabella@CitiBankHingKong.com
# 98                Mike@HSBC.com        Anthony@CitiBankPune.com
# 99       Jason@DEUTSCHEBANK.com     Anthony@CitiBankNewYork.com
#
#                               Subject  \
# 0                                None
# 1                      Payment Status
# 2   Urrgent: need transaction details
# 3                      Payment Failed
# 4                      Payment Failed
# 5          Waiting for amount pending
# 6                  Transaction Failed
# 7          Waiting for amount pending
# 8                      Payment Status
# 9              Payment is in progress
# 10          Update on payment request
# 11                     Payment Failed
# 12             Payment is in progress
# 13               Transaction Complete
# 14                     Payment Status
# 15         Transaction is in progress
# 16                   Payment Received
# 17         Waiting for amount pending
# 18               Transaction Complete
# 19                     Payment Status
# 20             Payment is in progress
# 21                   Payment Received
# 22                 Transaction Failed
# 23                 Transaction Failed
# 24          Update on payment request
# 25                     Payment Failed
# 26  Urrgent: need transaction details
# 27                   Payment Received
# 28                     Payment Failed
# 29                     Payment Failed
# ..                                ...
# 70  Urrgent: need transaction details
# 71                   Payment Received
# 72                   Payment Received
# 73          Update on payment request
# 74               Transaction Complete
# 75                 Transaction Failed
# 76          Update on payment request
# 77               Transaction Complete
# 78                     Payment Failed
# 79             Payment is in progress
# 80         Transaction is in progress
# 81                     Payment Status
# 82         Transaction is in progress
# 83         Transaction is in progress
# 84               Transaction Complete
# 85                   Payment Received
# 86             Payment is in progress
# 87         Waiting for amount pending
# 88  Urrgent: need transaction details
# 89         Transaction is in progress
# 90  Urrgent: need transaction details
# 91  Urrgent: need transaction details
# 92         Waiting for amount pending
# 93  Urrgent: need transaction details
# 94  Urrgent: need transaction details
# 95                     Payment Failed
# 96                     Payment Status
# 97               Transaction Complete
# 98                     Payment Status
# 99  Urrgent: need transaction details
#
#                                                  Body Class(output)
# 0                                                None          None
# 1   Please find the details of your account 412762...             D
# 2   We have received your request and will be send...             D
# 3   Due to lack of funds, cheque no. 2243942453635...             A
# 4   Payment of GBP879372 has been cancelled as per...             A
# 5    Payment 251637 will be completed within two days             B
# 6   Due to unknown technical errors, your transact...             A
# 7   Due to server overflow transaction 746546 will...             B
# 8   Please find the details of your account 651369...             D
# 9   Due to server overflow transaction 675182 will...             B
# 10  Please find the details of your account 843581...             D
# 11  Due to unknown technical errors, your transact...             A
# 12  The transaction 276628 is taking too long to b...             B
# 13  The transaction of amount EUR251481 has been r...             C
# 14  We have received your request and will be send...             D
# 15   Payment 141124 will be completed within two days             B
# 16  Full payment for amount EUR591854 has been suc...             C
# 17  The transaction 253914 is taking too long to b...             B
# 18  The transaction of amount USD749533 has been r...             C
# 19  We have received your request and will be send...             D
# 20  Fund transfer for ACC No. 443154 has partially...             B
# 21  Full payment for amount CAD518193 has been suc...             C
# 22  Payment of GBP542474 has been cancelled as per...             A
# 23  Due to lack of funds, cheque no. 2864358123624...             A
# 24  Please find the details of your account 949457...             D
# 25  Due to unknown technical errors, your transact...             A
# 26  Kindly provide the details for Acc no.384285 a...             D
# 27  The transaction for amount EUR444137 related t...             C
# 28  Payment of GBP321243 has been cancelled as per...             A
# 29  Due to lack of funds, cheque no. 9758339256268...             A
# ..                                                ...           ...
# 70  We have received your request and will be send...             D
# 71  The transaction for amount GBP589995 related t...             C
# 72  The transaction for amount USD873222 related t...             C
# 73  Please find the details of your account 895576...             D
# 74  The transaction of amount GBP932653 has been r...             C
# 75  Due to lack of funds, cheque no. 3298349835322...             A
# 76  Please find the details of your account 397333...             D
# 77  The transaction of amount EUR396865 has been r...             C
# 78  Due to unknown technical errors, your transact...             A
# 79  Fund transfer for ACC No. 672537 has partially...             B
# 80  Fund transfer for ACC No. 481541 has partially...             B
# 81  Kindly provide the details for Acc no.295835 a...             D
# 82  Due to server overflow transaction 785792 will...             B
# 83   Payment 689648 will be completed within two days             B
# 84  The transaction for amount USD492842 related t...             C
# 85  Full payment for amount USD775221 has been suc...             C
# 86   Payment 397435 will be completed within two days             B
# 87  Fund transfer for ACC No. 198357 has partially...             B
# 88  Please find the details of your account 265513...             D
# 89  Due to server overflow transaction 891917 will...             B
# 90  Kindly provide the details for Acc no.835214 a...             D
# 91  We have received your request and will be send...             D
# 92  The transaction 568722 is taking too long to b...             B
# 93  Kindly provide the details for Acc no.826424 a...             D
# 94  We have received your request and will be send...             D
# 95  Due to unknown technical errors, your transact...             A
# 96  Please find the details of your account 856676...             D
# 97  Full payment for amount USD713522 has been suc...             C
# 98  We have received your request and will be send...             D
# 99  Kindly provide the details for Acc no.322352 a...             D
#
# [100 rows x 5 columns]

# %%
#Whenever you need to join a digit put->  ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ ' sdjvbksd')  part in there

# %%
#BELOW IS THE CODE FOR A NUMBER IN SUBJECT AND BODY

# %%
def numbergen(n):
    return ''.join(["{}".format(randint(1, 9)) for num in range(0, n)])

# %%
def sub(s):
    subject=[' Acc ' + s + ' Update','Payment in Progress Acc ' + s,'Update on Acc '+ s,'Update on payment request for' + s ,'Payment Status for ' + s,'Urgent : need transaction details for ' + s,'Transaction Complete for ' + s,'Transaction is in progress for ' + s,'Payment Failed for ' + s,'Payment is in progress for ' + s,'Waiting for amount pending for '+ s,'Transaction Failed for' + s,'Payment Received for' + s]
    return random.choice(subject)

# %%
def transac(n,s):
    
    transacC=['The transaction for amount ' + random.choice(currency)+ ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' related to investment funds has been successfully completed.',
    'The transaction of amount ' +random.choice(currency)+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has been received successfully.',
    'Full payment for amount ' +random.choice(currency)+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has been successfully received.']

    transacP=['The transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' is taking too long to be completed',
    'Fund transfer for ACC No. ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has partially stopped due to unknown technical error. We regret the inconvenience.',
    'Due to server overflow transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' will be completed within seven to ten working days',
    'Payment ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' will be completed within two days']

    transacF=['Due to unknown technical errors, your transaction for amount' + random.choice(currency)+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has been cancelled.',
    'Payment of ' + random.choice(currency)+ ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has been cancelled as per your request.',
    'Due to lack of funds, cheque no. ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 24)]) + ' has bounced. Kindly ensure that you have enough funds and then submit a new cheque at the earliest.']

    transacR=['Kindly provide the details for Acc no.'+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ ' at the earliest',
    'Please find the details of your account '+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ ' attached',
    'We have received your request and will be sending you the details of acc '+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ 'soon.']
    if(n==1):
        return random.choice(transacC)
    elif n==2:
        return random.choice(transacP)
    elif n==3:
        return random.choice(transacF)
    elif n==4:
        return random.choice(transacR)

# %%
data2=[[]]

# %%
for i in range(len(From1)):
            for j in range(len(To2)):
                for k in range(len(Subject2)):
                    temp=''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])
                    s1=random.choice(name1)+random.choice(From1)
                    s2=random.choice(name2)+random.choice(To2)
                    s3=sub(temp)
                    s4=""
                    s5=""
                    words = s3.split()
                    for word in words:
                        if(word=='Failed'):
                            s4=transac(3,temp)
                            s5='A'
                        elif(word=='pending' or word=='progress' or word=='Update'):
                            s4=transac(2,temp)
                            s5='B'
                        elif(word=='Complete' or word=='Received'):
                            s4=transac(1,temp)
                            s5='C'
                        elif(word=='Status' or word=='request' or word=='details'):
                            s4=transac(4,temp)
                            s5='D'
                    m=[s1,s2,s3,s4,s5]
                    data2.append(m)

# %%
df = pd.DataFrame(data2, columns = ['From', 'To','Subject','Body','Class(output)'])

# %%
df.head(20)
# Out:
#                           From                              To  \
# 0                         None                            None
# 1    Jason@CitiBankNewYork.com   Isabella@CitiBankHingKong.com
# 2         Phillip@JPMorgan.com       Isabella@CitiBankPune.com
# 3      Morgan@DEUTSCHEBANK.com    Dipesh@CitiBankSingapore.com
# 4          Morgan@JPMorgan.com       Isabella@CitiBankPune.com
# 5          Jason@BNYMellon.com       Shai@CitiBankHingKong.com
# 6    Morgan@CitiBankLondon.com     Dipesh@CitiBankHingKong.com
# 7                Mike@HSBC.com           Shai@CitiBankPune.com
# 8           Spike@JPMorgan.com        Anthony@CitiBankPune.com
# 9                Adam@HSBC.com    Dipesh@CitiBankSingapore.com
# 10          Mike@BNYMellon.com    Isabella@CitiBankNewYork.com
# 11              Stacy@HSBC.com      Anthony@CitiBankLondon.com
# 12    Spike@CitiBankLondon.com       Shai@CitiBankHingKong.com
# 13  Morgan@CitiBankNewYork.com        Shai@CitiBankNewYork.com
# 14       Adam@DEUTSCHEBANK.com  Isabella@CitiBankSingapore.com
# 15              Stacy@HSBC.com     Dipesh@CitiBankHingKong.com
# 16   Spike@CitiBankNewYork.com      Shai@CitiBankSingapore.com
# 17          Adam@BNYMellon.com    Dipesh@CitiBankSingapore.com
# 18  Morgan@CitiBankNewYork.com     Dipesh@CitiBankHingKong.com
# 19    Mike@CitiBankNewYork.com    Isabella@CitiBankNewYork.com
#
#                                          Subject  \
# 0                                           None
# 1   Urgent : need transaction details for 646472
# 2          Waiting for amount pending for 269825
# 3                              Acc 412636 Update
# 4          Waiting for amount pending for 558691
# 5                Transaction Complete for 991587
# 6          Transaction is in progress for 973286
# 7   Urgent : need transaction details for 678761
# 8              Payment is in progress for 763667
# 9          Transaction is in progress for 981549
# 10  Urgent : need transaction details for 496348
# 11                  Transaction Failed for699762
# 12             Payment is in progress for 218997
# 13             Payment is in progress for 178773
# 14                     Payment Status for 487957
# 15                Payment in Progress Acc 571689
# 16  Urgent : need transaction details for 516936
# 17                             Acc 835455 Update
# 18               Transaction Complete for 213328
# 19             Payment is in progress for 328415
#
#                                                  Body Class(output)
# 0                                                None          None
# 1   Please find the details of your account 234319...             D
# 2   Due to server overflow transaction 678364 will...             B
# 3   The transaction 281592 is taking too long to b...             B
# 4   Fund transfer for ACC No. 389796 has partially...             B
# 5   The transaction for amount USD465167 related t...             C
# 6    Payment 625814 will be completed within two days             B
# 7   Kindly provide the details for Acc no.511155 a...             D
# 8   The transaction 549325 is taking too long to b...             B
# 9   The transaction 546727 is taking too long to b...             B
# 10  Please find the details of your account 762464...             D
# 11  Due to unknown technical errors, your transact...             A
# 12  The transaction 341446 is taking too long to b...             B
# 13  Fund transfer for ACC No. 642846 has partially...             B
# 14  Kindly provide the details for Acc no.284327 a...             D
# 15
# 16  Please find the details of your account 929574...             D
# 17  Fund transfer for ACC No. 298219 has partially...             B
# 18  Full payment for amount USD641116 has been suc...             C
# 19   Payment 735444 will be completed within two days             B

# %%
import datetime

# %%
start_date = datetime.date(2018, 12, 1)
end_date = datetime.date(2020, 5, 31)

time_between_dates = end_date - start_date
days_between_dates = time_between_dates.days
date_column_data = [start_date + datetime.timedelta(days=random.randrange(days_between_dates)) for i in range(len(data2))]
#print(date_column_data)

# %%
df['Payment Date'] = date_column_data

# %%
df.head(100)
# Out:
#                           From                              To  \
# 0                         None                            None
# 1    Jason@CitiBankNewYork.com   Isabella@CitiBankHingKong.com
# 2         Phillip@JPMorgan.com       Isabella@CitiBankPune.com
# 3      Morgan@DEUTSCHEBANK.com    Dipesh@CitiBankSingapore.com
# 4          Morgan@JPMorgan.com       Isabella@CitiBankPune.com
# 5          Jason@BNYMellon.com       Shai@CitiBankHingKong.com
# 6    Morgan@CitiBankLondon.com     Dipesh@CitiBankHingKong.com
# 7                Mike@HSBC.com           Shai@CitiBankPune.com
# 8           Spike@JPMorgan.com        Anthony@CitiBankPune.com
# 9                Adam@HSBC.com    Dipesh@CitiBankSingapore.com
# 10          Mike@BNYMellon.com    Isabella@CitiBankNewYork.com
# 96      Spike@DEUTSCHEBANK.com    Isabella@CitiBankNewYork.com
# 97               Adam@HSBC.com         Dipesh@CitiBankPune.com
# 98     Mike@CitiBankLondon.com           Shai@CitiBankPune.com
# 99      Jason@DEUTSCHEBANK.com       Dipesh@CitiBankLondon.com
#
#                                          Subject  \
# 0                                           None
# 1   Urgent : need transaction details for 646472
# 2          Waiting for amount pending for 269825
# 3                              Acc 412636 Update
# 4          Waiting for amount pending for 558691
# 5                Transaction Complete for 991587
# 6          Transaction is in progress for 973286
# 7   Urgent : need transaction details for 678761
# 8              Payment is in progress for 763667
# 9          Transaction is in progress for 981549
# 10  Urgent : need transaction details for 496348
# 11                  Transaction Failed for699762
# 12             Payment is in progress for 218997
# 13             Payment is in progress for 178773
# 14                     Payment Status for 487957
# 15                Payment in Progress Acc 571689
# 16  Urgent : need transaction details for 516936
# 17                             Acc 835455 Update
# 18               Transaction Complete for 213328
# 19             Payment is in progress for 328415
# 20         Transaction is in progress for 141765
# 21                    Payment Received for275534
# 22                          Update on Acc 699967
# 23                     Payment Status for 757626
# 24         Transaction is in progress for 913455
# 25                     Payment Failed for 129774
# 26  Urgent : need transaction details for 575732
# 27                     Payment Status for 379688
# 28                  Transaction Failed for581478
# 29                     Payment Failed for 367133
# ..                                           ...
# 70         Transaction is in progress for 391178
# 71                          Update on Acc 525983
# 72                Payment in Progress Acc 264831
# 73                  Transaction Failed for322254
# 74         Waiting for amount pending for 983476
# 75                     Payment Status for 866423
# 76         Transaction is in progress for 623178
# 77                  Transaction Failed for888614
# 78             Payment is in progress for 325865
# 79                  Transaction Failed for738522
# 80                     Payment Failed for 933952
# 81                             Acc 492983 Update
# 82                  Transaction Failed for696688
# 83  Urgent : need transaction details for 781155
# 84                          Update on Acc 654828
# 85                             Acc 691811 Update
# 86                          Update on Acc 472764
# 87             Payment is in progress for 966738
# 88             Payment is in progress for 915871
# 89           Update on payment request for642256
# 90                    Payment Received for823153
# 91               Transaction Complete for 412887
# 92                             Acc 694755 Update
# 93                Payment in Progress Acc 482971
# 94               Transaction Complete for 374542
# 95             Payment is in progress for 117931
# 96                          Update on Acc 372521
# 97         Transaction is in progress for 564532
# 98                    Payment Received for384551
# 99             Payment is in progress for 851889
#
#                                                  Body Class(output)  \
# 0                                                None          None
# 1   Please find the details of your account 234319...             D
# 2   Due to server overflow transaction 678364 will...             B
# 3   The transaction 281592 is taking too long to b...             B
# 4   Fund transfer for ACC No. 389796 has partially...             B
# 5   The transaction for amount USD465167 related t...             C
# 6    Payment 625814 will be completed within two days             B
# 7   Kindly provide the details for Acc no.511155 a...             D
# 8   The transaction 549325 is taking too long to b...             B
# 9   The transaction 546727 is taking too long to b...             B
# 10  Please find the details of your account 762464...             D
# 11  Due to unknown technical errors, your transact...             A
# 12  The transaction 341446 is taking too long to b...             B
# 13  Fund transfer for ACC No. 642846 has partially...             B
# 14  Kindly provide the details for Acc no.284327 a...             D
# 15
# 16  Please find the details of your account 929574...             D
# 17  Fund transfer for ACC No. 298219 has partially...             B
# 18  Full payment for amount USD641116 has been suc...             C
# 19   Payment 735444 will be completed within two days             B
# 20  Due to server overflow transaction 198866 will...             B
# 21  The transaction of amount CAD716993 has been r...             C
# 22  Fund transfer for ACC No. 434569 has partially...             B
# 23  We have received your request and will be send...             D
# 24  Due to server overflow transaction 778593 will...             B
# 25  Due to lack of funds, cheque no. 1165293233257...             A
# 26  Please find the details of your account 515369...             D
# 27  Please find the details of your account 117747...             D
# 28  Payment of GBP743222 has been cancelled as per...             A
# 29  Due to lack of funds, cheque no. 9997215854932...             A
# ..                                                ...           ...
# 70  Due to server overflow transaction 785764 will...             B
# 71   Payment 596755 will be completed within two days             B
# 72
# 73  Payment of USD836747 has been cancelled as per...             A
# 74   Payment 464791 will be completed within two days             B
# 75  Please find the details of your account 193365...             D
# 76   Payment 846961 will be completed within two days             B
# 77  Payment of EUR544122 has been cancelled as per...             A
# 78   Payment 184365 will be completed within two days             B
# 79  Payment of GBP574222 has been cancelled as per...             A
# 80  Payment of CAD464679 has been cancelled as per...             A
# 81  Due to server overflow transaction 753518 will...             B
# 82  Due to lack of funds, cheque no. 8815161963993...             A
# 83  Kindly provide the details for Acc no.782819 a...             D
# 84   Payment 893733 will be completed within two days             B
# 85  Due to server overflow transaction 659925 will...             B
# 86  Fund transfer for ACC No. 619185 has partially...             B
# 87   Payment 224919 will be completed within two days             B
# 88  The transaction 577776 is taking too long to b...             B
# 89  Kindly provide the details for Acc no.687119 a...             D
# 90  The transaction for amount GBP858572 related t...             C
# 91  The transaction of amount GBP618643 has been r...             C
# 92   Payment 519148 will be completed within two days             B
# 93
# 94  The transaction for amount EUR247881 related t...             C
# 95  The transaction 365193 is taking too long to b...             B
# 96  Due to server overflow transaction 166565 will...             B
# 97   Payment 643446 will be completed within two days             B
# 98  The transaction for amount CAD929321 related t...             C
# 99  Due to server overflow transaction 717322 will...             B
#
#    Payment Date
# 0    2020-01-27
# 1    2020-03-18
# 2    2020-03-05
# 3    2020-01-31
# 4    2019-02-21
# 5    2019-08-05
# 6    2019-08-22
# 7    2019-03-15
# 8    2020-04-16
# 9    2019-04-26
# 10   2019-11-13
# 11   2019-01-30
# 12   2019-03-07
# 13   2020-05-03
# 14   2018-12-01
# 15   2020-03-08
# 16   2019-11-30
# 17   2019-08-14
# 18   2020-05-26
# 19   2019-07-17
# 20   2020-02-27
# 21   2019-06-16
# 22   2019-02-18
# 23   2019-09-07
# 24   2019-06-28
# 25   2019-02-12
# 26   2019-05-31
# 27   2019-08-26
# 28   2019-02-10
# 29   2020-03-24
# ..          ...
# 70   2020-01-03
# 71   2019-12-23
# 72   2020-03-10
# 73   2019-11-08
# 74   2019-12-21
# 75   2019-12-18
# 76   2020-03-07
# 77   2020-04-16
# 78   2019-02-27
# 79   2019-12-31
# 80   2019-08-12
# 81   2020-05-07
# 82   2019-06-26
# 83   2019-05-27
# 84   2019-02-19
# 85   2019-10-27
# 86   2019-02-17
# 87   2018-12-27
# 88   2020-02-23
# 89   2019-11-07
# 90   2019-03-21
# 91   2019-05-18
# 92   2020-04-06
# 93   2020-02-19
# 94   2019-11-16
# 95   2019-05-17
# 96   2019-11-30
# 97   2020-02-10
# 98   2020-02-28
# 99   2019-07-10
#
# [100 rows x 6 columns]

# %%
df.to_csv(r'emaildataset.csv', index = False)
