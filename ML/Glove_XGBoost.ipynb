# %% [markdown]
# # Few-Shot Learning Email Classification with Pre-Trained Word2Vec Embeddings

# %%
import pandas as pd
import numpy as np
from random import seed
from random import sample
from wordfile import func
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import re
import joblib
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
from scipy import spatial
import os
import spacy
import en_core_web_sm

# %%
embeddings_index = {}
with open('/home/aheli/glove.6B.300d.txt',encoding='utf-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coeffs = np.asarray(values[1:],dtype='float32')
        embeddings_index[word] = coeffs
    f.close()

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
df = pd.read_csv("/home/aheli/SmartEmailTracker/Merged UI_Listener/emaildataset.csv", usecols = ['Subject','Body', 'Class'])

# %%
df.head(50)
# Out:
#                                               Subject  \
# 0               Transaction no. 072558 is unresolved.
# 1                           Order for new Cheque book
# 2   Required money acquired. Transaction 847047 is...
# 3       Asking for the details for transaction 746078
# 4              Partial payment for transaction 535918
# 5        Payment done and Transaction 683241 settled.
# 6                       Failure of transaction 608189
# 7               Send steps to activate online banking
# 8                       Incomplete transaction 947071
# 9                       Failure of transaction 443004
# 10  The pending amount for transaction 537615 will...
# 11     Handling the transaction 682817 after payment.
# 12           Upgrade to an account with more benefits
# 13          Processing transaction having ID : 064742
# 14                            issue a new Cheque book
# 15  The pending amount for transaction 376023 will...
# 16  Transaction having ID : 155325 has stopped. Help!
# 17              Change address for account no. 090514
# 18  Partially paid the required amount for transac...
# 19  there is an outstanding payment for transactio...
# 20        Sorted out the transaction with ID : 567556
# 21     Handling the transaction 606477 after payment.
# 22                     Transaction 793500 has failed!
# 23                      Failure of transaction 904961
# 24  Accepted payment. Transaction 650055 currently...
# 25                     Transaction 205387 is complete
# 26              Transaction no. 786516 is unresolved.
# 27               Urgent : Not able to withdraw amount
# 28  Accepted payment. Transaction307942 currently ...
# 29  Payment received for transaction : 410544 and ...
# 30  Accepted payment. Transaction031079 currently ...
# 31          Processing transaction having ID : 662798
# 32      Request to send details of transaction 129971
# 33           Fulfilled transaction having ID : 182042
# 34                     Transaction 126536 has failed!
# 35        Sorted out the transaction with ID : 104814
# 36  Pending payment for transaction having ID : 46...
# 37       Payment done and Transaction 733802 settled.
# 38                     Transaction 069701 has failed!
# 39   Want to know more about being a premium customer
# 40                       Want to block account 574380
# 41           Imploring update on transaction : 902339
# 42                Urgent : Transaction 548375 ceased.
# 43  Transaction 391479 stalled and payment not rec...
# 44                  How to change PIN no of ATM card?
# 45  Seeking update on the status of transaction 79...
# 46                   Concluded the transaction 288145
# 47         Payment outstanding for transaction 778165
# 48           Fulfilled transaction having ID : 140962
# 49           Fulfilled transaction having ID : 844492
#
#                                                  Body       Class
# 0   Sorry to inform that there has been only a par...     Pending
# 1   Good morning, I want to place an order for an ...     General
# 2   Hello! This is to inform you that I have recei...  Processing
# 3   I request you to kindly send the status of my ...     Request
# 4   Hello!! Greetings for the day. Status of trans...     Pending
# 5   Greetings! I wanted to let you know that I hav...    Complete
# 6   This is to notify you that my transaction 6081...      Failed
# 7   Hey, I have to transfer funds to a different b...     General
# 8   I regret to inform you that I could only pay t...     Pending
# 9   Hey, I see my transaction with ID 443004 has f...      Failed
# 10  Since my transaction 537615 is still pending, ...     Pending
# 11  Sincere greetings, I am glad to tell you that ...  Processing
# 12  Hello, greetings for the day, So I have an acc...     General
# 13  Acknowledging the received payment for transac...  Processing
# 14  Warm greetings to you. I have recently exhaust...     General
# 15  I regret to inform you the I could only pay th...     Pending
# 16  I have been your regular client and have follo...      Failed
# 17  Hey, It's me again. This time I want to change...     General
# 18  There has been only a partial payment of amoun...     Pending
# 19  The transaction 981293 is taking too long to c...     Pending
# 20  Greetings! I wanted to let you know that I hav...    Complete
# 21  Thank you for transferring the payment to my a...  Processing
# 22  I have been your regular client and have follo...      Failed
# 23  Greetings for the day, I checked my inbox and ...      Failed
# 24  Acknowledging the received payment for transac...  Processing
# 25  To whom it may concern, I just received paymen...    Complete
# 26  Hey, sincere apologies for transferring a frac...     Pending
# 27  This is to inform you that I am not able to wi...     General
# 28  Acknowledging the received payment for transac...  Processing
# 29  Acknowledging the received payment for transac...  Processing
# 30  Thank you for transferring the payment to my a...  Processing
# 31  Sincere greetings, I am glad to tell you that ...  Processing
# 32  Can you please tell me the amount transferred ...     Request
# 33  Hello! Sincere greetings for the day. I would ...    Complete
# 34  This is to notify you that my transaction 1265...      Failed
# 35  Hey, I am writing in reference to the transact...    Complete
# 36  Hey, sincere apologies for transferring a frac...     Pending
# 37  Greetings! I wanted to let you know that I hav...    Complete
# 38  This is to notify you that my transaction 0697...      Failed
# 39  Sincere greetings. I recently came across an o...     General
# 40  Hey, I think I lost my ATM card today so can y...     General
# 41  Can you please tell me the amount transferred ...     Request
# 42  This is to notify you that my transaction 5483...      Failed
# 43  This is in response to your email stating that...      Failed
# 44  Please reply this is very urgent. I have to ch...     General
# 45  I need details of 796561 urgently, please prov...     Request
# 46  Greetings! I wanted to let you know that I hav...    Complete
# 47  this is to regretfully inform you that I could...     Pending
# 48  I deeply appreciate your quick service as I ha...    Complete
# 49  To whom it may concern, I have successfully re...    Complete

# %%
nlp = spacy.load('en')

# %%
nlp_ = en_core_web_sm.load()

# %%
my_stop = ["'d", "'ll", "'m", "'re", "'s", "'ve",'a','cc','subject','http', 'gbp', 'usd', 'eur', 'inr', 'cad', 'thanks', "acc", "id", 'account', 'regards', 'hi', 'hello', 'thank you', 'greetings', 'about','above', 'across','after','afterwards','alone','along','am','among', 'amongst','amount','an','and','another','any','anyhow','anyone','anything','anyway','anywhere','are','around','as', 'at','be','became','because','become','becomes','becoming','been','before','beforehand','behind','being','below', 'beside','besides','between','both','bottom','but','by','ca','call','can','could','did', 'do', 'does', 'doing', 'down', 'due', 'during', 'each', 'eight', 'either', 'eleven', 'else', 'elsewhere', 'everyone', 'everything', 'everywhere', 'fifteen', 'fifty', 'first', 'five', 'for', 'former', 'formerly', 'forty', 'four', 'from', 'front', 'further', 'get', 'give', 'go', 'had', 'has', 'have', 'he', 'hence', 'her', 'here', 'hereafter', 'hereby', 'herein', 'hereupon', 'hers', 'herself', 'him', 'himself', 'his', 'how', 'however', 'hundred', 'i', 'if', 'in', 'indeed', 'into', 'is', 'it', 'its', 'itself', 'just', 'keep', 'last', 'latter', 'latterly', 'least', 'less', 'made', 'make', 'many', 'may', 'me', 'meanwhile', 'might', 'mine', 'more', 'moreover', 'move', 'much', 'must', 'my', 'myself', 'name', 'namely', 'neither', 'nevertheless', 'next', 'nine', 'no', 'nobody', 'now', 'nowhere', 'of', 'off', 'often', 'on', 'one', 'onto', 'or', 'other', 'others', 'otherwise', 'our', 'ours', 'ourselves', 'out', 'own', 'part', 'per', 'perhaps', 'please', 'put', 'quite', 'rather', 're', 'really', 'regarding', 'same', 'say', 'see', 'seem', 'seemed', 'seeming', 'seems', 'she', 'should', 'show', 'side', 'since', 'six', 'sixty', 'so', 'some', 'somehow', 'someone', 'something', 'sometime', 'somewhere', 'such', 'take', 'ten', 'than', 'that', 'the', 'their', 'them', 'themselves', 'then', 'thence', 'there', 'thereafter', 'thereby', 'therefore', 'therein', 'thereupon', 'these', 'they', 'third', 'this', 'those', 'three', 'through', 'throughout', 'thru', 'thus', 'to', 'together', 'too', 'top', 'toward', 'towards', 'twelve', 'twenty', 'two', 'under', 'up', 'upon', 'us', 'using', 'various', 'via', 'was', 'we', 'well', 'were', 'whatever', 'whence', 'whenever', 'whereafter', 'whereas', 'whereby', 'wherein', 'whereupon', 'wherever', 'whether', 'which', 'while', 'whither', 'whoever', 'whole', 'whom', 'whose', 'will', 'with', 'within', 'would', 'yet', 'you', 'your', 'yours', 'yourself', 'yourselves', '‘d', '‘ll', '‘m', '‘re', '‘s', '‘ve', '’d', '’ll', '’m', '’re', '’s', '’ve']

# %%
def get_only_chars(text):    
    text = text.replace("-", " ") #replace hyphens with spaces
    text = text.replace("\t", " ")
    text = text.replace("\n", " ")

    text=text.rstrip()
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    t = ""

    for i in text.lower().split():
        if func(i) is not None:
            t += func(i) + " "
        else :
            t += i + " "

    t = t.rstrip()
    
    text = " ".join([i for i in t.lower().split()])
    text = " ".join(token for token in text.split() if token not in my_stop)

#     doc = nlp(text)
    
#     *****
    doc = nlp(text)
    
    normalized = " ".join(token.lemma_ for token in doc)
    
    doc = " ".join(token.orth_ for token in nlp(normalized) if not token.is_punct | token.is_space)

    return doc
#     *****
    
#     doc = " ".join(token.orth_ for token in doc if not token.is_punct | token.is_space)
#     return doc

# %%
print(get_only_chars("hi i want info on le 12234."))
# Out:
# want info legal entity

# %%
for i in range(df.shape[0]):
    # merge subject and body strings
    df['Text'] = (df['Subject'] + " " + df['Body'])

# %%
def converter(x):
    try:
        return ' '.join([x.lower() for x in str(x).split()])
    except AttributeError:
        return None  # or some other value

df['Text'] = df['Text'].apply(converter)

# %%
# text_clean=[]

# for i in range(df.shape[0]):
#     text_clean.append(get_only_chars(df.loc[i]['Text']))

# %%
df['Text'] = df['Text'].apply(lambda x: get_only_chars(x))

# %%
df = df.drop_duplicates('Text')

# %%
df.shape
# Out:
# (354, 4)

# %%
df.sample(frac=1).reset_index(drop=True)
# Out:
#                                                Subject  \
# 0            Payment is pending for transaction 022539
# 1    Pending payment for transaction having ID : 46...
# 2               Soliciting information for ID : 696876
# 3    Payment received for transaction : 130956 and ...
# 4                        Failure of transaction 443004
# ..                                                 ...
# 349                          Create a new bank account
# 350      Asking for the details for transaction 573115
# 351      Request to send details of transaction 879899
# 352                Dealing with the transaction 807909
# 353                       Want to block account 574380
#
#                                                   Body       Class  \
# 0    It's been 10 days since transaction 022539 . I...     Pending
# 1    Hey, sincere apologies for transferring a frac...     Pending
# 2    Urgently require details of acc 696876 reply asap     Request
# 3    Hello! This is to inform you that I have recei...  Processing
# 4    Hey, I see my transaction with ID 443004 has f...      Failed
# ..                                                 ...         ...
# 349  Hey, Can you please send me the detailed steps...     General
# 350  Kindly note that this is urgent, I need detail...     Request
# 351  I need details of 879899 urgently, please prov...     Request
# 352  Acknowledging the received payment for transac...  Processing
# 353  Hey, I think I lost my ATM card today so can y...     General
#
#                                                   Text
# 0    payment pende transaction s day transaction ve...
# 1    pende payment transaction have hey sincere apo...
# 2    solicit information urgently require detail re...
# 3    payment receive transaction processing inform ...
# 4    failure transaction hey transaction fail think...
# ..                                                 ...
# 349  create new bank hey send detailed step ought f...
# 350  ask detail transaction kindly note urgent need...
# 351  request send detail transaction need detail ur...
# 352  deal transaction acknowledge receive payment t...
# 353  want block hey think lose atm card today block...
#
# [354 rows x 4 columns]

# %%
# set the by default to:
num_classes = df.Class.unique() # the number of classes we consider (since the dataset has many classes)
sample_size = 5 # the number of labeled sampled we’ll require from the user

# %%
smallest_sample_size = min(df['Class'].value_counts())

# %%
# Generate samples that contains K samples of each class

def gen_sample(sample_size, num_classes, df):
    
#     df = df.sample(frac=1).reset_index(drop=True)

    df_1 = df[(df["Class"] < num_classes+1)].reset_index().drop(["index"], axis=1).reset_index().drop(["index"], axis=1)
    
    train = df_1[df_1["Class"] == np.unique(df_1['Class'])[0]].sample(sample_size)
    train_index = train.index.tolist()

    for i in range(1,num_classes):
        train_2 = df_1[df_1["Class"] == np.unique(df_1['Class'])[i]].sample(sample_size)
        train = pd.concat([train, train_2], axis=0)
        train_index.extend(train_2.index.tolist())

    test = df_1[~df_1.index.isin(train_index)]
    return train, test

# %%
from sklearn.preprocessing import LabelEncoder 

le = LabelEncoder()
df['Class'] = le.fit_transform(df['Class'])

# %%
df.head(20)
# Out:
#                                               Subject  \
# 0               Transaction no. 072558 is unresolved.
# 1                           Order for new Cheque book
# 2   Required money acquired. Transaction 847047 is...
# 3       Asking for the details for transaction 746078
# 4              Partial payment for transaction 535918
# 5        Payment done and Transaction 683241 settled.
# 6                       Failure of transaction 608189
# 7               Send steps to activate online banking
# 8                       Incomplete transaction 947071
# 9                       Failure of transaction 443004
# 10  The pending amount for transaction 537615 will...
# 11     Handling the transaction 682817 after payment.
# 12           Upgrade to an account with more benefits
# 13          Processing transaction having ID : 064742
# 14                            issue a new Cheque book
# 15  The pending amount for transaction 376023 will...
# 16  Transaction having ID : 155325 has stopped. Help!
# 17              Change address for account no. 090514
# 18  Partially paid the required amount for transac...
# 19  there is an outstanding payment for transactio...
#
#                                                  Body  Class  \
# 0   Sorry to inform that there has been only a par...      3
# 1   Good morning, I want to place an order for an ...      2
# 2   Hello! This is to inform you that I have recei...      4
# 3   I request you to kindly send the status of my ...      5
# 4   Hello!! Greetings for the day. Status of trans...      3
# 5   Greetings! I wanted to let you know that I hav...      0
# 6   This is to notify you that my transaction 6081...      1
# 7   Hey, I have to transfer funds to a different b...      2
# 8   I regret to inform you that I could only pay t...      3
# 9   Hey, I see my transaction with ID 443004 has f...      1
# 10  Since my transaction 537615 is still pending, ...      3
# 11  Sincere greetings, I am glad to tell you that ...      4
# 12  Hello, greetings for the day, So I have an acc...      2
# 13  Acknowledging the received payment for transac...      4
# 14  Warm greetings to you. I have recently exhaust...      2
# 15  I regret to inform you the I could only pay th...      3
# 16  I have been your regular client and have follo...      1
# 17  Hey, It's me again. This time I want to change...      2
# 18  There has been only a partial payment of amoun...      3
# 19  The transaction 981293 is taking too long to c...      3
#
#                                                  Text
# 0   transaction unresolve sorry inform only partia...
# 1   order new cheque book good morning want place ...
# 2   require money acquire transaction process info...
# 3   ask detail transaction request kindly send sta...
# 4   partial payment transaction day status transac...
# 5   payment do transaction settle want let know ac...
# 6   failure transaction notify transaction fail re...
# 7   send step activate online banking hey transfer...
# 8   incomplete transaction regret inform only pay ...
# 9   failure transaction hey transaction fail think...
# 10  pende transaction reach soon transaction still...
# 11  handle transaction payment sincere glad tell f...
# 12  upgrade benefits day branch have recently see ...
# 13  process transaction have acknowledge receive p...
# 14  issue new cheque book warm recently exhaust ch...
# 15  pende transaction reach soon regret inform onl...
# 16  transaction have stop help regular client foll...
# 17  change address hey s again time want change ad...
# 18  partially pay require transaction only partial...
# 19  outstanding payment transaction transaction ta...

# %%
df.Class.value_counts()
# Out:
# 2    75
# 5    72
# 3    66
# 0    51
# 1    49
# 4    41
# Name: Class, dtype: int64

# %%
for i in range(0, 6):
    print(i)
    print(le.inverse_transform([i]))
# Out:
# 0
# ['Complete']
# 1
# ['Failed']
# 2
# ['General']
# 3
# ['Pending']
# 4
# ['Processing']
# 5
# ['Request']

# %%
train, test = gen_sample(25, 6, df)

# %%
train.Class.value_counts()
# Out:
# 5    25
# 4    25
# 3    25
# 2    25
# 1    25
# 0    25
# Name: Class, dtype: int64

# %%
test.Class.value_counts()
# Out:
# 2    50
# 5    47
# 3    41
# 0    26
# 1    24
# 4    16
# Name: Class, dtype: int64

# %%
def transform_sentence(text, embeddings_index):

    def preprocess_text(raw_text, model=embeddings_index):

        raw_text = raw_text.split()
        return list(filter(lambda x: x in embeddings_index.keys(), raw_text))

    tokens = preprocess_text(text)

    if not tokens:
        return np.zeros(300)

    c = [embeddings_index[i] for i in tokens]
    text_vector = np.mean(c, axis=0)
    return np.array(text_vector)

# %%
if not os.path.exists('/home/aheli/SmartEmailTracker/Merged UI_Listener/pkl_objects'):
        os.mkdir('/home/aheli/SmartEmailTracker/Merged UI_Listener/pkl_objects')
    
joblib.dump(le, '/home/aheli/SmartEmailTracker/Merged UI_Listener/pkl_objects/labelencoder.pkl')
# Out:
# ['/home/aheli/SmartEmailTracker/Merged UI_Listener/pkl_objects/labelencoder.pkl']

# %% [markdown]
# ## Pre-trained Glove embeddings and ML algorithms

# %%
# Install with below cell if you're not able to install on terminal

# import sys
# !{sys.executable} -m pip install xgboost

# %%
import xgboost

# %%
def return_score_xgb(sample_size, num_classes, df):

    train, test = gen_sample(sample_size, num_classes, df=df)

    X_train = train['Text'].values
    y_train = train['Class'].values
    X_test = test['Text'].values
    y_test = test['Class'].values

    X_train_mean = np.array([transform_sentence(x, embeddings_index) for x in X_train])
    X_test_mean = np.array([transform_sentence(x, embeddings_index) for x in X_test])

#     XG Boost
    clf = xgboost.XGBClassifier()
    
    eval_set = [(X_train_mean, y_train), (X_test_mean, y_test)]
    eval_metric = ["auc","error", "logloss"]
    # %time clf.fit(X_train_mean, y_train, early_stopping_rounds=10, eval_metric="merror", eval_set=eval_set, verbose=True)
#     clf.fit(X_train_mean, y_train)

    joblib.dump(clf, './clf.pkl')

    y_pred = clf.predict(X_test_mean)
    
    # evaluate predictions
    accuracy = accuracy_score(y_pred, y_test)
    print("Accuracy: %.2f%%" % (accuracy * 100.0))

    return accuracy_score(y_pred, y_test)

# %% [markdown]
# ## Comparison of accuracies

# %%
all_accuracy = {0: []}

for num_samples in range(1, 26):
    all_accuracy[0].append(return_score_xgb(num_samples,len(df.Class.unique()), df))
# Out:
# [0]	validation_0-merror:0.83333	validation_1-merror:0.85632
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.83333	validation_1-merror:0.85632
# [2]	validation_0-merror:0.83333	validation_1-merror:0.85632
# [3]	validation_0-merror:0.83333	validation_1-merror:0.85632
# [4]	validation_0-merror:0.83333	validation_1-merror:0.85632
# [5]	validation_0-merror:0.83333	validation_1-merror:0.85632
# [6]	validation_0-merror:0.83333	validation_1-merror:0.85632
# [7]	validation_0-merror:0.83333	validation_1-merror:0.85632
# [8]	validation_0-merror:0.83333	validation_1-merror:0.85632
# [9]	validation_0-merror:0.83333	validation_1-merror:0.85632
# [10]	validation_0-merror:0.83333	validation_1-merror:0.85632
# Stopping. Best iteration:
# [0]	validation_0-merror:0.83333	validation_1-merror:0.85632
#
# CPU times: user 509 ms, sys: 30.2 ms, total: 540 ms
# Wall time: 293 ms
# Accuracy: 14.37%
# [0]	validation_0-merror:0.41667	validation_1-merror:0.74269
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.59649
# [2]	validation_0-merror:0.00000	validation_1-merror:0.61111
# [3]	validation_0-merror:0.00000	validation_1-merror:0.53801
# [4]	validation_0-merror:0.00000	validation_1-merror:0.50877
# [5]	validation_0-merror:0.00000	validation_1-merror:0.45906
# [6]	validation_0-merror:0.00000	validation_1-merror:0.37134
# [7]	validation_0-merror:0.00000	validation_1-merror:0.35965
# [8]	validation_0-merror:0.00000	validation_1-merror:0.35380
# [9]	validation_0-merror:0.00000	validation_1-merror:0.37719
# [10]	validation_0-merror:0.00000	validation_1-merror:0.37134
# [8]	validation_0-merror:0.00000	validation_1-merror:0.18056
# [9]	validation_0-merror:0.00000	validation_1-merror:0.17361
# [10]	validation_0-merror:0.00000	validation_1-merror:0.17361
# [11]	validation_0-merror:0.00000	validation_1-merror:0.17708
# [12]	validation_0-merror:0.00000	validation_1-merror:0.17361
# [13]	validation_0-merror:0.00000	validation_1-merror:0.17708
# [14]	validation_0-merror:0.00000	validation_1-merror:0.17014
# [15]	validation_0-merror:0.00000	validation_1-merror:0.18056
# [16]	validation_0-merror:0.00000	validation_1-merror:0.18056
# [17]	validation_0-merror:0.00000	validation_1-merror:0.17014
# [18]	validation_0-merror:0.00000	validation_1-merror:0.17361
# [19]	validation_0-merror:0.00000	validation_1-merror:0.16667
# [20]	validation_0-merror:0.00000	validation_1-merror:0.16319
# [21]	validation_0-merror:0.00000	validation_1-merror:0.15625
# [22]	validation_0-merror:0.00000	validation_1-merror:0.15625
# [23]	validation_0-merror:0.00000	validation_1-merror:0.15625
# [24]	validation_0-merror:0.00000	validation_1-merror:0.15625
# [25]	validation_0-merror:0.00000	validation_1-merror:0.15625
# [26]	validation_0-merror:0.00000	validation_1-merror:0.15625
# [27]	validation_0-merror:0.00000	validation_1-merror:0.15625
# [28]	validation_0-merror:0.00000	validation_1-merror:0.15625
# [29]	validation_0-merror:0.00000	validation_1-merror:0.15625
# [30]	validation_0-merror:0.00000	validation_1-merror:0.15625
# [31]	validation_0-merror:0.00000	validation_1-merror:0.15625
# Stopping. Best iteration:
# [21]	validation_0-merror:0.00000	validation_1-merror:0.15625
#
# CPU times: user 1.53 s, sys: 108 ms, total: 1.63 s
# Wall time: 668 ms
# Accuracy: 84.38%
# [0]	validation_0-merror:0.01389	validation_1-merror:0.37234
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.01389	validation_1-merror:0.31206
# [2]	validation_0-merror:0.00000	validation_1-merror:0.30496
# [3]	validation_0-merror:0.00000	validation_1-merror:0.25177
# [4]	validation_0-merror:0.00000	validation_1-merror:0.23759
# [5]	validation_0-merror:0.00000	validation_1-merror:0.22695
# [6]	validation_0-merror:0.00000	validation_1-merror:0.22695
# [7]	validation_0-merror:0.00000	validation_1-merror:0.22340
# [8]	validation_0-merror:0.00000	validation_1-merror:0.21986
# [9]	validation_0-merror:0.00000	validation_1-merror:0.21986
# [10]	validation_0-merror:0.00000	validation_1-merror:0.21277
# [11]	validation_0-merror:0.00000	validation_1-merror:0.21631
# [12]	validation_0-merror:0.00000	validation_1-merror:0.21631
# [13]	validation_0-merror:0.00000	validation_1-merror:0.21986
# [14]	validation_0-merror:0.00000	validation_1-merror:0.21986
# [15]	validation_0-merror:0.00000	validation_1-merror:0.21631
# [16]	validation_0-merror:0.00000	validation_1-merror:0.21631
# [17]	validation_0-merror:0.00000	validation_1-merror:0.20567
# [18]	validation_0-merror:0.00000	validation_1-merror:0.20567
# [19]	validation_0-merror:0.00000	validation_1-merror:0.20567
# [20]	validation_0-merror:0.00000	validation_1-merror:0.20213
# [21]	validation_0-merror:0.00000	validation_1-merror:0.20567
# [22]	validation_0-merror:0.00000	validation_1-merror:0.20213
# [23]	validation_0-merror:0.00000	validation_1-merror:0.20213
# [24]	validation_0-merror:0.00000	validation_1-merror:0.20213
# [25]	validation_0-merror:0.00000	validation_1-merror:0.20213
# [26]	validation_0-merror:0.00000	validation_1-merror:0.20213
# [27]	validation_0-merror:0.00000	validation_1-merror:0.20213
# [28]	validation_0-merror:0.00000	validation_1-merror:0.20213
# [29]	validation_0-merror:0.00000	validation_1-merror:0.20213
# [30]	validation_0-merror:0.00000	validation_1-merror:0.20213
# Stopping. Best iteration:
# [20]	validation_0-merror:0.00000	validation_1-merror:0.20213
#
# CPU times: user 1.34 s, sys: 51.7 ms, total: 1.39 s
# Wall time: 909 ms
# Accuracy: 79.79%
# [0]	validation_0-merror:0.01282	validation_1-merror:0.28261
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.01282	validation_1-merror:0.19565
# [2]	validation_0-merror:0.00000	validation_1-merror:0.18478
# [3]	validation_0-merror:0.00000	validation_1-merror:0.17391
# [4]	validation_0-merror:0.00000	validation_1-merror:0.14493
# [5]	validation_0-merror:0.00000	validation_1-merror:0.13406
# [6]	validation_0-merror:0.00000	validation_1-merror:0.11957
# [7]	validation_0-merror:0.00000	validation_1-merror:0.13043
# [8]	validation_0-merror:0.00000	validation_1-merror:0.11957
# [9]	validation_0-merror:0.00000	validation_1-merror:0.12319
# [10]	validation_0-merror:0.00000	validation_1-merror:0.13043
# [11]	validation_0-merror:0.00000	validation_1-merror:0.12319
# [12]	validation_0-merror:0.00000	validation_1-merror:0.12681
# [13]	validation_0-merror:0.00000	validation_1-merror:0.12681
# [14]	validation_0-merror:0.00000	validation_1-merror:0.11957
# [15]	validation_0-merror:0.00000	validation_1-merror:0.10870
# [16]	validation_0-merror:0.00000	validation_1-merror:0.10507
# [17]	validation_0-merror:0.00000	validation_1-merror:0.10870
# [18]	validation_0-merror:0.00000	validation_1-merror:0.10870
# [19]	validation_0-merror:0.00000	validation_1-merror:0.09783
# [20]	validation_0-merror:0.00000	validation_1-merror:0.10145
# [21]	validation_0-merror:0.00000	validation_1-merror:0.10145
# [22]	validation_0-merror:0.00000	validation_1-merror:0.10145
# [23]	validation_0-merror:0.00000	validation_1-merror:0.10145
# [24]	validation_0-merror:0.00000	validation_1-merror:0.10145
# [25]	validation_0-merror:0.00000	validation_1-merror:0.10145
# [26]	validation_0-merror:0.00000	validation_1-merror:0.10145
# [27]	validation_0-merror:0.00000	validation_1-merror:0.10145
# [28]	validation_0-merror:0.00000	validation_1-merror:0.10145
# [29]	validation_0-merror:0.00000	validation_1-merror:0.10145
# Stopping. Best iteration:
# [19]	validation_0-merror:0.00000	validation_1-merror:0.09783
#
# CPU times: user 1.49 s, sys: 67.9 ms, total: 1.56 s
# Wall time: 726 ms
# Accuracy: 90.22%
# [0]	validation_0-merror:0.03571	validation_1-merror:0.28889
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0
# [21]	validation_0-merror:0.00000	validation_1-merror:0.17045
# [22]	validation_0-merror:0.00000	validation_1-merror:0.17045
# [23]	validation_0-merror:0.00000	validation_1-merror:0.16667
# [24]	validation_0-merror:0.00000	validation_1-merror:0.16667
# [25]	validation_0-merror:0.00000	validation_1-merror:0.16667
# [26]	validation_0-merror:0.00000	validation_1-merror:0.16667
# [27]	validation_0-merror:0.00000	validation_1-merror:0.16667
# [28]	validation_0-merror:0.00000	validation_1-merror:0.16667
# [29]	validation_0-merror:0.00000	validation_1-merror:0.16667
# [30]	validation_0-merror:0.00000	validation_1-merror:0.16667
# [31]	validation_0-merror:0.00000	validation_1-merror:0.16667
# [32]	validation_0-merror:0.00000	validation_1-merror:0.16667
# [33]	validation_0-merror:0.00000	validation_1-merror:0.16667
# Stopping. Best iteration:
# [23]	validation_0-merror:0.00000	validation_1-merror:0.16667
#
# CPU times: user 1.66 s, sys: 56 ms, total: 1.72 s
# Wall time: 732 ms
# Accuracy: 83.33%
# [0]	validation_0-merror:0.02083	validation_1-merror:0.23643
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.15116
# [2]	validation_0-merror:0.00000	validation_1-merror:0.15504
# [3]	validation_0-merror:0.00000	validation_1-merror:0.12791
# [4]	validation_0-merror:0.00000	validation_1-merror:0.13178
# [5]	validation_0-merror:0.00000	validation_1-merror:0.12403
# [6]	validation_0-merror:0.00000	validation_1-merror:0.11240
# [7]	validation_0-merror:0.00000	validation_1-merror:0.12403
# [8]	validation_0-merror:0.00000	validation_1-merror:0.10853
# [9]	validation_0-merror:0.00000	validation_1-merror:0.10853
# [10]	validation_0-merror:0.00000	validation_1-merror:0.08139
# [11]	validation_0-merror:0.00000	validation_1-merror:0.08527
# [12]	validation_0-merror:0.00000	validation_1-merror:0.07752
# [13]	validation_0-merror:0.00000	validation_1-merror:0.07752
# [14]	validation_0-merror:0.00000	validation_1-merror:0.08527
# [15]	validation_0-merror:0.00000	validation_1-merror:0.08527
# [16]	validation_0-merror:0.00000	validation_1-merror:0.08139
# [17]	validation_0-merror:0.00000	validation_1-merror:0.08527
# [18]	validation_0-merror:0.00000	validation_1-merror:0.07752
# [19]	validation_0-merror:0.00000	validation_1-merror:0.07752
# [20]	validation_0-merror:0.00000	validation_1-merror:0.06977
# [21]	validation_0-merror:0.00000	validation_1-merror:0.06977
# [22]	validation_0-merror:0.00000	validation_1-merror:0.07364
# [23]	validation_0-merror:0.00000	validation_1-merror:0.06977
# [24]	validation_0-merror:0.00000	validation_1-merror:0.06977
# [25]	validation_0-merror:0.00000	validation_1-merror:0.06977
# [26]	validation_0-merror:0.00000	validation_1-merror:0.06977
# [27]	validation_0-merror:0.00000	validation_1-merror:0.06589
# [28]	validation_0-merror:0.00000	validation_1-merror:0.06589
# [29]	validation_0-merror:0.00000	validation_1-merror:0.06589
# [30]	validation_0-merror:0.00000	validation_1-merror:0.06589
# [31]	validation_0-merror:0.00000	validation_1-merror:0.06589
# [32]	validation_0-merror:0.00000	validation_1-merror:0.06589
# [33]	validation_0-merror:0.00000	validation_1-merror:0.06589
# [34]	validation_0-merror:0.00000	validation_1-merror:0.06589
# [35]	validation_0-merror:0.00000	validation_1-merror:0.06589
# [36]	validation_0-merror:0.00000	validation_1-merror:0.06589
# [37]	validation_0-merror:0.00000	validation_1-merror:0.06589
# Stopping. Best iteration:
# [27]	validation_0-merror:0.00000	validation_1-merror:0.06589
#
# CPU times: user 1.88 s, sys: 81.9 ms, total: 1.97 s
# Wall time: 893 ms
# Accuracy: 93.41%
# [0]	validation_0-merror:0.01961	validation_1-merror:0.22619
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.01961	validation_1-merror:0.20635
# [2]	validation_0-merror:0.00980	validation_1-merror:0.17460
# [3]	validation_0-merror:0.00000	validation_1-merror:0.14683
# [4]	validation_0-merror:0.00000	validation_1-merror:0.14683
# [5]	validation_0-merror:0.00000	validation_1-merror:0.13889
# [6]	validation_0-merror:0.00000	validation_1-merror:0.12302
# [7]	validation_0-merror:0.00000	validation_1-merror:0.11905
# [8]	validation_0-merror:0.00000	validation_1-merror:0.10714
# [9]	validation_0-merror:0.00000	validation_1-merror:0.10318
# [10]	validation_0-merror:0.00000	validation_1-merror:0.10714
# [11]	validation_0-merror:0.00000	validation_1-merror:0.09921
# [12]	validation_0-merror:0.00000	validation_1-merror:0.11111
# [13]	validation_0-merror:0.00000	validation_1-merror:0.09921
# [14]	validation_0-merror:0.00000	validation_1-merror:0.09127
# [15]	validation_0-merror:0.00000	validation_1-merror:0.09127
# [16]	validation_0-merror:0.00000	validation_1-merror:0.10318
# [17]	validation_0-merror:0.00000	validation_1-merror:0.10318
# [18]	validation_0-merror:0.00000	validation_1-merror:0.09524
# [19]	validation_0-merror:0.00000	validation_1-merror:0.10318
# [20]	validation_0-merror:0.00000	validation_1-merror:0.09921
# [21]	validation_0-merror:0.00000	validation_1-merror:0.09921
# [22]	validation_0-merror:0.00000	validation_1-merror:0.09921
# [23]	validation_0-merror:0.00000	validation_1-merror:0.09524
# [24]	validation_0-merror:0.00000	validation_1-merror:0.08730
# [25]	validation_0-merror:0.00000	validation_1-merror:0.08730
# [26]	validation_0-merror:0.00000	validation_1-merror:0.08730
# [27]	validation_0-merror:0.00000	validation_1-merror:0.08730
# [28]	validation_0-merror:0.00000	validation_1-merror:0.08730
# [29]	validation_0-merror:0.00000	validation_1-merror:0.08730
# [30]	validation_0-merror:0.00000	validation_1-merror:0.08730
# [31]	validation_0-merror:0.00000	validation_1-merror:0.08730
# [32]	validation_0-merror:0.00000	validation_1-merror:0.08730
# [33]	validation_0-merror:0.00000	validation_1-merror:0.08730
# [34]	validation_0-merror:0.00000	validation_1-merror:0.08730
# Stopping. Best iteration:
# [24]	validation_0-merror:0.00000	validation_1-merror:0.08730
#
# CPU times: user 2.07 s, sys: 55.4 ms, total: 2.12 s
# Wall time: 913 ms
# Accuracy: 91.27%
# [0]	validation_0-merror:0.00926	validation_1-merror:0.26423
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00926	validation_1-merror:0.21545
# [2]	validation_0-merror:0.00000	validation_1-merror:0.15854
# [3]	validation_0-merror:0.00000	validation_1-merror:0.16667
# [4]	validation_0-merror:0.00000	validation_1-merror:0.17480
# [5]	validation_0-merror:0.00000	validation_1-merror:0.14228
# [6]	validation_0-merror:0.00000	validation_1-merror:0.11382
# [7]	validation_0-merror:0.00000	validation_1-merror:0.11789
# [8]	validation_0-merror:0.00000	validation_1-merror:0.10569
# [9]	validation_0-merror:0.00000	validation_1-merror:0.10163
# [10]	validation_0-merror:0.00000	validation_1-merror:0.10569
# [11]	validation_0-merror:0.00000	validation_1-merror:0.10163
# [12]	validation_0-merror:0.00000	validation_1-merror:0.09350
# [13]	validation_0-merror:0.00000	validation_1-merror:0.09350
# [14]	validation_0-merror:0.00000	validation_1-merror:0.09350
# [15]	validation_0-merror:0.00000	validation_1-merror:0.08943
# [16]	validation_0-merror:0.00000	validation_1-merror:0.07724
# [17]	validation_0-merror:0.00000	validation_1-merror:0.08130
# [18]	validation_0-merror:0.00000	validation_1-merror:0.07724
# [19]	validation_0-merror:0.00000	validation_1-merror:0.07724
# [20]	validation_0-merror:0.00000	validation_1-merror:0.06911
# [21]	validation_0-merror:0.00000	validation_1-merror:0.06911
# [22]	validation_0-merror:0.00000	validation_1-merror:0.06911
# [23]	validation_0-merror:0.00000	validation_1-merror:0.06911
# [24]	validation_0-merror:0.00000	validation_1-merror:0.06911
# [25]	validation_0-merror:0.00000	validation_1-merror:0.06911
# [26]	validation_0-merror:0.00000	validation_1-merror:0.06911
# [27]	validation_0-merror:0.00000	validation_1-merror:0.06911
# [28]	validation_0-merror:0.00000	validation_1-merror:0.06911
# [29]	validation_0-merror:0.00000	validation_1-merror:0.06911
# [30]	validation_0-merror:0.00000	validation_1-merror:0.06911
# Stopping. Best iteration:
# [20]	validation_0-merror:0.00000	validation_1-merror:0.06911
#
# CPU times: user 1.45 s, sys: 47 ms, total: 1.49 s
# Wall time: 607 ms
# Accuracy: 93.09%
# [0]	validation_0-merror:0.00000	validation_1-merror:0.28750
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.28333
# [2]	validation_0-merror:0.00000	validation_1-merror:0.23750
# [3]	validation_0-merror:0.00000	validation_1-merror:0.17917
# [4]	validation_0-merror:0.00000	validation_1-merror:0.15417
# [5]	validation_0-merror:0.00000	validation_1-merror:0.14583
# [6]	validation_0-merror:0.00000	validation_1-merror:0.13333
# [7]	validation_0-merror:0.00000	validation_1-merror:0.13333
# [8]	validation_0-merror:0.00000	validation_1-merror:0.13333
# [9]	validation_0-merror:0.00000	validation_1-merror:0.12917
# [10]	validation_0-merror:0.00000	validation_1-merror:0.12500
# [11]	validation_0-merror:0.00000	validation_1-merror:0.12083
# [12]	validation_0-merror:0.00000	validation_1-merror:0.11250
# [13]	validation_0-merror:0.00000	validation_1-merror:0.11667
# [14]	validation_0-merror:0.00000	validation_1-merror:0.12500
# [15]	validation_0-merror:0.00000	validation_1-merror:0.12083
# [16]	validation_0-merror:0.00000	validation_1-merror:0.12083
# [17]	validation_0-merror:0.00000	validation_1-merror:0.11667
# [18]	validation_0-merror:0.00000	validation_1-merror:0.11667
# [19]	validation_0-merror:0.00000	validation_1-merror:0.11667
# [20]	validation_0-merror:0.00000	validation_1-merror:0.11250
# [21]	validation_0-merror:0.00000	validation_1-merror:0.11250
# [22]	validation_0-merror:0.00000	validation_1-merror:0.11250
# Stopping. Best iteration:
# [12]	validation_0-merror:0.00000	validation_1-merror:0.11250
#
# CPU times: user 1.38 s, sys: 28.3 ms, total: 1.41 s
# Wall time: 573 ms
# Accuracy: 88.75%
# [0]	validation_0-merror:0.01667	validation_1-merror:0.27350
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.23932
# [2]	validation_0-merror:0.00000	validation_1-merror:0.23077
# [3]	validation_0-merror:0.00000	validation_1-merror:0.21795
# [4]	validation_0-merror:0.00000	validation_1-merror:0.22222
# [5]	validation_0-merror:0.00000	validation_1-merror:0.20940
# [6]	validation_0-merror:0.00000	validation_1-merror:0.19658
# [7]	validation_0-merror:0.00000	validation_1-merror:0.19231
# [8]	validation_0-merror:0.00000	validation_1-merror:0.18803
# [9]	validation_0-merror:0.00000	validation_1-merror:0.17949
# [10]	validation_0-merror:0.00000	validation_1-merror:0.17521
# [11]	validation_0-merror:0.00000	validation_1-merror:0.17521
# [12]	validation_0-merror:0.00000	validation_1-merror:0.17521
# [13]	validation_0-merror:0.00000	validation_1-merror:0.16239
# [14]	validation_0-merror:0.00000	validation_1-merror:0.16667
# [15]	validation_0-merror:0.00000	validation_1-merror:0.17094
# [16]	validation_0-merror:0.00000	validation_1-merror:0.17094
# [17]	validation_0-merror:0.00000	validation_1-merror:0.17094
# [18]	validation_0-merror:0.00000	validation_1-merror:0.16239
# [19]	validation_0-merror:0.00000	validation_1-merror:0.16239
# [20]	validation_0-merror:0.00000	validation_1-merror:0.15812
# [21]	validation_0-merror:0.00000	validation_1-merror:0.15812
# [22]	validation_0-merror:0.00000	validation_1-merror:0.15812
# [23]	validation_0-merror:0.00000	validation_1-merror:0.15812
# [24]	validation_0-merror:0.00000	validation_1-merror:0.15812
# [25]	validation_0-merror:0.00000	validation_1-merror:0.15812
# [26]	validation_0-merror:0.00000	validation_1-merror:0.15812
# [27]	validation_0-merror:0.00000	validation_1-merror:0.15812
# [28]	validation_0-merror:0.00000	validation_1-merror:0.15812
# [29]	validation_0-merror:0.00000	validation_1-merror:0.15812
# [30]	validation_0-merror:0.00000	validation_1-merror:0.15812
# Stopping. Best iteration:
# [20]	validation_0-merror:0.00000	validation_1-merror:0.15812
#
# CPU times: user 2.05 s, sys: 75.1 ms, total: 2.13 s
# Wall time: 1.07 s
# Accuracy: 84.19%
# [0]	validation_0-merror:0.00794	validation_1-merror:0.17544
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.11403
# [2]	validation_0-merror:0.00000	validation_1-merror:0.12719
# [3]	validation_0-merror:0.00000	validation_1-merror:0.13597
# [4]	validation_0-merror:0.00000	validation_1-merror:0.13158
# [5]	validation_0-merror:0.00000	validation_1-merror:0.11842
# [6]	validation_0-merror:0.00000	validation_1-merror:0.11842
# [7]	validation_0-merror:0.00000	validation_1-merror:0.12281
# [8]	validation_0-merror:0.00000	validation_1-merror:0.12281
# [9]	validation_0-merror:0.00000	validation_1-merror:0.12281
# [10]	validation_0-merror:0.00000	validation_1-merror:0.12719
# [11]	validation_0-merror:0.00000	validation_1-merror:0.12281
# Stopping. Best iteration:
# [1]	validation_0-merror:0.00000	validation_1-merror:0.11403
#
# CPU times: user 1.25 s, sys: 46.3 ms, total: 1.29 s
# Wall time: 553 ms
# Accuracy: 88.60%
# [0]	validation_0-merror:0.01515	validation_1-merror:0.20721
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.14865
# [2]	validation_0-merror:0.00000	validation_1-merror:0.12613
# [3]	validation_0-merror:0.00000	validation_1-merror:0.10360
# [4]	validation_0-merror:0.00000	validation_1-merror:0.09009
# [5]	validation_0-merror:0.00000	validation_1-merror:0.08559
# [6]	validation_0-merror:0.00000	validation_1-merror:0.07207
# [7]	validation_0-merror:0.00000	validation_1-merror:0.06757
# [8]	validation_0-merror:0.00000	validation_1-merror:0.06757
# [9]	validation_0-merror:0.00000	validation_1-merror:0.07207
# [10]	validation_0-merror:0.00000	validation_1-merror:0.06757
# [11]	validation_0-merror:0.00000	validation_1-merror:0.06757
# [12]	validation_0-merror:0.00000	validation_1-merror:0.06757
# [13]	validation_0-merror:0.00000	validation_1-merror:0.07207
# [14]	validation_0-merror:0.00000	validation_1-merror:0.06757
# [15]	validation_0-merror:0.00000	validation_1-merror:0.07207
# [16]	validation_0-merror:0.00000	validation_1-merror:0.07207
# [17]	validation_0-merror:0.00000	validation_1-merror:0.07207
# Stopping. Best iteration:
# [7]	validation_0-merror:0.00000	validation_1-merror:0.06757
#
# CPU times: user 1.28 s, sys: 58.6 ms, total: 1.34 s
# Wall time: 564 ms
# Accuracy: 93.24%
# [0]	validation_0-merror:0.01449	validation_1-merror:0.20833
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.15278
# [2]	validation_0-merror:0.00000	validation_1-merror:0.12500
# [3]	validation_0-merror:0.00000	validation_1-merror:0.11574
# [4]	validation_0-merror:0.00000	validation_1-merror:0.09722
# [5]	validation_0-merror:0.00000	validation_1-merror:0.08796
# [6]	validation_0-merror:0.00000	validation_1-merror:0.08796
# [7]	validation_0-merror:0.00000	validation_1-merror:0.08796
# [8]	validation_0-merror:0.00000	validation_1-merror:0.08796
# [9]	validation_0-merror:0.00000	validation_1-merror:0.06019
# [10]	validation_0-merror:0.00000	validation_1-merror:0.05556
# [11]	validation_0-merror:0.00000	validation_1-merror:0.05093
# [12]	validation_0-merror:0.00000	validation_1-merror:0.05093
# [13]	validation_0-merror:0.00000	validation_1-merror:0.04630
# [14]	validation_0-merror:0.00000	validation_1-merror:0.04630
# [15]	validation_0-merror:0.00000	validation_1-merror:0.04167
# [16]	validation_0-merror:0.00000	validation_1-merror:0.04167
# [17]	validation_0-merror:0.00000	validation_1-merror:0.04167
# [18]	validation_0-merror:0.00000	validation_1-merror:0.04630
# [19]	validation_0-merror:0.00000	validation_1-merror:0.04630
# [20]	validation_0-merror:0.00000	validation_1-merror:0.04167
# [21]	validation_0-merror:0.00000	validation_1-merror:0.04167
# [22]	validation_0-merror:0.00000	validation_1-merror:0.04167
# [23]	validation_0-merror:0.00000	validation_1-merror:0.03704
# [24]	validation_0-merror:0.00000	validation_1-merror:0.03241
# [25]	validation_0-merror:0.00000	validation_1-merror:0.03241
# [26]	validation_0-merror:0.00000	validation_1-merror:0.03241
# [27]	validation_0-merror:0.00000	validation_1-merror:0.03241
# [28]	validation_0-merror:0.00000	validation_1-merror:0.03241
# [29]	validation_0-merror:0.00000	validation_1-merror:0.03241
# [30]	validation_0-merror:0.00000	validation_1-merror:0.03241
# [31]	validation_0-merror:0.00000	validation_1-merror:0.03241
# [32]	validation_0-merror:0.00000	validation_1-merror:0.03241
# [33]	validation_0-merror:0.00000	validation_1-merror:0.03241
# [34]	validation_0-merror:0.00000	validation_1-merror:0.03241
# Stopping. Best iteration:
# [24]	validation_0-merror:0.00000	validation_1-merror:0.03241
#
# CPU times: user 1.95 s, sys: 40.2 ms, total: 1.99 s
# Wall time: 841 ms
# Accuracy: 96.76%
# [0]	validation_0-merror:0.01389	validation_1-merror:0.19048
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.15238
# [2]	validation_0-merror:0.00000	validation_1-merror:0.10000
# [3]	validation_0-merror:0.00000	validation_1-merror:0.10000
# [4]	validation_0-merror:0.00000	validation_1-merror:0.10476
# [5]	validation_0-merror:0.00000	validation_1-merror:0.10476
# [6]	validation_0-merror:0.00000	validation_1-merror:0.10000
# [7]	validation_0-merror:0.00000	validation_1-merror:0.09524
# [8]	validation_0-merror:0.00000	validation_1-merror:0.08571
# [9]	validation_0-merror:0.00000	validation_1-merror:0.08571
# [10]	validation_0-merror:0.00000	validation_1-merror:0.08571
# [11]	validation_0-merror:0.00000	validation_1-merror:0.09524
# [12]	validation_0-merror:0.00000	validation_1-merror:0.08571
# [13]	validation_0-merror:0.00000	validation_1-merror:0.08571
# [14]	validation_0-merror:0.00000	validation_1-merror:0.08571
# [15]	validation_0-merror:0.00000	validation_1-merror:0.08095
# [16]	validation_0-merror:0.00000	validation_1-merror:0.08095
# [17]	validation_0-merror:0.00000	validation_1-merror:0.07619
# [18]	validation_0-merror:0.00000	validation_1-merror:0.07619
# [19]	validation_0-merror:0.00000	validation_1-merror:0.09048
# [20]	validation_0-merror:0.00000	validation_1-merror:0.09048
# [21]	validation_0-merror:0.00000	validation_1-merror:0.09048
# [22]	validation_0-merror:0.00000	validation_1-merror:0.08571
# [23]	validation_0-merror:0.00000	validation_1-merror:0.07619
# [24]	validation_0-merror:0.00000	validation_1-merror:0.08571
# [25]	validation_0-merror:0.00000	validation_1-merror:0.08095
# [26]	validation_0-merror:0.00000	validation_1-merror:0.08095
# [27]	validation_0-merror:0.00000	validation_1-merror:0.08095
# Stopping. Best iteration:
# [17]	validation_0-merror:0.00000	validation_1-merror:0.07619
#
# CPU times: user 2.2 s, sys: 59.2 ms, total: 2.26 s
# Wall time: 915 ms
# Accuracy: 92.38%
# [0]	validation_0-merror:0.01333	validation_1-merror:0.20588
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00667	validation_1-merror:0.16176
# [2]	validation_0-merror:0.00000	validation_1-merror:0.15196
# [3]	validation_0-merror:0.00000	validation_1-merror:0.13235
# [4]	validation_0-merror:0.00000	validation_1-merror:0.14216
# [5]	validation_0-merror:0.00000	validation_1-merror:0.12255
# [6]	validation_0-merror:0.00000	validation_1-merror:0.09804
# [7]	validation_0-merror:0.00000	validation_1-merror:0.10294
# [8]	validation_0-merror:0.00000	validation_1-merror:0.09804
# [9]	validation_0-merror:0.00000	validation_1-merror:0.09804
# [10]	validation_0-merror:0.00000	validation_1-merror:0.08823
# [11]	validation_0-merror:0.00000	validation_1-merror:0.08333
# [12]	validation_0-merror:0.00000	validation_1-merror:0.08333
# [13]	validation_0-merror:0.00000	validation_1-merror:0.08333
# [14]	validation_0-merror:0.00000	validation_1-merror:0.08333
# [15]	validation_0-merror:0.00000	validation_1-merror:0.07843
# [16]	validation_0-merror:0.00000	validation_1-merror:0.07353
# [17]	validation_0-merror:0.00000	validation_1-merror:0.07353
# [18]	validation_0-merror:0.00000	validation_1-merror:0.07353
# [19]	validation_0-merror:0.00000	validation_1-merror:0.07353
# [20]	validation_0-merror:0.00000	validation_1-merror:0.07353
# [21]	validation_0-merror:0.00000	validation_1-merror:0.07353
# [22]	validation_0-merror:0.00000	validation_1-merror:0.07353
# [23]	validation_0-merror:0.00000	validation_1-merror:0.07353
# [24]	validation_0-merror:0.00000	validation_1-merror:0.07353
# [25]	validation_0-merror:0.00000	validation_1-merror:0.07353
# [26]	validation_0-merror:0.00000	validation_1-merror:0.07353
# Stopping. Best iteration:
# [16]	validation_0-merror:0.00000	validation_1-merror:0.07353
#
# CPU times: user 2.5 s, sys: 84.1 ms, total: 2.58 s
# Wall time: 1.05 s
# Accuracy: 92.65%

# %%
plt.figure(figsize=(12,8))
plt.plot(all_accuracy[0])
# plt.axvline(7, c='black', alpha=0.5)

plt.title("Accuracy depending on the number of samples for XG Boost algorithm")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Summary

# %%
df_results = pd.DataFrame({
    
    'Nb Classes':[6], 

    'mean XG Boost':[np.mean(all_accuracy[0])], 
    'max XG Boost':[
        max(all_accuracy[0])]
    })

df_results
# Out:
#    Nb Classes  mean XG Boost  max XG Boost
# 0           6       0.773548      0.967593

# %%
def return_score(sample_size, num_classes, df):

    train, test = gen_sample(sample_size, num_classes, df=df)

    X_train = train['Text'].values
    y_train = train['Class'].values
    X_test = test['Text'].values
    y_test = test['Class'].values

    X_train_mean = np.array([transform_sentence(x, embeddings_index) for x in X_train])
    X_test_mean = np.array([transform_sentence(x, embeddings_index) for x in X_test])

#     XG Boost
    clf2 = xgboost.XGBClassifier()
    
    eval_set = [(X_train_mean, y_train), (X_test_mean, y_test)]
#     eval_metric = ["auc","error", "logloss"]
    clf2.fit(X_train_mean, y_train, early_stopping_rounds=10, eval_metric="merror", eval_set=eval_set, verbose=True)
    

    joblib.dump(clf, './clf_multi.pkl')

    y_pred = clf2.predict(X_test_mean)
    
    # evaluate predictions
    accuracy = accuracy_score(y_pred, y_test)
    print("Accuracy: %.2f%%" % (accuracy * 100.0))

    return accuracy_score(y_pred, y_test)

# %%
all_accuracy_xgb = {num:[] for num in range(2, len(df.Class.unique()) + 1)}

# %%
for num_samples in range(1, 40):

    for num_cl in range(2, len(df.Class.unique()) + 1):

        all_accuracy_xgb[num_cl].append(return_score_xgb(num_samples,num_cl, df))

# %%
plt.figure(figsize=(12,8))
plt.plot(all_accuracy_xgb[2], label="2 classes")
plt.plot(all_accuracy_xgb[3], label="3 classes")
plt.plot(all_accuracy_xgb[4], label="4 classes")
plt.plot(all_accuracy_xgb[5], label="5 classes")
plt.plot(all_accuracy_xgb[6], label="6 classes")
plt.axvline(7, c='black', alpha=0.5)

plt.title("Accuracy depending on the number of classes for XG Boost algorithm")
plt.legend()
plt.show()
plt.savefig('accuracy_plot.jpg')

# %%
df_results = pd.DataFrame({
    
    'Nb Classes':[2, 3, 4, 5, 6], 

    'mean XG Boost':[np.mean(all_accuracy_xgb[2]), 
        np.mean(all_accuracy_xgb[3]), 
        np.mean(all_accuracy_xgb[4]), 
        np.mean(all_accuracy_xgb[5]),
        np.mean(all_accuracy_xgb[6])],
    'max XG Boost':[max(all_accuracy_xgb[2]), 
        max(all_accuracy_xgb[3]), 
        max(all_accuracy_xgb[4]), 
        max(all_accuracy_xgb[5]),
        max(all_accuracy_xgb[6])]
    })

# %%
df_results

# %% [markdown]
# ## Testing on incoming email

# %%
le = joblib.load('/home/aheli/SmartEmailTracker/Merged UI_Listener/pkl_objects/labelencoder.pkl')
clf = joblib.load('./clf.pkl')

# %%
def is_empty_sent(cd):
#     for i in range(cd.shape[0]):
#         if cd[i] != 0:
#             return False
#     return True
    all_zeros = not cd.any()
    return all_zeros

print(is_empty_sent(transform_sentence("efrg vftrg ojinc", embeddings_index)))
# Out:
# True

# %%
def inp(emailto, emailfrom, subj, bod):
    text = subj + " " + bod
    text = get_only_chars(text)
    X_test_mean = np.array([transform_sentence(text, embeddings_index)])
    
    if is_empty_sent(X_test_mean) is True:
        print("Unable to read email.Please ensure that it is in English!")
        return

    y_pred = clf.predict(X_test_mean)
    print(y_pred)

    return le.inverse_transform(y_pred)

# %%
print(inp("fvf", "defrfg", "payment processed", "hi, the payment for acc 1234 for usd 3456 was paid successfully."))
# Out:
# [4]
# ['Processing']

# %%
print(inp("cfdfv", "derftrg", "Partially paid the required amount for transaction", "There has been only a partial payment of amount 1234"))
# Out:
# [3]
# ['Pending']

# %%
print(inp("Jason@DEUTSCHEBANK.com", "Suhail@CitiBankPune.com", "Want to know more about being a premium customer", "Sincere greetings. I recently came across an offer saying I would have higher interest rates if I am willing to upgrade my account to a premium one. I want to base my decision on its pros as well as cons. So perhaps you could throw some light on it? That woud be very kind of you."))
# Out:
# [2]
# ['General']

# %%
print(inp("qwrqef", "cfdvfv", "", "Payment of 471862128 CAD to account id 101165 has been made on 19/02/2020 and is in progress, please acknowledge."))
# Out:
# [1]
# ['Failed']

# %%
print(inp("RFg", "ewrdef", "what is the status of my transaction: 12345", "hello "))
# Out:
# [3]
# ['Pending']

# %%
print(inp("abdf@", "fvfb","payment for ID 3456 done", "I'm glad to inform you that your payment was successfully transferred to the bank account."))
# Out:
# [0]
# ['Complete']
