# %% [markdown]
# # Few-Shot Learning Email Classification with Pre-Trained Word2Vec Embeddings

# %%
import pandas as pd
import numpy as np
from random import seed
from random import sample
from wordfile import func
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import re
import joblib
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
from scipy import spatial
import os
import spacy

# %%
embeddings_index = {}
with open('../glove.6B.300d.txt',encoding='utf-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coeffs = np.asarray(values[1:],dtype='float32')
        embeddings_index[word] = coeffs
    f.close()

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
df = pd.read_csv("./emaildataset.csv", usecols = ['Subject','Body', 'Class'])
df.head()
# Out:
#                                              Subject  \
# 0              Transaction no. 072558 is unresolved.
# 1                          Order for new Cheque book
# 2  Required money acquired. Transaction 847047 is...
# 3      Asking for the details for transaction 746078
# 4             Partial payment for transaction 535918
#
#                                                 Body       Class
# 0  Sorry to inform that there has been only a par...     Pending
# 1  Good morning, I want to place an order for an ...     General
# 2  Hello! This is to inform you that I have recei...  Processing
# 3  I request you to kindly send the status of my ...     Request
# 4  Hello!! Greetings for the day. Status of trans...     Pending

# %%
nlp = spacy.load('en')

# %%
my_stop = ["'d", "'ll", "'m", "'re", "'s", "'ve",'a','cc','subject','http', 'gbp', 'usd', 'eur', 'inr', 'cad', 'thanks', "acc", "id", 'account', 'regards', 'hi', 'hello', 'thank you', 'greetings', 'about','above', 'across','after','afterwards','alone','along','am','among', 'amongst','amount','an','and','another','any','anyhow','anyone','anything','anyway','anywhere','are','around','as', 'at','be','became','because','become','becomes','becoming','been','before','beforehand','behind','being','below', 'beside','besides','between','both','bottom','but','by','ca','call','can','could','did', 'do', 'does', 'doing', 'down', 'due', 'during', 'each', 'eight', 'either', 'eleven', 'else', 'elsewhere', 'everyone', 'everything', 'everywhere', 'fifteen', 'fifty', 'first', 'five', 'for', 'former', 'formerly', 'forty', 'four', 'from', 'front', 'further', 'get', 'give', 'go', 'had', 'has', 'have', 'he', 'hence', 'her', 'here', 'hereafter', 'hereby', 'herein', 'hereupon', 'hers', 'herself', 'him', 'himself', 'his', 'how', 'however', 'hundred', 'i', 'if', 'in', 'indeed', 'into', 'is', 'it', 'its', 'itself', 'just', 'keep', 'last', 'latter', 'latterly', 'least', 'less', 'made', 'make', 'many', 'may', 'me', 'meanwhile', 'might', 'mine', 'more', 'moreover', 'move', 'much', 'must', 'my', 'myself', 'name', 'namely', 'neither', 'nevertheless', 'next', 'nine', 'no', 'nobody', 'now', 'nowhere', 'of', 'off', 'often', 'on', 'one', 'onto', 'or', 'other', 'others', 'otherwise', 'our', 'ours', 'ourselves', 'out', 'own', 'part', 'per', 'perhaps', 'please', 'put', 'quite', 'rather', 're', 'really', 'regarding', 'same', 'say', 'see', 'seem', 'seemed', 'seeming', 'seems', 'she', 'should', 'show', 'side', 'since', 'six', 'sixty', 'so', 'some', 'somehow', 'someone', 'something', 'sometime', 'somewhere', 'such', 'take', 'ten', 'than', 'that', 'the', 'their', 'them', 'themselves', 'then', 'thence', 'there', 'thereafter', 'thereby', 'therefore', 'therein', 'thereupon', 'these', 'they', 'third', 'this', 'those', 'three', 'through', 'throughout', 'thru', 'thus', 'to', 'together', 'too', 'top', 'toward', 'towards', 'twelve', 'twenty', 'two', 'under', 'up', 'upon', 'us', 'using', 'various', 'via', 'was', 'we', 'well', 'were', 'whatever', 'whence', 'whenever', 'whereafter', 'whereas', 'whereby', 'wherein', 'whereupon', 'wherever', 'whether', 'which', 'while', 'whither', 'whoever', 'whole', 'whom', 'whose', 'will', 'with', 'within', 'would', 'yet', 'you', 'your', 'yours', 'yourself', 'yourselves', '‘d', '‘ll', '‘m', '‘re', '‘s', '‘ve', '’d', '’ll', '’m', '’re', '’s', '’ve']

# %%
def get_only_chars(text):    
    text = text.replace("-", " ") #replace hyphens with spaces
    text = text.replace("\t", " ")
    text = text.replace("\n", " ")

    text=text.rstrip()
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    t = ""

    for i in text.lower().split():
        if func(i) is not None:
            t += func(i) + " "
        else :
            t += i + " "

    t = t.rstrip()
    
    text = " ".join([i for i in t.lower().split()])
    text = " ".join(token for token in text.split() if token not in my_stop)

    doc = nlp(text)
    
    doc = " ".join(token.orth_ for token in doc if not token.is_punct | token.is_space)
    return doc

# %%
print(get_only_chars("hi i want info on le 12234."))
# Out:
# want info legal entity

# %%
for i in range(df.shape[0]):
    # merge subject and body strings
    df['Text'] = (df['Subject'] + " " + df['Body'])

# %%
def converter(x):
    try:
        return ' '.join([x.lower() for x in str(x).split()])
    except AttributeError:
        return None  # or some other value

df['Text'] = df['Text'].apply(converter)

# %%
text_clean=[]

for i in range(df.shape[0]):
    text_clean.append(get_only_chars(df.loc[i]['Text']))

# %%
df['Text'] = df['Text'].apply(lambda x: get_only_chars(x))

# %%
df = df.drop_duplicates('Text')

# %%
df.shape
# Out:
# (355, 4)

# %%
df.sample(frac=1).reset_index(drop=True)
# Out:
#                                                Subject  \
# 0             Imploring update on transaction : 222632
# 1             Imploring update on transaction : 404035
# 2           Payment outstanding for transaction 399192
# 3    The pending amount for transaction 213375 will...
# 4                                      New Cheque book
# ..                                                 ...
# 350  Partially paid the required amount for transac...
# 351  Pending payment for transaction having ID : 80...
# 352      Request to send details of transaction 375722
# 353   Received full payment for transaction no. 956518
# 354       Abrupt closure of transaction with ID 868876
#
#                                                   Body     Class  \
# 0    Hey, I would be really grateful if you could t...   Request
# 1                I need a status update on 404035 asap   Request
# 2    Since my transaction 399192 is still pending, ...   Pending
# 3    The transaction 213375 is taking too long to c...   Pending
# 4    I need a new cheque book of 25 leaves. Kindly ...   General
# ..                                                 ...       ...
# 350  Hey, sincere apologies for transferring a frac...   Pending
# 351  I regret to inform you the I could only pay th...   Pending
# 352  Please provide a status update on 375722 at th...   Request
# 353  Hello! Sincere greetings for the day. I would ...  Complete
# 354  This is in response to your email stating that...    Failed
#
#                                                   Text
# 0    imploring update transaction hey grateful tell...
# 1    imploring update transaction need status updat...
# 2    payment outstanding transaction transaction st...
# 3    pending transaction reach soon transaction tak...
# 4    new cheque book need new cheque book leaves ki...
# ..                                                 ...
# 350  partially paid required transaction hey sincer...
# 351  pending payment transaction having regret info...
# 352  request send details transaction provide statu...
# 353  received full payment transaction sincere day ...
# 354  abrupt closure transaction response email stat...
#
# [355 rows x 4 columns]

# %%
# set the by default to:
num_classes = df.Class.unique() # the number of classes we consider (since the dataset has many classes)
sample_size = 5 # the number of labeled sampled we’ll require from the user

# %%
smallest_sample_size = min(df['Class'].value_counts())

# %%
# Generate samples that contains K samples of each class

def gen_sample(sample_size, num_classes, df):
    
    df = df.sample(frac=1).reset_index(drop=True)

    df_1 = df[(df["Class"] < num_classes+1)].reset_index().drop(["index"], axis=1).reset_index().drop(["index"], axis=1)
    
    train = df_1[df_1["Class"] == np.unique(df_1['Class'])[0]].sample(sample_size)
    train_index = train.index.tolist()

    for i in range(1,num_classes):
        train_2 = df_1[df_1["Class"] == np.unique(df_1['Class'])[i]].sample(sample_size)
        train = pd.concat([train, train_2], axis=0)
        train_index.extend(train_2.index.tolist())

    test = df_1[~df_1.index.isin(train_index)]
    return train, test

# %%
from sklearn.preprocessing import LabelEncoder 

le = LabelEncoder()
df['Class'] = le.fit_transform(df['Class'])

# %%
df.head(20)
# Out:
#                                               Subject  \
# 0               Transaction no. 072558 is unresolved.
# 1                           Order for new Cheque book
# 2   Required money acquired. Transaction 847047 is...
# 3       Asking for the details for transaction 746078
# 4              Partial payment for transaction 535918
# 5        Payment done and Transaction 683241 settled.
# 6                       Failure of transaction 608189
# 7               Send steps to activate online banking
# 8                       Incomplete transaction 947071
# 9                       Failure of transaction 443004
# 10  The pending amount for transaction 537615 will...
# 11     Handling the transaction 682817 after payment.
# 12           Upgrade to an account with more benefits
# 13          Processing transaction having ID : 064742
# 14                            issue a new Cheque book
# 15  The pending amount for transaction 376023 will...
# 16  Transaction having ID : 155325 has stopped. Help!
# 17              Change address for account no. 090514
# 18  Partially paid the required amount for transac...
# 19  there is an outstanding payment for transactio...
#
#                                                  Body  Class  \
# 0   Sorry to inform that there has been only a par...      3
# 1   Good morning, I want to place an order for an ...      2
# 2   Hello! This is to inform you that I have recei...      4
# 3   I request you to kindly send the status of my ...      5
# 4   Hello!! Greetings for the day. Status of trans...      3
# 5   Greetings! I wanted to let you know that I hav...      0
# 6   This is to notify you that my transaction 6081...      1
# 7   Hey, I have to transfer funds to a different b...      2
# 8   I regret to inform you that I could only pay t...      3
# 9   Hey, I see my transaction with ID 443004 has f...      1
# 10  Since my transaction 537615 is still pending, ...      3
# 11  Sincere greetings, I am glad to tell you that ...      4
# 12  Hello, greetings for the day, So I have an acc...      2
# 13  Acknowledging the received payment for transac...      4
# 14  Warm greetings to you. I have recently exhaust...      2
# 15  I regret to inform you the I could only pay th...      3
# 16  I have been your regular client and have follo...      1
# 17  Hey, It's me again. This time I want to change...      2
# 18  There has been only a partial payment of amoun...      3
# 19  The transaction 981293 is taking too long to c...      3
#
#                                                  Text
# 0   transaction unresolved sorry inform only parti...
# 1   order new cheque book good morning want place ...
# 2   required money acquired transaction process in...
# 3   asking details transaction request kindly send...
# 4   partial payment transaction day status transac...
# 5   payment done transaction settled wanted let kn...
# 6   failure transaction notify transaction failed ...
# 7   send steps activate online banking hey transfe...
# 8   incomplete transaction regret inform only pay ...
# 9   failure transaction hey transaction failed thi...
# 10  pending transaction reach soon transaction sti...
# 11  handling transaction payment sincere glad tell...
# 12  upgrade benefits day branch having recently se...
# 13  processing transaction having acknowledging re...
# 14  issue new cheque book warm recently exhausted ...
# 15  pending transaction reach soon regret inform o...
# 16  transaction having stopped help regular client...
# 17  change address hey s again time want change ad...
# 18  partially paid required transaction only parti...
# 19  outstanding payment transaction transaction ta...

# %%
df.Class.value_counts()
# Out:
# 2    75
# 5    72
# 3    66
# 0    52
# 1    49
# 4    41
# Name: Class, dtype: int64

# %%
for i in range(0, 6):
    print(i)
    print(le.inverse_transform([i]))
# Out:
# 0
# ['Complete']
# 1
# ['Failed']
# 2
# ['General']
# 3
# ['Pending']
# 4
# ['Processing']
# 5
# ['Request']

# %%
def transform_sentence(text, embeddings_index):

    def preprocess_text(raw_text, model=embeddings_index):

        raw_text = raw_text.split()
        return list(filter(lambda x: x in embeddings_index.keys(), raw_text))

    tokens = preprocess_text(text)

    if not tokens:
        return np.zeros(300)

    c = [embeddings_index[i] for i in tokens]
    text_vector = np.mean(c, axis=0)
    return np.array(text_vector)

# %%
if not os.path.exists('./pkl_objects'):
        os.mkdir('./pkl_objects')
    
joblib.dump(le, './pkl_objects/labelencoder.pkl')
# Out:
# ['./pkl_objects/labelencoder.pkl']

# %% [markdown]
# ## Pre-trained Glove embeddings and ML algorithms

# %%
# Install with below cell if you're not able to install on terminal

# import sys
# !{sys.executable} -m pip install xgboost

# %%
import xgboost

# %%
def return_score_xgb(sample_size, num_classes, df):

    train, test = gen_sample(sample_size, num_classes, df=df)

    X_train = train['Text'].values
    y_train = train['Class'].values
    X_test = test['Text'].values
    y_test = test['Class'].values

    X_train_mean = np.array([transform_sentence(x, embeddings_index) for x in X_train])
    X_test_mean = np.array([transform_sentence(x, embeddings_index) for x in X_test])

#     XG Boost
    clf = xgboost.XGBClassifier()
    
    eval_set = [(X_train_mean, y_train), (X_test_mean, y_test)]
#     eval_metric = ["auc","error", "logloss"]
    # %time clf.fit(X_train_mean, y_train, early_stopping_rounds=10, eval_metric="merror", eval_set=eval_set, verbose=True)
    

    joblib.dump(clf, './pkl_objects/clf.pkl')

    y_pred = clf.predict(X_test_mean)
    
    # evaluate predictions
    accuracy = accuracy_score(y_pred, y_test)
    print("Accuracy: %.2f%%" % (accuracy * 100.0))

    return accuracy_score(y_pred, y_test)

# %% [markdown]
# ## Comparison of accuracies

# %%
all_accuracy = {0: []}

for num_samples in range(1, 41):
    all_accuracy[0].append(return_score_xgb(num_samples,len(df.Class.unique()), df))
# Out:
# [0]	validation_0-merror:0.83333	validation_1-merror:0.85387
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.83333	validation_1-merror:0.85387
# [2]	validation_0-merror:0.83333	validation_1-merror:0.85387
# [3]	validation_0-merror:0.83333	validation_1-merror:0.85387
# [4]	validation_0-merror:0.83333	validation_1-merror:0.85387
# [5]	validation_0-merror:0.83333	validation_1-merror:0.85387
# [6]	validation_0-merror:0.83333	validation_1-merror:0.85387
# [7]	validation_0-merror:0.83333	validation_1-merror:0.85387
# [8]	validation_0-merror:0.83333	validation_1-merror:0.85387
# [9]	validation_0-merror:0.83333	validation_1-merror:0.85387
# [10]	validation_0-merror:0.83333	validation_1-merror:0.85387
# Stopping. Best iteration:
# [0]	validation_0-merror:0.83333	validation_1-merror:0.85387
#
# CPU times: user 359 ms, sys: 4.53 ms, total: 363 ms
# Wall time: 145 ms
# Accuracy: 14.61%
# [0]	validation_0-merror:0.33333	validation_1-merror:0.76093
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.69679
# [2]	validation_0-merror:0.00000	validation_1-merror:0.58601
# [3]	validation_0-merror:0.00000	validation_1-merror:0.54519
# [4]	validation_0-merror:0.00000	validation_1-merror:0.56268
# [5]	validation_0-merror:0.00000	validation_1-merror:0.56560
# [6]	validation_0-merror:0.00000	validation_1-merror:0.54227
# [7]	validation_0-merror:0.00000	validation_1-merror:0.52187
# [8]	validation_0-merror:0.00000	validation_1-merror:0.48105
# [9]	validation_0-merror:0.00000	validation_1-merror:0.46647
# [10]	validation_0-merror:0.00000	validation_1-merror:0.46356
# [11]	validation_0-merror:0.00000	validation_1-merror:0.45773
# [12]	validation_0-merror:0.00000	validation_1-merror:0.45773
# [13]	validation_0-merror:0.00000	validation_1-merror:0.45773
# [14]	validation_0-merror:0.00000	validation_1-merror:0.45773
# [15]	validation_0-merror:0.00000	validation_1-merror:0.45773
# [16]	validation_0-merror:0.00000	validation_1-merror:0.46064
# [17]	validation_0-merror:0.00000	validation_1-merror:0.46064
# [18]	validation_0-merror:0.00000	validation_1-merror:0.46064
# [19]	validation_0-merror:0.00000	validation_1-merror:0.46064
# [20]	validation_0-merror:0.00000	validation_1-merror:0.46064
# [21]	validation_0-merror:0.00000	validation_1-merror:0.46064
# Stopping. Best iteration:
# [11]	validation_0-merror:0.00000	validation_1-merror:0.45773
#
# CPU times: user 613 ms, sys: 12 ms, total: 625 ms
# Wall time: 240 ms
# Accuracy: 54.23%
# [0]	validation_0-merror:0.22222	validation_1-merror:0.57864
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.45994
# [2]	validation_0-merror:0.00000	validation_1-merror:0.45994
# [3]	validation_0-merror:0.00000	validation_1-merror:0.45994
# [4]	validation_0-merror:0.00000	validation_1-merror:0.45994
# [5]	validation_0-merror:0.00000	validation_1-merror:0.45994
# [6]	validation_0-merror:0.00000	validation_1-merror:0.45994
# [7]	validation_0-merror:0.00000	validation_1-merror:0.45994
# [8]	validation_0-merror:0.00000	validation_1-merror:0.45994
# [9]	validation_0-merror:0.00000	validation_1-merror:0.45994
# [10]	validation_0-merror:0.00000	validation_1-merror:0.45697
# [11]	validation_0-merror:0.00000	validation_1-merror:0.45697
# [12]	validation_0-merror:0.00000	validation_1-merror:0.45697
# [13]	validation_0-merror:0.00000	validation_1-merror:0.45994
# [14]	validation_0-merror:0.00000	validation_1-merror:0.45697
# [15]	validation_0-merror:0.00000	validation_1-merror:0.45697
# [16]	validation_0-merror:0.00000	validation_1-merror:0.45697
# [17]	validation_0-merror:0.00000	validation_1-merror:0.45697
# [13]	validation_0-merror:0.00000	validation_1-merror:0.48923
# [14]	validation_0-merror:0.00000	validation_1-merror:0.48923
# [15]	validation_0-merror:0.00000	validation_1-merror:0.48615
# [16]	validation_0-merror:0.00000	validation_1-merror:0.48615
# [17]	validation_0-merror:0.00000	validation_1-merror:0.48923
# [18]	validation_0-merror:0.00000	validation_1-merror:0.48923
# [19]	validation_0-merror:0.00000	validation_1-merror:0.48923
# [20]	validation_0-merror:0.00000	validation_1-merror:0.48923
# [21]	validation_0-merror:0.00000	validation_1-merror:0.48923
# [22]	validation_0-merror:0.00000	validation_1-merror:0.48923
# [23]	validation_0-merror:0.00000	validation_1-merror:0.48923
# [24]	validation_0-merror:0.00000	validation_1-merror:0.48923
# [25]	validation_0-merror:0.00000	validation_1-merror:0.48923
# Stopping. Best iteration:
# [15]	validation_0-merror:0.00000	validation_1-merror:0.48615
#
# CPU times: user 903 ms, sys: 20.3 ms, total: 924 ms
# Wall time: 352 ms
# Accuracy: 51.38%
# [0]	validation_0-merror:0.00000	validation_1-merror:0.37618
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.32288
# [2]	validation_0-merror:0.00000	validation_1-merror:0.32915
# [3]	validation_0-merror:0.00000	validation_1-merror:0.32288
# [4]	validation_0-merror:0.00000	validation_1-merror:0.31661
# [5]	validation_0-merror:0.00000	validation_1-merror:0.31661
# [6]	validation_0-merror:0.00000	validation_1-merror:0.31975
# [7]	validation_0-merror:0.00000	validation_1-merror:0.31661
# [8]	validation_0-merror:0.00000	validation_1-merror:0.31661
# [9]	validation_0-merror:0.00000	validation_1-merror:0.32602
# [10]	validation_0-merror:0.00000	validation_1-merror:0.33542
# [11]	validation_0-merror:0.00000	validation_1-merror:0.31975
# [12]	validation_0-merror:0.00000	validation_1-merror:0.30721
# [13]	validation_0-merror:0.00000	validation_1-merror:0.31975
# [14]	validation_0-merror:0.00000	validation_1-merror:0.31348
# [15]	validation_0-merror:0.00000	validation_1-merror:0.30721
# [16]	validation_0-merror:0.00000	validation_1-merror:0.30721
# [17]	validation_0-merror:0.00000	validation_1-merror:0.29467
# [18]	validation_0-merror:0.00000	validation_1-merror:0.29467
# [19]	validation_0-merror:0.00000	validation_1-merror:0.29467
# [20]	validation_0-merror:0.00000	validation_1-merror:0.29467
# [21]	validation_0-merror:0.00000	validation_1-merror:0.29467
# [22]	validation_0-merror:0.00000	validation_1-merror:0.29467
# [23]	validation_0-merror:0.00000	validation_1-merror:0.29467
# [24]	validation_0-merror:0.00000	validation_1-merror:0.29467
# [25]	validation_0-merror:0.00000	validation_1-merror:0.29467
# [26]	validation_0-merror:0.00000	validation_1-merror:0.29467
# [27]	validation_0-merror:0.00000	validation_1-merror:0.29467
# Stopping. Best iteration:
# [17]	validation_0-merror:0.00000	validation_1-merror:0.29467
#
# CPU times: user 1.15 s, sys: 44.8 ms, total: 1.2 s
# Wall time: 528 ms
# Accuracy: 70.53%
# [0]	validation_0-merror:0.02381	validation_1-merror:0.37380
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0
# [14]	validation_0-merror:0.00000	validation_1-merror:0.06498
# [15]	validation_0-merror:0.00000	validation_1-merror:0.06498
# [16]	validation_0-merror:0.00000	validation_1-merror:0.06498
# [17]	validation_0-merror:0.00000	validation_1-merror:0.06137
# [18]	validation_0-merror:0.00000	validation_1-merror:0.05776
# [19]	validation_0-merror:0.00000	validation_1-merror:0.05776
# [20]	validation_0-merror:0.00000	validation_1-merror:0.05776
# [21]	validation_0-merror:0.00000	validation_1-merror:0.05776
# [22]	validation_0-merror:0.00000	validation_1-merror:0.05776
# [23]	validation_0-merror:0.00000	validation_1-merror:0.05776
# [24]	validation_0-merror:0.00000	validation_1-merror:0.05776
# [25]	validation_0-merror:0.00000	validation_1-merror:0.05776
# [26]	validation_0-merror:0.00000	validation_1-merror:0.05776
# [27]	validation_0-merror:0.00000	validation_1-merror:0.05776
# [28]	validation_0-merror:0.00000	validation_1-merror:0.05776
# Stopping. Best iteration:
# [18]	validation_0-merror:0.00000	validation_1-merror:0.05776
#
# CPU times: user 1.46 s, sys: 19.8 ms, total: 1.48 s
# Wall time: 507 ms
# Accuracy: 94.22%
# [0]	validation_0-merror:0.00000	validation_1-merror:0.29889
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.20664
# [2]	validation_0-merror:0.00000	validation_1-merror:0.16605
# [3]	validation_0-merror:0.00000	validation_1-merror:0.15867
# [4]	validation_0-merror:0.00000	validation_1-merror:0.15498
# [5]	validation_0-merror:0.00000	validation_1-merror:0.18450
# [6]	validation_0-merror:0.00000	validation_1-merror:0.18081
# [7]	validation_0-merror:0.00000	validation_1-merror:0.18450
# [8]	validation_0-merror:0.00000	validation_1-merror:0.18081
# [9]	validation_0-merror:0.00000	validation_1-merror:0.18450
# [10]	validation_0-merror:0.00000	validation_1-merror:0.17343
# [11]	validation_0-merror:0.00000	validation_1-merror:0.17343
# [12]	validation_0-merror:0.00000	validation_1-merror:0.16974
# [13]	validation_0-merror:0.00000	validation_1-merror:0.17343
# [14]	validation_0-merror:0.00000	validation_1-merror:0.15867
# Stopping. Best iteration:
# [4]	validation_0-merror:0.00000	validation_1-merror:0.15498
#
# CPU times: user 678 ms, sys: 24 ms, total: 702 ms
# Wall time: 212 ms
# Accuracy: 84.50%
# [0]	validation_0-merror:0.00000	validation_1-merror:0.16981
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.15472
# [2]	validation_0-merror:0.00000	validation_1-merror:0.13962
# [3]	validation_0-merror:0.00000	validation_1-merror:0.11321
# [4]	validation_0-merror:0.00000	validation_1-merror:0.10943
# [5]	validation_0-merror:0.00000	validation_1-merror:0.11321
# [6]	validation_0-merror:0.00000	validation_1-merror:0.12076
# [7]	validation_0-merror:0.00000	validation_1-merror:0.10943
# [8]	validation_0-merror:0.00000	validation_1-merror:0.11321
# [9]	validation_0-merror:0.00000	validation_1-merror:0.10943
# [10]	validation_0-merror:0.00000	validation_1-merror:0.10566
# [11]	validation_0-merror:0.00000	validation_1-merror:0.10566
# [12]	validation_0-merror:0.00000	validation_1-merror:0.10566
# [13]	validation_0-merror:0.00000	validation_1-merror:0.10566
# [14]	validation_0-merror:0.00000	validation_1-merror:0.09811
# [15]	validation_0-merror:0.00000	validation_1-merror:0.09434
# [16]	validation_0-merror:0.00000	validation_1-merror:0.09057
# [17]	validation_0-merror:0.00000	validation_1-merror:0.09811
# [18]	validation_0-merror:0.00000	validation_1-merror:0.09811
# [19]	validation_0-merror:0.00000	validation_1-merror:0.09811
# [20]	validation_0-merror:0.00000	validation_1-merror:0.09434
# [21]	validation_0-merror:0.00000	validation_1-merror:0.09811
# [22]	validation_0-merror:0.00000	validation_1-merror:0.09811
# [23]	validation_0-merror:0.00000	validation_1-merror:0.09811
# [24]	validation_0-merror:0.00000	validation_1-merror:0.09811
# [25]	validation_0-merror:0.00000	validation_1-merror:0.09811
# [26]	validation_0-merror:0.00000	validation_1-merror:0.09811
# Stopping. Best iteration:
# [16]	validation_0-merror:0.00000	validation_1-merror:0.09057
#
# CPU times: user 1.26 s, sys: 31.7 ms, total: 1.29 s
# Wall time: 422 ms
# Accuracy: 90.94%
# [0]	validation_0-merror:0.01042	validation_1-merror:0.25096
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.20077
# [2]	validation_0-merror:0.00000	validation_1-merror:0.15444
# [3]	validation_0-merror:0.00000	validation_1-merror:0.13514
# [4]	validation_0-merror:0.00000	validation_1-merror:0.12741
# [5]	validation_0-merror:0.00000	validation_1-merror:0.08494
# [6]	validation_0-merror:0.00000	validation_1-merror:0.07336
# [7]	validation_0-merror:0.00000	validation_1-merror:0.08108
# [8]	validation_0-merror:0.00000	validation_1-merror:0.06564
# [9]	validation_0-merror:0.00000	validation_1-merror:0.06178
# [10]	validation_0-merror:0.00000	validation_1-merror:0.06178
# [11]	validation_0-merror:0.00000	validation_1-merror:0.05792
# [12]	validation_0-merror:0.00000	validation_1-merror:0.06564
# [13]	validation_0-merror:0.00000	validation_1-merror:0.06178
# [14]	validation_0-merror:0.00000	validation_1-merror:0.05405
# [15]	validation_0-merror:0.00000	validation_1-merror:0.05405
# [16]	validation_0-merror:0.00000	validation_1-merror:0.04633
# [17]	validation_0-merror:0.00000	validation_1-merror:0.04633
# [18]	validation_0-merror:0.00000	validation_1-merror:0.04633
# [19]	validation_0-merror:0.00000	validation_1-merror:0.04633
# [20]	validation_0-merror:0.00000	validation_1-merror:0.04633
# [21]	validation_0-merror:0.00000	validation_1-merror:0.04633
# [22]	validation_0-merror:0.00000	validation_1-merror:0.04633
# [23]	validation_0-merror:0.00000	validation_1-merror:0.04633
# [24]	validation_0-merror:0.00000	validation_1-merror:0.04247
# [25]	validation_0-merror:0.00000	validation_1-merror:0.04247
# [26]	validation_0-merror:0.00000	validation_1-merror:0.04247
# [27]	validation_0-merror:0.00000	validation_1-merror:0.04247
# [28]	validation_0-merror:0.00000	validation_1-merror:0.04247
# [29]	validation_0-merror:0.00000	validation_1-merror:0.04247
# [30]	validation_0-merror:0.00000	validation_1-merror:0.04247
# [31]	validation_0-merror:0.00000	validation_1-merror:0.04247
# [32]	validation_0-merror:0.00000	validation_1-merror:0.04247
# [33]	validation_0-merror:0.00000	validation_1-merror:0.04247
# [34]	validation_0-merror:0.00000	validation_1-merror:0.04247
# Stopping. Best iteration:
# [24]	validation_0-merror:0.00000	validation_1-merror:0.04247
#
# CPU times: user 1.53 s, sys: 55.6 ms, total: 1.58 s
# Wall time: 522 ms
# Accuracy: 95.75%
# [0]	validation_0-merror:0.01961	validation_1-merror:0.26877
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00980	validation_1-merror:0.22134
# [2]	validation_0-merror:0.00000	validation_1-merror:0.18577
# [3]	validation_0-merror:0.00000	validation_1-merror:0.20158
# [4]	validation_0-merror:0.00000	validation_1-merror:0.19763
# [5]	validation_0-merror:0.00000	validation_1-merror:0.16601
# [6]	validation_0-merror:0.00000	validation_1-merror:0.16996
# [7]	validation_0-merror:0.00000	validation_1-merror:0.15810
# [8]	validation_0-merror:0.00000	validation_1-merror:0.16996
# [9]	validation_0-merror:0.00000	validation_1-merror:0.15810
# [10]	validation_0-merror:0.00000	validation_1-merror:0.16601
# [11]	validation_0-merror:0.00000	validation_1-merror:0.15810
# [12]	validation_0-merror:0.00000	validation_1-merror:0.16206
# [13]	validation_0-merror:0.00000	validation_1-merror:0.15415
# [14]	validation_0-merror:0.00000	validation_1-merror:0.14625
# [15]	validation_0-merror:0.00000	validation_1-merror:0.14625
# [16]	validation_0-merror:0.00000	validation_1-merror:0.13834
# [17]	validation_0-merror:0.00000	validation_1-merror:0.14229
# [18]	validation_0-merror:0.00000	validation_1-merror:0.12648
# [19]	validation_0-merror:0.00000	validation_1-merror:0.12253
# [20]	validation_0-merror:0.00000	validation_1-merror:0.12253
# [21]	validation_0-merror:0.00000	validation_1-merror:0.12253
# [22]	validation_0-merror:0.00000	validation_1-merror:0.12253
# [23]	validation_0-merror:0.00000	validation_1-merror:0.12253
# [24]	validation_0-merror:0.00000	validation_1-merror:0.12253
# [25]	validation_0-merror:0.00000	validation_1-merror:0.11858
# [26]	validation_0-merror:0.00000	validation_1-merror:0.11858
# [27]	validation_0-merror:0.00000	validation_1-merror:0.11858
# [28]	validation_0-merror:0.00000	validation_1-merror:0.11858
# [29]	validation_0-merror:0.00000	validation_1-merror:0.11858
# [30]	validation_0-merror:0.00000	validation_1-merror:0.11858
# [31]	validation_0-merror:0.00000	validation_1-merror:0.11858
# [32]	validation_0-merror:0.00000	validation_1-merror:0.11858
# [33]	validation_0-merror:0.00000	validation_1-merror:0.11858
# [34]	validation_0-merror:0.00000	validation_1-merror:0.11858
# [35]	validation_0-merror:0.00000	validation_1-merror:0.11858
# Stopping. Best iteration:
# [25]	validation_0-merror:0.00000	validation_1-merror:0.11858
#
# CPU times: user 1.76 s, sys: 64 ms, total: 1.83 s
# Wall time: 599 ms
# Accuracy: 88.14%
# [0]	validation_0-merror:0.00926	validation_1-merror:0.21457
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0
# [25]	validation_0-merror:0.00000	validation_1-merror:0.04149
# [26]	validation_0-merror:0.00000	validation_1-merror:0.04149
# [27]	validation_0-merror:0.00000	validation_1-merror:0.04149
# [28]	validation_0-merror:0.00000	validation_1-merror:0.04149
# [29]	validation_0-merror:0.00000	validation_1-merror:0.04149
# [30]	validation_0-merror:0.00000	validation_1-merror:0.04149
# Stopping. Best iteration:
# [20]	validation_0-merror:0.00000	validation_1-merror:0.04149
#
# CPU times: user 1.43 s, sys: 35.6 ms, total: 1.47 s
# Wall time: 465 ms
# Accuracy: 95.85%
# [0]	validation_0-merror:0.02500	validation_1-merror:0.19149
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.01667	validation_1-merror:0.11489
# [2]	validation_0-merror:0.00833	validation_1-merror:0.08936
# [3]	validation_0-merror:0.00000	validation_1-merror:0.08085
# [4]	validation_0-merror:0.00000	validation_1-merror:0.08085
# [5]	validation_0-merror:0.00000	validation_1-merror:0.06809
# [6]	validation_0-merror:0.00000	validation_1-merror:0.05532
# [7]	validation_0-merror:0.00000	validation_1-merror:0.05106
# [8]	validation_0-merror:0.00000	validation_1-merror:0.03404
# [9]	validation_0-merror:0.00000	validation_1-merror:0.03830
# [10]	validation_0-merror:0.00000	validation_1-merror:0.04255
# [11]	validation_0-merror:0.00000	validation_1-merror:0.03830
# [12]	validation_0-merror:0.00000	validation_1-merror:0.03830
# [13]	validation_0-merror:0.00000	validation_1-merror:0.03830
# [14]	validation_0-merror:0.00000	validation_1-merror:0.04255
# [15]	validation_0-merror:0.00000	validation_1-merror:0.04255
# [16]	validation_0-merror:0.00000	validation_1-merror:0.04255
# [17]	validation_0-merror:0.00000	validation_1-merror:0.04255
# [18]	validation_0-merror:0.00000	validation_1-merror:0.04255
# Stopping. Best iteration:
# [8]	validation_0-merror:0.00000	validation_1-merror:0.03404
#
# CPU times: user 1.32 s, sys: 27.4 ms, total: 1.35 s
# Wall time: 438 ms
# Accuracy: 96.60%
# [0]	validation_0-merror:0.01587	validation_1-merror:0.20087
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.17031
# [2]	validation_0-merror:0.00000	validation_1-merror:0.13537
# [3]	validation_0-merror:0.00000	validation_1-merror:0.13974
# [4]	validation_0-merror:0.00000	validation_1-merror:0.14847
# [5]	validation_0-merror:0.00000	validation_1-merror:0.13974
# [6]	validation_0-merror:0.00000	validation_1-merror:0.14847
# [7]	validation_0-merror:0.00000	validation_1-merror:0.13974
# [8]	validation_0-merror:0.00000	validation_1-merror:0.14411
# [9]	validation_0-merror:0.00000	validation_1-merror:0.13974
# [10]	validation_0-merror:0.00000	validation_1-merror:0.13537
# [11]	validation_0-merror:0.00000	validation_1-merror:0.14411
# [12]	validation_0-merror:0.00000	validation_1-merror:0.13974
# Stopping. Best iteration:
# [2]	validation_0-merror:0.00000	validation_1-merror:0.13537
#
# CPU times: user 1.02 s, sys: 27.9 ms, total: 1.05 s
# Wall time: 329 ms
# Accuracy: 86.46%
# [0]	validation_0-merror:0.00000	validation_1-merror:0.11659
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.09417
# [2]	validation_0-merror:0.00000	validation_1-merror:0.08520
# [3]	validation_0-merror:0.00000	validation_1-merror:0.07175
# [4]	validation_0-merror:0.00000	validation_1-merror:0.06727
# [5]	validation_0-merror:0.00000	validation_1-merror:0.07623
# [6]	validation_0-merror:0.00000	validation_1-merror:0.07175
# [7]	validation_0-merror:0.00000	validation_1-merror:0.06278
# [8]	validation_0-merror:0.00000	validation_1-merror:0.06278
# [9]	validation_0-merror:0.00000	validation_1-merror:0.06278
# [10]	validation_0-merror:0.00000	validation_1-merror:0.05830
# [11]	validation_0-merror:0.00000	validation_1-merror:0.05381
# [12]	validation_0-merror:0.00000	validation_1-merror:0.05381
# [13]	validation_0-merror:0.00000	validation_1-merror:0.05381
# [14]	validation_0-merror:0.00000	validation_1-merror:0.05381
# [15]	validation_0-merror:0.00000	validation_1-merror:0.04933
# [16]	validation_0-merror:0.00000	validation_1-merror:0.04933
# [17]	validation_0-merror:0.00000	validation_1-merror:0.04933
# [18]	validation_0-merror:0.00000	validation_1-merror:0.04933
# [19]	validation_0-merror:0.00000	validation_1-merror:0.04933
# [20]	validation_0-merror:0.00000	validation_1-merror:0.04933
# [21]	validation_0-merror:0.00000	validation_1-merror:0.04933
# [22]	validation_0-merror:0.00000	validation_1-merror:0.04484
# [23]	validation_0-merror:0.00000	validation_1-merror:0.04484
# [24]	validation_0-merror:0.00000	validation_1-merror:0.04036
# [25]	validation_0-merror:0.00000	validation_1-merror:0.04484
# [26]	validation_0-merror:0.00000	validation_1-merror:0.04484
# [27]	validation_0-merror:0.00000	validation_1-merror:0.04484
# [28]	validation_0-merror:0.00000	validation_1-merror:0.04484
# [29]	validation_0-merror:0.00000	validation_1-merror:0.04036
# [30]	validation_0-merror:0.00000	validation_1-merror:0.04484
# [31]	validation_0-merror:0.00000	validation_1-merror:0.04484
# [32]	validation_0-merror:0.00000	validation_1-merror:0.04484
# [33]	validation_0-merror:0.00000	validation_1-merror:0.04484
# [34]	validation_0-merror:0.00000	validation_1-merror:0.04484
# Stopping. Best iteration:
# [24]	validation_0-merror:0.00000	validation_1-merror:0.04036
#
# CPU times: user 1.82 s, sys: 55.4 ms, total: 1.88 s
# Wall time: 596 ms
# Accuracy: 95.96%
# [0]	validation_0-merror:0.00000	validation_1-merror:0.23963
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.16590
# [2]	validation_0-merror:0.00000	validation_1-merror:0.13364
# [3]	validation_0-merror:0.00000	validation_1-merror:0.12442
# [4]	validation_0-merror:0.00000	validation_1-merror:0.13825
# [5]	validation_0-merror:0.00000	validation_1-merror:0.13825
# [6]	validation_0-merror:0.00000	validation_1-merror:0.14286
# [7]	validation_0-merror:0.00000	validation_1-merror:0.14747
# [8]	validation_0-merror:0.00000	validation_1-merror:0.14286
# [9]	validation_0-merror:0.00000	validation_1-merror:0.14286
# [10]	validation_0-merror:0.00000	validation_1-merror:0.12903
# [11]	validation_0-merror:0.00000	validation_1-merror:0.12903
# [12]	validation_0-merror:0.00000	validation_1-merror:0.12903
# [13]	validation_0-merror:0.00000	validation_1-merror:0.12442
# Stopping. Best iteration:
# [3]	validation_0-merror:0.00000	validation_1-merror:0.12442
#
# CPU times: user 946 ms, sys: 24 ms, total: 970 ms
# Wall time: 300 ms
# Accuracy: 87.56%
# [0]	validation_0-merror:0.02083	validation_1-merror:0.20853
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00694	validation_1-merror:0.13270
# [2]	validation_0-merror:0.00694	validation_1-merror:0.12796
# [3]	validation_0-merror:0.00000	validation_1-merror:0.11374
# [4]	validation_0-merror:0.00000	validation_1-merror:0.10901
# [5]	validation_0-merror:0.00000	validation_1-merror:0.11374
# [6]	validation_0-merror:0.00000	validation_1-merror:0.10901
# [7]	validation_0-merror:0.00000	validation_1-merror:0.09953
# [8]	validation_0-merror:0.00000	validation_1-merror:0.09479
# [9]	validation_0-merror:0.00000	validation_1-merror:0.09479
# [10]	validation_0-merror:0.00000	validation_1-merror:0.09005
# [11]	validation_0-merror:0.00000	validation_1-merror:0.09005
# [12]	validation_0-merror:0.00000	validation_1-merror:0.09005
# [13]	validation_0-merror:0.00000	validation_1-merror:0.09005
# [14]	validation_0-merror:0.00000	validation_1-merror:0.08531
# [15]	validation_0-merror:0.00000	validation_1-merror:0.08057
# [16]	validation_0-merror:0.00000	validation_1-merror:0.07583
# [17]	validation_0-merror:0.00000	validation_1-merror:0.07583
# [18]	validation_0-merror:0.00000	validation_1-merror:0.07583
# [19]	validation_0-merror:0.00000	validation_1-merror:0.07583
# [20]	validation_0-merror:0.00000	validation_1-merror:0.08531
# [21]	validation_0-merror:0.00000	validation_1-merror:0.07583
# [22]	validation_0-merror:0.00000	validation_1-merror:0.08057
# [23]	validation_0-merror:0.00000	validation_1-merror:0.08057
# [24]	validation_0-merror:0.00000	validation_1-merror:0.08057
# [25]	validation_0-merror:0.00000	validation_1-merror:0.08057
# [26]	validation_0-merror:0.00000	validation_1-merror:0.08057
# Stopping. Best iteration:
# [16]	validation_0-merror:0.00000	validation_1-merror:0.07583
#
# CPU times: user 1.56 s, sys: 55.6 ms, total: 1.62 s
# Wall time: 521 ms
# Accuracy: 92.42%
# [0]	validation_0-merror:0.02667	validation_1-merror:0.14146
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.10244
# [2]	validation_0-merror:0.00000	validation_1-merror:0.09268
# [3]	validation_0-merror:0.00000	validation_1-merror:0.06829
# [4]	validation_0-merror:0.00000	validation_1-merror:0.04878
# [5]	validation_0-merror:0.00000	validation_1-merror:0.04878
# [6]	validation_0-merror:0.00000	validation_1-merror:0.03902
# [7]	validation_0-merror:0.00000	validation_1-merror:0.02927
# [8]	validation_0-merror:0.00000	validation_1-merror:0.02439
# [9]	validation_0-merror:0.00000	validation_1-merror:0.01951
# [10]	validation_0-merror:0.00000	validation_1-merror:0.01463
# [11]	validation_0-merror:0.00000	validation_1-merror:0.01951
# [12]	validation_0-merror:0.00000	validation_1-merror:0.02439
# [13]	validation_0-merror:0.00000	validation_1-merror:0.01951
# [14]	validation_0-merror:0.00000	validation_1-merror:0.01951
# [15]	validation_0-merror:0.00000	validation_1-merror:0.00976
# [16]	validation_0-merror:0.00000	validation_1-merror:0.00976
# [17]	validation_0-merror:0.00000	validation_1-merror:0.01463
# [18]	validation_0-merror:0.00000	validation_1-merror:0.00976
# [19]	validation_0-merror:0.00000	validation_1-merror:0.01463
# [20]	validation_0-merror:0.00000	validation_1-merror:0.01463
# [21]	validation_0-merror:0.00000	validation_1-merror:0.01463
# [22]	validation_0-merror:0.00000	validation_1-merror:0.01463
# [23]	validation_0-merror:0.00000	validation_1-merror:0.01951
# [24]	validation_0-merror:0.00000	validation_1-merror:0.01951
# [25]	validation_0-merror:0.00000	validation_1-merror:0.01951
# Stopping. Best iteration:
# [15]	validation_0-merror:0.00000	validation_1-merror:0.00976
#
# CPU times: user 1.8 s, sys: 72.1 ms, total: 1.87 s
# Wall time: 621 ms
# Accuracy: 99.02%
# [0]	validation_0-merror:0.01923	validation_1-merror:0.21608
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.16080
# [2]	validation_0-merror:0.00000	validation_1-merror:0.12563
# [3]	validation_0-merror:0.00000	validation_1-merror:0.09548
# ...
# [2]	validation_0-merror:0.00000	validation_1-merror:0.09202
# [3]	validation_0-merror:0.00000	validation_1-merror:0.11043
# [4]	validation_0-merror:0.00000	validation_1-merror:0.10429
# [5]	validation_0-merror:0.00000	validation_1-merror:0.12270
# [6]	validation_0-merror:0.00000	validation_1-merror:0.09202
# [7]	validation_0-merror:0.00000	validation_1-merror:0.07976
# [8]	validation_0-merror:0.00000	validation_1-merror:0.07976
# [9]	validation_0-merror:0.00000	validation_1-merror:0.07362
# [10]	validation_0-merror:0.00000	validation_1-merror:0.06135
# [11]	validation_0-merror:0.00000	validation_1-merror:0.06135
# [12]	validation_0-merror:0.00000	validation_1-merror:0.05522
# [13]	validation_0-merror:0.00000	validation_1-merror:0.04908
# [14]	validation_0-merror:0.00000	validation_1-merror:0.04294
# [15]	validation_0-merror:0.00000	validation_1-merror:0.04294
# [16]	validation_0-merror:0.00000	validation_1-merror:0.03681
# [17]	validation_0-merror:0.00000	validation_1-merror:0.03068
# [18]	validation_0-merror:0.00000	validation_1-merror:0.03068
# [19]	validation_0-merror:0.00000	validation_1-merror:0.03681
# [20]	validation_0-merror:0.00000	validation_1-merror:0.03068
# [21]	validation_0-merror:0.00000	validation_1-merror:0.03068
# [22]	validation_0-merror:0.00000	validation_1-merror:0.03068
# [23]	validation_0-merror:0.00000	validation_1-merror:0.03068
# [24]	validation_0-merror:0.00000	validation_1-merror:0.03068
# [25]	validation_0-merror:0.00000	validation_1-merror:0.03068
# [26]	validation_0-merror:0.00000	validation_1-merror:0.03068
# [27]	validation_0-merror:0.00000	validation_1-merror:0.03068
# Stopping. Best iteration:
# [17]	validation_0-merror:0.00000	validation_1-merror:0.03068
#
# CPU times: user 2.06 s, sys: 60.2 ms, total: 2.12 s
# Wall time: 681 ms
# Accuracy: 96.93%
# [0]	validation_0-merror:0.01515	validation_1-merror:0.13376
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0
# [17]	validation_0-merror:0.00000	validation_1-merror:0.04138
# [18]	validation_0-merror:0.00000	validation_1-merror:0.04138
# [19]	validation_0-merror:0.00000	validation_1-merror:0.04138
# [20]	validation_0-merror:0.00000	validation_1-merror:0.03448
# [21]	validation_0-merror:0.00000	validation_1-merror:0.03448
# [22]	validation_0-merror:0.00000	validation_1-merror:0.03448
# [23]	validation_0-merror:0.00000	validation_1-merror:0.04138
# [24]	validation_0-merror:0.00000	validation_1-merror:0.03448
# [25]	validation_0-merror:0.00000	validation_1-merror:0.03448
# [26]	validation_0-merror:0.00000	validation_1-merror:0.02759
# [27]	validation_0-merror:0.00000	validation_1-merror:0.02759
# [28]	validation_0-merror:0.00000	validation_1-merror:0.02759
# [29]	validation_0-merror:0.00000	validation_1-merror:0.02759
# [30]	validation_0-merror:0.00000	validation_1-merror:0.02759
# [31]	validation_0-merror:0.00000	validation_1-merror:0.02759
# [32]	validation_0-merror:0.00000	validation_1-merror:0.02759
# [33]	validation_0-merror:0.00000	validation_1-merror:0.02759
# [34]	validation_0-merror:0.00000	validation_1-merror:0.02759
# [35]	validation_0-merror:0.00000	validation_1-merror:0.02759
# [36]	validation_0-merror:0.00000	validation_1-merror:0.02759
# Stopping. Best iteration:
# [26]	validation_0-merror:0.00000	validation_1-merror:0.02759
#
# CPU times: user 2.28 s, sys: 43.9 ms, total: 2.32 s
# Wall time: 717 ms
# Accuracy: 97.24%
# [0]	validation_0-merror:0.00000	validation_1-merror:0.14389
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.10791
# [2]	validation_0-merror:0.00000	validation_1-merror:0.08633
# [3]	validation_0-merror:0.00000	validation_1-merror:0.07194
# [4]	validation_0-merror:0.00000	validation_1-merror:0.07194
# [5]	validation_0-merror:0.00000	validation_1-merror:0.07194
# [6]	validation_0-merror:0.00000	validation_1-merror:0.07194
# [7]	validation_0-merror:0.00000	validation_1-merror:0.07194
# [8]	validation_0-merror:0.00000	validation_1-merror:0.06475
# [9]	validation_0-merror:0.00000	validation_1-merror:0.05755
# [10]	validation_0-merror:0.00000	validation_1-merror:0.05036
# [11]	validation_0-merror:0.00000	validation_1-merror:0.04317
# [12]	validation_0-merror:0.00000	validation_1-merror:0.04317
# [13]	validation_0-merror:0.00000	validation_1-merror:0.04317
# [14]	validation_0-merror:0.00000	validation_1-merror:0.04317
# [15]	validation_0-merror:0.00000	validation_1-merror:0.04317
# [16]	validation_0-merror:0.00000	validation_1-merror:0.04317
# [17]	validation_0-merror:0.00000	validation_1-merror:0.03597
# [18]	validation_0-merror:0.00000	validation_1-merror:0.03597
# [19]	validation_0-merror:0.00000	validation_1-merror:0.03597
# [20]	validation_0-merror:0.00000	validation_1-merror:0.02878
# [21]	validation_0-merror:0.00000	validation_1-merror:0.02878
# [22]	validation_0-merror:0.00000	validation_1-merror:0.02878
# [23]	validation_0-merror:0.00000	validation_1-merror:0.02878
# [24]	validation_0-merror:0.00000	validation_1-merror:0.02878
# [25]	validation_0-merror:0.00000	validation_1-merror:0.02878
# [26]	validation_0-merror:0.00000	validation_1-merror:0.02878
# [27]	validation_0-merror:0.00000	validation_1-merror:0.02878
# [28]	validation_0-merror:0.00000	validation_1-merror:0.02878
# [29]	validation_0-merror:0.00000	validation_1-merror:0.02878
# [30]	validation_0-merror:0.00000	validation_1-merror:0.02878
# Stopping. Best iteration:
# [20]	validation_0-merror:0.00000	validation_1-merror:0.02878
#
# CPU times: user 2.45 s, sys: 71.8 ms, total: 2.52 s
# Wall time: 794 ms
# Accuracy: 97.12%
# [0]	validation_0-merror:0.00901	validation_1-merror:0.09023
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.06015
# [2]	validation_0-merror:0.00000	validation_1-merror:0.05263
# [3]	validation_0-merror:0.00000	validation_1-merror:0.05263
# [4]	validation_0-merror:0.00000	validation_1-merror:0.05263
# [5]	validation_0-merror:0.00000	validation_1-merror:0.05263
# [6]	validation_0-merror:0.00000	validation_1-merror:0.05263
# [7]	validation_0-merror:0.00000	validation_1-merror:0.04511
# [8]	validation_0-merror:0.00000	validation_1-merror:0.04511
# [9]	validation_0-merror:0.00000	validation_1-merror:0.04511
# [10]	validation_0-merror:0.00000	validation_1-merror:0.04511
# [11]	validation_0-merror:0.00000	validation_1-merror:0.03759
# [12]	validation_0-merror:0.00000	validation_1-merror:0.03759
# [13]	validation_0-merror:0.00000	validation_1-merror:0.03759
# [14]	validation_0-merror:0.00000	validation_1-merror:0.03759
# [15]	validation_0-merror:0.00000	validation_1-merror:0.03759
# [16]	validation_0-merror:0.00000	validation_1-merror:0.03759
# [17]	validation_0-merror:0.00000	validation_1-merror:0.03759
# [18]	validation_0-merror:0.00000	validation_1-merror:0.03759
# [19]	validation_0-merror:0.00000	validation_1-merror:0.03759
# [20]	validation_0-merror:0.00000	validation_1-merror:0.03759
# [21]	validation_0-merror:0.00000	validation_1-merror:0.03759
# Stopping. Best iteration:
# [11]	validation_0-merror:0.00000	validation_1-merror:0.03759
#
# CPU times: user 2.01 s, sys: 60.6 ms, total: 2.08 s
# Wall time: 708 ms
# Accuracy: 96.24%
# [0]	validation_0-merror:0.00439	validation_1-merror:0.13386
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00439	validation_1-merror:0.09449
# [2]	validation_0-merror:0.00439	validation_1-merror:0.08661
# [3]	validation_0-merror:0.00000	validation_1-merror:0.08661
# [4]	validation_0-merror:0.00000	validation_1-merror:0.07874
# [5]	validation_0-merror:0.00000	validation_1-merror:0.05512
# [6]	validation_0-merror:0.00000	validation_1-merror:0.05512
# [7]	validation_0-merror:0.00000	validation_1-merror:0.05512
# [8]	validation_0-merror:0.00000	validation_1-merror:0.04724
# [9]	validation_0-merror:0.00000	validation_1-merror:0.04724
# [10]	validation_0-merror:0.00000	validation_1-merror:0.04724
# [11]	validation_0-merror:0.00000	validation_1-merror:0.04724
# [12]	validation_0-merror:0.00000	validation_1-merror:0.04724
# [13]	validation_0-merror:0.00000	validation_1-merror:0.04724
# [14]	validation_0-merror:0.00000	validation_1-merror:0.04724
# [15]	validation_0-merror:0.00000	validation_1-merror:0.04724
# [16]	validation_0-merror:0.00000	validation_1-merror:0.04724
# [17]	validation_0-merror:0.00000	validation_1-merror:0.04724
# [18]	validation_0-merror:0.00000	validation_1-merror:0.04724
# Stopping. Best iteration:
# [8]	validation_0-merror:0.00000	validation_1-merror:0.04724
#
# CPU times: user 2.57 s, sys: 64 ms, total: 2.63 s
# Wall time: 892 ms
# Accuracy: 95.28%
# [0]	validation_0-merror:0.00855	validation_1-merror:0.10744
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00427	validation_1-merror:0.06612
# [2]	validation_0-merror:0.00427	validation_1-merror:0.09091
# [3]	validation_0-merror:0.00427	validation_1-merror:0.07438
# [4]	validation_0-merror:0.00000	validation_1-merror:0.08264
# [5]	validation_0-merror:0.00000	validation_1-merror:0.07438
# [6]	validation_0-merror:0.00000	validation_1-merror:0.07438
# [7]	validation_0-merror:0.00000	validation_1-merror:0.06612
# [8]	validation_0-merror:0.00000	validation_1-merror:0.05785
# [9]	validation_0-merror:0.00000	validation_1-merror:0.05785
# [10]	validation_0-merror:0.00000	validation_1-merror:0.04959
# [11]	validation_0-merror:0.00000	validation_1-merror:0.04959
# [12]	validation_0-merror:0.00000	validation_1-merror:0.04959
# [13]	validation_0-merror:0.00000	validation_1-merror:0.03306
# [14]	validation_0-merror:0.00000	validation_1-merror:0.04132
# [15]	validation_0-merror:0.00000	validation_1-merror:0.04132
# [16]	validation_0-merror:0.00000	validation_1-merror:0.04132
# [17]	validation_0-merror:0.00000	validation_1-merror:0.04132
# [18]	validation_0-merror:0.00000	validation_1-merror:0.04132
# [19]	validation_0-merror:0.00000	validation_1-merror:0.04132
# [20]	validation_0-merror:0.00000	validation_1-merror:0.04132
# [21]	validation_0-merror:0.00000	validation_1-merror:0.03306
# [22]	validation_0-merror:0.00000	validation_1-merror:0.03306
# [23]	validation_0-merror:0.00000	validation_1-merror:0.03306
# Stopping. Best iteration:
# [13]	validation_0-merror:0.00000	validation_1-merror:0.03306
#
# CPU times: user 2.08 s, sys: 31.9 ms, total: 2.11 s
# Wall time: 640 ms
# Accuracy: 96.69%
# [0]	validation_0-merror:0.00417	validation_1-merror:0.10435
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.00000	validation_1-merror:0.08696
# [2]	validation_0-merror:0.00000	validation_1-merror:0.07826
# [3]	validation_0-merror:0.00000	validation_1-merror:0.06957
# [4]	validation_0-merror:0.00000	validation_1-merror:0.06957
# [5]	validation_0-merror:0.00000	validation_1-merror:0.06087
# [6]	validation_0-merror:0.00000	validation_1-merror:0.06087
# [7]	validation_0-merror:0.00000	validation_1-merror:0.04348
# [8]	validation_0-merror:0.00000	validation_1-merror:0.03478
# [9]	validation_0-merror:0.00000	validation_1-merror:0.02609
# [10]	validation_0-merror:0.00000	validation_1-merror:0.01739
# [11]	validation_0-merror:0.00000	validation_1-merror:0.01739
# [12]	validation_0-merror:0.00000	validation_1-merror:0.00870
# [13]	validation_0-merror:0.00000	validation_1-merror:0.00870
# [14]	validation_0-merror:0.00000	validation_1-merror:0.00870
# [15]	validation_0-merror:0.00000	validation_1-merror:0.00870
# [16]	validation_0-merror:0.00000	validation_1-merror:0.00870
# [17]	validation_0-merror:0.00000	validation_1-merror:0.00870
# [18]	validation_0-merror:0.00000	validation_1-merror:0.00870
# [19]	validation_0-merror:0.00000	validation_1-merror:0.00870
# [20]	validation_0-merror:0.00000	validation_1-merror:0.00870
# [21]	validation_0-merror:0.00000	validation_1-merror:0.00870
# [22]	validation_0-merror:0.00000	validation_1-merror:0.00870
# Stopping. Best iteration:
# [12]	validation_0-merror:0.00000	validation_1-merror:0.00870
#
# CPU times: user 2.01 s, sys: 39.8 ms, total: 2.05 s
# Wall time: 610 ms
# Accuracy: 99.13%

# %%
plt.figure(figsize=(12,8))
plt.plot(all_accuracy[0])
# plt.axvline(7, c='black', alpha=0.5)

plt.title("Accuracy depending on the number of samples for XG Boost algorithm")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df_results = pd.DataFrame({
    
    'Nb Classes':[6], 

    'mean XG Boost':[np.mean(all_accuracy[0])], 
    'max XG Boost':[
        max(all_accuracy[0])]
    })

df_results
# Out:
#    Nb Classes  mean XG Boost  max XG Boost
# 0           6       0.859905      0.991304

# %%
all_accuracy_xgb = {num:[] for num in range(2, len(df.Class.unique()) + 1)}

# %%
for num_samples in range(1, 40):

    for num_cl in range(2, len(df.Class.unique()) + 1):

        all_accuracy_xgb[num_cl].append(return_score_xgb(num_samples,num_cl, df))

# %%
plt.figure(figsize=(12,8))
plt.plot(all_accuracy_xgb[2], label="2 classes")
plt.plot(all_accuracy_xgb[3], label="3 classes")
plt.plot(all_accuracy_xgb[4], label="4 classes")
plt.plot(all_accuracy_xgb[5], label="5 classes")
plt.plot(all_accuracy_xgb[6], label="6 classes")
plt.axvline(7, c='black', alpha=0.5)

plt.title("Accuracy depending on the number of classes for XG Boost algorithm")
plt.legend()
plt.show()
plt.savefig('accuracy_plot.jpg')

# %% [markdown]
# ## Summary

# %%
df_results = pd.DataFrame({
    
    'Nb Classes':[2, 3, 4, 5, 6], 

    'mean XG Boost':[np.mean(all_accuracy_xgb[2]), 
        np.mean(all_accuracy_xgb[3]), 
        np.mean(all_accuracy_xgb[4]), 
        np.mean(all_accuracy_xgb[5]),
        np.mean(all_accuracy_xgb[6])],
    'max XG Boost':[max(all_accuracy_xgb[2]), 
        max(all_accuracy_xgb[3]), 
        max(all_accuracy_xgb[4]), 
        max(all_accuracy_xgb[5]),
        max(all_accuracy_xgb[6])]
    })

# %%
df_results
# Out:
#    Nb Classes  mean XG Boost  max XG Boost
# 0           2       0.357257      0.459459
# 1           3       0.545866      0.650000
# 2           4       0.674852      0.814978
# 3           5       0.608261      0.713208
# 4           6       0.865999      0.991736

# %% [markdown]
# ## Testing on incoming email

# %%
le = joblib.load('./pkl_objects/labelencoder.pkl')
clf = joblib.load('./pkl_objects/clf.pkl')

# %%
def inp(emailto, emailfrom, subj, bod):
    text = subj + " " + bod
    text = get_only_chars(text)
    X_test_mean = np.array([transform_sentence(text, embeddings_index)])

    y_pred = clf.predict(X_test_mean)
    print(y_pred)

    return le.inverse_transform(y_pred)

# %%
print(inp("fvf", "defrfg", "payment processed", "hi, the payment for acc 1234 for usd 3456 was paid successfully."))
# Out:
# [0]
# ['Complete']

# %%
print(inp("cfdfv", "derftrg", "Partially paid the required amount for transaction", "There has been only a partial payment of amount 1234"))
# Out:
# [3]
# ['Pending']
