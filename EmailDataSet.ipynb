# %%
#Email generation code

# %%
import pandas as pd
import numpy as np
import import_ipynb

# %%
import msgbody
from msgbody import numgen, transacBank,transacClient , subClient, subBank
# Out:
# importing Jupyter notebook from msgbody.ipynb

# %%
From1=['@JPMorgan.com','@DEUTSCHEBANK.com','@BNYMellon.com','@HSBC.com','@SBI.com','@HDFC.com','@DESHAW.com']

From2=['@CitiBankNewYork.com','@CitiBankLondon.com','@CitiBankPune.com','@CitiBankSingapore.com','@CitiBankHingKong.com']

To1=['@JPMorgan.com','@DEUTSCHEBANK.com','@BNYMellon.com','@HSBC.com','@SBI.com','@HDFC.com','@DESHAW.com']

To2=['@CitiBankNewYork.com','@CitiBankLondon.com','@CitiBankPune.com','@CitiBankSingapore.com','@CitiBankHingKong.com']

Subject2=['Update on payment request', 'Payment Status', 'Urrgent: need transaction details','Transaction Complete','Transaction is in progress','Payment Failed','Payment is in progress','Waiting for amount pending','Transaction Failed','Payment Received']

name1=['Phillip','Mike','Jason','Adam','Morgan','Spike','Stacy','Dave','David','Bella','Angella','Stefeny']
name2=['Shai','Dipesh','Anthony','Isabella','Shanguisi','liFang','AjayNager','Sumit','Suhail','Shubhanshu']
currency = ['USD','GBP','CAD','EUR','INR','YEN']

# %%
import random
from random import randint

# %%
###Whenever you need to join a digit put->  ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+   part in there

# %%
##BELOW IS THE CODE FOR A NUMBER IN SUBJECT AND BODY and Original Dataset generator

# %%
data2=[[]]

# %%
#final code for dataset generation form Bank side
for i in range(len(name1)):
            for j in range(len(name2)):
                for k in range(10):
                    temp=numgen(6)
                    s1=random.choice(name1)+random.choice(From1)
                    s2=random.choice(name2)+random.choice(To2)
                    s3=subBank(temp)
                    s4=""
                    s5=""
                    words = s3.split()
                    for word in words:
                        word=word.lower()
                        if(word=='failed'):
                            s4=transacBank(3,temp)
                            s5='BankFailed'
                            break
                        elif(word=='pending' or word=='progress'):
                            s4=transacBank(2,temp)
                            s5='BankProgress'
                            break
                        elif(word=='complete' or word=='received'):
                            s4=transacBank(1,temp)
                            s5='BankComplete'
                            break
                        elif(word=='status' or word=='details' or word=='update'):
                            k=numgen(1)
                            if(k<'4'):
                                s4=transacBank(1,temp)
                                s5='BankComplete'
                            elif(k>'3' and k<'7'):
                                s4=transacBank(2,temp)
                                s5='BankProgress'
                            elif(k>'6'):
                                s4=transacBank(3,temp)
                                s5='BankFailed'
                            break
                        elif words=='provide' or word=='request':
                            s4=transacBank(4,temp)
                            s5='BankRequest'
                            break
                    
                    m=[s1,s2,s3,s4,s5,temp]
                    data2.append(m)

# %%
#final code for dataset generation form Client side
for i in range(len(From1)):
            for j in range(len(To2)):
                for k in range(11):
                    temp=numgen(6)
                    s1=random.choice(name1)+random.choice(To1)
                    s2=random.choice(name2)+random.choice(From2)
                    s3=subClient(temp)
                    s4=""
                    s5=""
                    words = s3.split()
                    for word in words:
                        word=word.lower()
                        if(word=='failed' or word=='failure'):
                            s4=transacClient(3,temp)
                            s5='ClientFailed'
                            break
                        elif(word=='pending' or word=='progress'):
                            s4=transacClient(2,temp)
                            s5='ClientProgress'
                            break
                        elif(word=='complete' or word=='received'):
                            s4=transacClient(1,temp)
                            s5='ClientComplete'
                            break
                        elif(word=='status' or word=='details' or word=='update' or word=='provide' or word=='request'):
                            s4=transacClient(4,temp)
                            s5='ClientStatus'
                            break
                    m=[s1,s2,s3,s4,s5,temp]
                    data2.append(m)

# %%
df = pd.DataFrame(data2, columns = ['From', 'To','Subject','Body','Class','TransactionID'])

# %%
df.head(20)
# Out:
#                       From                               To  \
# 0                     None                             None
# 1         Bella@DESHAW.com       AjayNager@CitiBankPune.com
# 2    Mike@DEUTSCHEBANK.com      liFang@CitiBankHingKong.com
# 3         Phillip@HDFC.com         Sumit@CitiBankLondon.com
# 4         Jason@DESHAW.com     Isabella@CitiBankNewYork.com
# 5         Angella@HDFC.com       liFang@CitiBankNewYork.com
# 6          Mike@DESHAW.com        Suhail@CitiBankLondon.com
# 7             Dave@SBI.com      Dipesh@CitiBankHingKong.com
# 8         Spike@DESHAW.com    Shubhanshu@CitiBankLondon.com
# 9         Phillip@HDFC.com       Sumit@CitiBankHingKong.com
# 10      Spike@JPMorgan.com         Anthony@CitiBankPune.com
# 11  Jason@DEUTSCHEBANK.com      Sumit@CitiBankSingapore.com
# 12      Bella@JPMorgan.com        Dipesh@CitiBankLondon.com
# 13      Adam@BNYMellon.com  AjayNager@CitiBankSingapore.com
# 14  David@DEUTSCHEBANK.com  Shubhanshu@CitiBankHingKong.com
# 15        Angella@HSBC.com       Sumit@CitiBankHingKong.com
# 16           Adam@HDFC.com       liFang@CitiBankNewYork.com
# 17        Stacy@DESHAW.com    Shanguisi@CitiBankNewYork.com
# 18            Mike@SBI.com    Shanguisi@CitiBankNewYork.com
# 19        Angella@HDFC.com  Shanguisi@CitiBankSingapore.com
#
#                                               Subject  \
# 0                                                None
# 1                           Payment Failed for 782376
# 2               Transaction is in progress for 428375
# 3                Current Update on Account No. 331537
# 4                           Payment Status for 387225
# 5   Urgent payment of pending amountUSD553541requi...
# 6                           Payment Failed for 492153
# 7                                   Acc 243458 Update
# 8   Provide the details regarding transaction: 148152
# 9   Urgent payment of pending amountEUR324534requi...
# 10  Urgent payment of pending amountUSD196712requi...
# 11  Urgent payment of pending amountGBP597933requi...
# 12                                  Acc 259736 Update
# 13                                  Acc 683566 Update
# 14              Transaction is in progress for 488664
# 15  Urgent payment of pending amountCAD421391requi...
# 16                    Transaction Complete for 281947
# 17  Provide the details regarding transaction: 438135
# 18              Transaction is in progress for 114979
# 19               Current Update on Account No. 747714
#
#                                                  Body         Class  \
# 0                                                None          None
# 1   Regret to inform that transaction GBP 761135co...    BankFailed
# 2   Fund transfer for Account No. 428375 has stopp...  BankProgress
# 3   Due to incorrect details filled, USD 937458 ha...    BankFailed
# 4   Due to lack of funds, cheque no. 4819199844312...    BankFailed
# 5   We are sorry but your fund transfer 553541 is ...  BankProgress
# 6   Due to incorrect details filled, EUR 945963 ha...    BankFailed
# 7   Due to lack of funds, cheque no. 8919779943892...    BankFailed
# 8   Greetings! This is to inform you that your tra...  BankComplete
# 9   Fund transfer for Account No. 324534 has stopp...  BankProgress
# 10  Hey, We got your query regarding details of ac...  BankProgress
# 11   Payment 597933 will be completed within two days  BankProgress
# 12       USD 328723 completed successfully, congrats!  BankComplete
# 13       USD 323145 completed successfully, congrats!  BankComplete
# 14  We are sorry but your fund transfer 488664 is ...  BankProgress
# 15  Due to server overflow transaction 421391 will...  BankProgress
# 16       EUR 413166 completed successfully, congrats!  BankComplete
# 17  The transaction of amount USD 415398 has been ...  BankComplete
# 18  Sorry, due to high volume of requests, your tr...  BankProgress
# 19  The transaction for amount EUR 863856 related ...  BankComplete
#
#    TransactionID
# 0           None
# 1         782376
# 2         428375
# 3         331537
# 4         387225
# 5         553541
# 6         492153
# 7         243458
# 8         148152
# 9         324534
# 10        196712
# 11        597933
# 12        259736
# 13        683566
# 14        488664
# 15        421391
# 16        281947
# 17        438135
# 18        114979
# 19        747714

# %%
import datetime

# %%
start_date = datetime.date(2018, 12, 1)
end_date = datetime.date(2020, 5, 31)

time_between_dates = end_date - start_date
days_between_dates = time_between_dates.days
date_column_data = [start_date + datetime.timedelta(days=random.randrange(days_between_dates)) for i in range(len(data2))]
#print(date_column_data)

# %%
df['Payment Date'] = date_column_data

# %%
df.head(10)
# Out:
#                     From                             To  \
# 0                   None                           None
# 1       Bella@DESHAW.com     AjayNager@CitiBankPune.com
# 2  Mike@DEUTSCHEBANK.com    liFang@CitiBankHingKong.com
# 3       Phillip@HDFC.com       Sumit@CitiBankLondon.com
# 4       Jason@DESHAW.com   Isabella@CitiBankNewYork.com
# 5       Angella@HDFC.com     liFang@CitiBankNewYork.com
# 6        Mike@DESHAW.com      Suhail@CitiBankLondon.com
# 7           Dave@SBI.com    Dipesh@CitiBankHingKong.com
# 8       Spike@DESHAW.com  Shubhanshu@CitiBankLondon.com
# 9       Phillip@HDFC.com     Sumit@CitiBankHingKong.com
#
#                                              Subject  \
# 0                                               None
# 1                          Payment Failed for 782376
# 2              Transaction is in progress for 428375
# 3               Current Update on Account No. 331537
# 4                          Payment Status for 387225
# 5  Urgent payment of pending amountUSD553541requi...
# 6                          Payment Failed for 492153
# 7                                  Acc 243458 Update
# 8  Provide the details regarding transaction: 148152
# 9  Urgent payment of pending amountEUR324534requi...
#
#                                                 Body         Class  \
# 0                                               None          None
# 1  Regret to inform that transaction GBP 761135co...    BankFailed
# 2  Fund transfer for Account No. 428375 has stopp...  BankProgress
# 3  Due to incorrect details filled, USD 937458 ha...    BankFailed
# 4  Due to lack of funds, cheque no. 4819199844312...    BankFailed
# 5  We are sorry but your fund transfer 553541 is ...  BankProgress
# 6  Due to incorrect details filled, EUR 945963 ha...    BankFailed
# 7  Due to lack of funds, cheque no. 8919779943892...    BankFailed
# 8  Greetings! This is to inform you that your tra...  BankComplete
# 9  Fund transfer for Account No. 324534 has stopp...  BankProgress
#
#   TransactionID Payment Date
# 0          None   2019-01-07
# 1        782376   2019-05-14
# 2        428375   2020-05-11
# 3        331537   2019-03-26
# 4        387225   2020-02-12
# 5        553541   2019-08-17
# 6        492153   2020-01-28
# 7        243458   2020-02-03
# 8        148152   2019-02-27
# 9        324534   2019-12-14

# %%
df.drop(0,inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index                   From                            To  \
# 0      1       Bella@DESHAW.com    AjayNager@CitiBankPune.com
# 1      2  Mike@DEUTSCHEBANK.com   liFang@CitiBankHingKong.com
# 2      3       Phillip@HDFC.com      Sumit@CitiBankLondon.com
# 3      4       Jason@DESHAW.com  Isabella@CitiBankNewYork.com
# 4      5       Angella@HDFC.com    liFang@CitiBankNewYork.com
#
#                                              Subject  \
# 0                          Payment Failed for 782376
# 1              Transaction is in progress for 428375
# 2               Current Update on Account No. 331537
# 3                          Payment Status for 387225
# 4  Urgent payment of pending amountUSD553541requi...
#
#                                                 Body         Class  \
# 0  Regret to inform that transaction GBP 761135co...    BankFailed
# 1  Fund transfer for Account No. 428375 has stopp...  BankProgress
# 2  Due to incorrect details filled, USD 937458 ha...    BankFailed
# 3  Due to lack of funds, cheque no. 4819199844312...    BankFailed
# 4  We are sorry but your fund transfer 553541 is ...  BankProgress
#
#   TransactionID Payment Date
# 0        782376   2019-05-14
# 1        428375   2020-05-11
# 2        331537   2019-03-26
# 3        387225   2020-02-12
# 4        553541   2019-08-17

# %%
df.drop(["index"],axis=1,inplace=True)

# %%
df.shape
# Out:
# (1585, 7)

# %%
#This the DataSet we Have generated
df.head()
# Out:
#                     From                            To  \
# 0       Bella@DESHAW.com    AjayNager@CitiBankPune.com
# 1  Mike@DEUTSCHEBANK.com   liFang@CitiBankHingKong.com
# 2       Phillip@HDFC.com      Sumit@CitiBankLondon.com
# 3       Jason@DESHAW.com  Isabella@CitiBankNewYork.com
# 4       Angella@HDFC.com    liFang@CitiBankNewYork.com
#
#                                              Subject  \
# 0                          Payment Failed for 782376
# 1              Transaction is in progress for 428375
# 2               Current Update on Account No. 331537
# 3                          Payment Status for 387225
# 4  Urgent payment of pending amountUSD553541requi...
#
#                                                 Body         Class  \
# 0  Regret to inform that transaction GBP 761135co...    BankFailed
# 1  Fund transfer for Account No. 428375 has stopp...  BankProgress
# 2  Due to incorrect details filled, USD 937458 ha...    BankFailed
# 3  Due to lack of funds, cheque no. 4819199844312...    BankFailed
# 4  We are sorry but your fund transfer 553541 is ...  BankProgress
#
#   TransactionID Payment Date
# 0        782376   2019-05-14
# 1        428375   2020-05-11
# 2        331537   2019-03-26
# 3        387225   2020-02-12
# 4        553541   2019-08-17

# %%
df.to_csv(r'C:\Users\Siddharth\Desktop\temp\emaildataset.csv', index = False)
