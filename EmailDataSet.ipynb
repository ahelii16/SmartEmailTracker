# %%
import pandas as pd
import numpy as np

# %%
From1=['@JPMorgan.com','@DEUTSCHEBANK.com','@BNYMellon.com','@HSBC.com','@CitiBankNewYork.com','@CitiBankLondon.com']

To2=['@CitiBankNewYork.com','@CitiBankLondon.com','@CitiBankPune.com','@CitiBankSingapore.com','@CitiBankHingKong.com']

Subject2=['Update on payment request', 'Payment Status', 'Urrgent: need transaction details','Transaction Complete','Transaction is in progress','Payment Failed','Payment is in progress','Waiting for amount pending','Transaction Failed','Payment Received']

name1=['Phillip','Mike','Jason','Adam','Morgan','Spike','Stacy']
name2=['Shai','Dipesh','Anthony','Isabella']
currency = ['USD','GBP','CAD','EUR']

# %%
data1=[[]]

# %%
import random
from random import randint

# %%
transacC=['The transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' related to investment funds has been successfully completed.',
'The transaction ' +''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' have been received.',
'Full payment for update ' +''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' is successfully received.']

transacP=['The transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' is taking too long to be completed',
'Fund transfer for ACC No. ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has partially stopped due to unknown technical error. We regret the inconvenience.',
'Due to server overflow transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' will be completed within seven to ten working days',
'Payment ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' will be completed within two days']

transacF=['Due to an unknown technical error, your transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' have been cancelled.',
'Payment ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' have been cancelled as per your request.',
'Lack of funds, check no. ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 24)]) + ' has been bounced.']

transacR=[
    'Kindly provide the details for Acc no.'+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ ' at the earliest',
    'Please find the details of your account '+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ ' attached',
    'We have received your request and will be sending you the details of acc '+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ 'soon.'
]

# %%
for i in range(len(From1)):
            for j in range(len(To2)):
                for k in range(len(Subject2)):
                    s1=random.choice(name1)+random.choice(From1)
                    s2=random.choice(name2)+random.choice(To2)
                    s3=random.choice(Subject2)
                    s4=""
                    s5=""
                    words = s3.split()
                    if(words[-1]=='Failed'):
                        s4=transac(3,temp)
                        s5='A'
                    elif(words[-1]=='pending' or words[-1]=='progress' or words[-1]=='Update' or words[-1]==temp):
                        s4=transac(2,temp)
                        s5='B'
                    elif(words[-1]=='Complete' or words[-1]=='Received'):
                        s4=transac(1,temp)
                        s5='C'
                    elif(words[-1]=='Status' or words[-1]=='request' or words[-1]=='details'):
                        s4=transac(4,temp)
                        s5='D'
                    m=[s1,s2,s3,s4,s5]
                    data1.append(m)

# %%
df1 = pd.DataFrame(data1, columns = ['From', 'To','Subject','Body','Class(output)'])

# %%
df1.head(100)
# Out:
#                           From                              To  \
# 0                         None                            None
# 86      Spike@DEUTSCHEBANK.com        Anthony@CitiBankPune.com
# 87     Mike@CitiBankLondon.com     Dipesh@CitiBankHingKong.com
# 88         Spike@BNYMellon.com       Shai@CitiBankHingKong.com
# 89     Adam@CitiBankLondon.com       Shai@CitiBankHingKong.com
# 90      Stacy@DEUTSCHEBANK.com       Shai@CitiBankHingKong.com
# 91          Adam@BNYMellon.com    Dipesh@CitiBankSingapore.com
# 92               Mike@HSBC.com    Dipesh@CitiBankSingapore.com
# 93    Jason@CitiBankLondon.com     Isabella@CitiBankLondon.com
# 94    Stacy@CitiBankLondon.com       Shai@CitiBankHingKong.com
# 95          Adam@BNYMellon.com        Anthony@CitiBankPune.com
# 96            Phillip@HSBC.com     Dipesh@CitiBankHingKong.com
# 97             Morgan@HSBC.com     Isabella@CitiBankLondon.com
# 98   Stacy@CitiBankNewYork.com      Shai@CitiBankSingapore.com
# 99           Mike@JPMorgan.com    Anthony@CitiBankHingKong.com
#
#                               Subject  \
# 0                                None
# 1              Payment is in progress
# 2                      Payment Status
# 3                      Payment Failed
# 4                Transaction Complete
# 5                    Payment Received
# 6          Waiting for amount pending
# 7                      Payment Status
# 8          Waiting for amount pending
# 9                      Payment Status
# 10                 Transaction Failed
# 11         Transaction is in progress
# 12                 Transaction Failed
# 13  Urrgent: need transaction details
# 14                     Payment Status
# 15                   Payment Received
# 16               Transaction Complete
# 17          Update on payment request
# 18                     Payment Status
# 19                 Transaction Failed
# 20         Transaction is in progress
# 21         Waiting for amount pending
# 22                     Payment Status
# 23  Urrgent: need transaction details
# 24               Transaction Complete
# 25               Transaction Complete
# 26          Update on payment request
# 27         Waiting for amount pending
# 28          Update on payment request
# 29          Update on payment request
# ..                                ...
# 70         Waiting for amount pending
# 71          Update on payment request
# 72                     Payment Failed
# 73         Transaction is in progress
# 74               Transaction Complete
# 75               Transaction Complete
# 76         Waiting for amount pending
# 77             Payment is in progress
# 78             Payment is in progress
# 79                 Transaction Failed
# 80         Waiting for amount pending
# 81          Update on payment request
# 82  Urrgent: need transaction details
# 83                   Payment Received
# 84                     Payment Failed
# 85                     Payment Failed
# 86  Urrgent: need transaction details
# 87         Waiting for amount pending
# 88                 Transaction Failed
# 89             Payment is in progress
# 90               Transaction Complete
# 91               Transaction Complete
# 92                     Payment Status
# 93         Waiting for amount pending
# 94                     Payment Failed
# 95               Transaction Complete
# 96               Transaction Complete
# 97                   Payment Received
# 98                   Payment Received
# 99                     Payment Status
#
#                                                  Body Class(output)
# 0                                                None          None
# 1    Payment 821476 will be completed within two days             B
# 2   We have received your request and will be send...             D
# 3   Due to unknown technical errors, your transact...             A
# 4   The transaction for amount GBP762213 related t...             C
# 5   Full payment for amount EUR391238 has been suc...             C
# 6   The transaction 374871 is taking too long to b...             B
# 7   Please find the details of your account 457946...             D
# 8   Fund transfer for ACC No. 358126 has partially...             B
# 9   Kindly provide the details for Acc no.913982 a...             D
# 10  Due to lack of funds, cheque no. 1894816634536...             A
# 11  Fund transfer for ACC No. 812823 has partially...             B
# 12  Payment of USD295283 has been cancelled as per...             A
# 13  Kindly provide the details for Acc no.142524 a...             D
# 14  Please find the details of your account 633827...             D
# 15  The transaction of amount CAD367583 has been r...             C
# 16  The transaction for amount USD858286 related t...             C
# 17  Kindly provide the details for Acc no.748197 a...             D
# 18  Kindly provide the details for Acc no.661393 a...             D
# 19  Due to unknown technical errors, your transact...             A
# 20   Payment 897658 will be completed within two days             B
# 21   Payment 824614 will be completed within two days             B
# 22  We have received your request and will be send...             D
# 23  We have received your request and will be send...             D
# 24  Full payment for amount CAD554976 has been suc...             C
# 25  Full payment for amount USD834316 has been suc...             C
# 26  We have received your request and will be send...             D
# 27  Fund transfer for ACC No. 274226 has partially...             B
# 28  Please find the details of your account 434477...             D
# 29  We have received your request and will be send...             D
# ..                                                ...           ...
# 70  Due to server overflow transaction 358556 will...             B
# 71  We have received your request and will be send...             D
# 72  Payment of USD975369 has been cancelled as per...             A
# 73   Payment 958571 will be completed within two days             B
# 74  Full payment for amount EUR758697 has been suc...             C
# 75  The transaction for amount USD255193 related t...             C
# 76   Payment 711223 will be completed within two days             B
# 77  Due to server overflow transaction 411611 will...             B
# 78  Fund transfer for ACC No. 547476 has partially...             B
# 79  Due to lack of funds, cheque no. 7729999788599...             A
# 80  The transaction 767897 is taking too long to b...             B
# 81  We have received your request and will be send...             D
# 82  Please find the details of your account 958961...             D
# 83  The transaction of amount CAD952968 has been r...             C
# 84  Due to unknown technical errors, your transact...             A
# 85  Payment of USD665499 has been cancelled as per...             A
# 86  Kindly provide the details for Acc no.424564 a...             D
# 87  Fund transfer for ACC No. 329941 has partially...             B
# 88  Due to unknown technical errors, your transact...             A
# 89  Due to server overflow transaction 252585 will...             B
# 90  Full payment for amount GBP881786 has been suc...             C
# 91  The transaction of amount CAD963914 has been r...             C
# 92  We have received your request and will be send...             D
# 93  Fund transfer for ACC No. 678528 has partially...             B
# 94  Due to lack of funds, cheque no. 4549937353248...             A
# 95  The transaction of amount USD591683 has been r...             C
# 96  Full payment for amount USD368152 has been suc...             C
# 97  Full payment for amount USD194845 has been suc...             C
# 98  The transaction for amount USD262758 related t...             C
# 99  Kindly provide the details for Acc no.338912 a...             D
#
# [100 rows x 5 columns]

# %%
#Whenever you need to join a digit put->  ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ ' sdjvbksd')  part in there

# %%
#BELOW IS THE CODE FOR A NUMBER IN SUBJECT AND BODY

# %%
def numbergen(n):
    return ''.join(["{}".format(randint(1, 9)) for num in range(0, n)])

# %%
def sub(s):
    subject=[' Acc ' + s + ' Update','Payment in Progress Acc ' + s,'Update on Acc '+ s,'Update on payment request for' + s ,'Payment Status for ' + s,'Urgent : need transaction details for ' + s,'Transaction Complete for ' + s,'Transaction is in progress for ' + s,'Payment Failed for ' + s,'Payment is in progress for ' + s,'Waiting for amount pending for '+ s,'Transaction Failed for' + s,'Payment Received for' + s]
    return random.choice(subject)

# %%
def transac(n,s):
    
    transacC=['The transaction for amount ' + random.choice(currency)+ ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' related to investment funds has been successfully completed.',
    'The transaction of amount ' +random.choice(currency)+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has been received successfully.',
    'Full payment for amount ' +random.choice(currency)+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has been successfully received.']

    transacP=['The transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' is taking too long to be completed',
    'Fund transfer for ACC No. ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has partially stopped due to unknown technical error. We regret the inconvenience.',
    'Due to server overflow transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' will be completed within seven to ten working days',
    'Payment ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' will be completed within two days']

    transacF=['Due to unknown technical errors, your transaction for amount' + random.choice(currency)+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has been cancelled.',
    'Payment of ' + random.choice(currency)+ ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has been cancelled as per your request.',
    'Due to lack of funds, cheque no. ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 24)]) + ' has bounced. Kindly ensure that you have enough funds and then submit a new cheque at the earliest.']

    transacR=['Kindly provide the details for Acc no.'+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ ' at the earliest',
    'Please find the details of your account '+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ ' attached',
    'We have received your request and will be sending you the details of acc '+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ 'soon.']
    if(n==1):
        return random.choice(transacC)
    elif n==2:
        return random.choice(transacP)
    elif n==3:
        return random.choice(transacF)
    elif n==4:
        return random.choice(transacR)

# %%
data2=[[]]

# %%
for i in range(len(From1)):
            for j in range(len(To2)):
                for k in range(len(Subject2)):
                    temp=''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])
                    s1=random.choice(name1)+random.choice(From1)
                    s2=random.choice(name2)+random.choice(To2)
                    s3=sub(temp)
                    s4=""
                    s5=""
                    words = s3.split()
                    for word in words:
                        word=word.lower()
                        if(word=='failed'):
                            s4=transac(3,temp)
                            s5='A'
                        elif(word=='pending' or word=='progress' or word=='update'):
                            s4=transac(2,temp)
                            s5='B'
                        elif(word=='complete' or word=='received'):
                            s4=transac(1,temp)
                            s5='C'
                        elif(word=='status' or word=='request' or word=='details'):
                            s4=transac(4,temp)
                            s5='D'
                    m=[s1,s2,s3,s4,s5]
                    data2.append(m)

# %%
df = pd.DataFrame(data2, columns = ['From', 'To','Subject','Body','Class(output)'])

# %%
df.head(20)
# Out:
#                          From                              To  \
# 0                        None                            None
# 1          Spike@JPMorgan.com        Anthony@CitiBankPune.com
# 2     Adam@CitiBankLondon.com       Shai@CitiBankHingKong.com
# 3              Stacy@HSBC.com       Shai@CitiBankHingKong.com
# 4          Adam@BNYMellon.com       Isabella@CitiBankPune.com
# 5   Spike@CitiBankNewYork.com      Shai@CitiBankSingapore.com
# 6   Stacy@CitiBankNewYork.com     Anthony@CitiBankNewYork.com
# 7          Mike@BNYMellon.com         Shai@CitiBankLondon.com
# 8      Jason@DEUTSCHEBANK.com       Shai@CitiBankHingKong.com
# 9         Morgan@JPMorgan.com     Anthony@CitiBankNewYork.com
# 10   Spike@CitiBankLondon.com   Isabella@CitiBankHingKong.com
# 11  Morgan@CitiBankLondon.com         Shai@CitiBankLondon.com
# 12      Mike@DEUTSCHEBANK.com         Shai@CitiBankLondon.com
# 13            Morgan@HSBC.com      Shai@CitiBankSingapore.com
# 14   Mike@CitiBankNewYork.com    Anthony@CitiBankHingKong.com
# 15  Stacy@CitiBankNewYork.com     Dipesh@CitiBankHingKong.com
# 16        Morgan@JPMorgan.com  Isabella@CitiBankSingapore.com
# 17   Spike@CitiBankLondon.com       Shai@CitiBankHingKong.com
# 18         Mike@BNYMellon.com     Dipesh@CitiBankHingKong.com
# 19  Morgan@CitiBankLondon.com   Anthony@CitiBankSingapore.com
#
#                                          Subject  \
# 0                                           None
# 1                     Payment Received for599587
# 2                   Transaction Failed for298195
# 3              Payment is in progress for 391874
# 4                     Payment Received for261685
# 5                              Acc 745639 Update
# 6   Urgent : need transaction details for 493685
# 7                      Payment Failed for 891873
# 8                           Update on Acc 128993
# 9   Urgent : need transaction details for 629611
# 10           Update on payment request for349737
# 11         Waiting for amount pending for 243645
# 12                          Update on Acc 925148
# 13         Waiting for amount pending for 918266
# 14                  Transaction Failed for428878
# 15             Payment is in progress for 872525
# 16                Payment in Progress Acc 889452
# 17             Payment is in progress for 528324
# 18             Payment is in progress for 683366
# 19                Payment in Progress Acc 237372
#
#                                                  Body Class(output)
# 0                                                None          None
# 1   Full payment for amount CAD281814 has been suc...             C
# 2   Due to unknown technical errors, your transact...             A
# 3   Fund transfer for ACC No. 411679 has partially...             B
# 4   The transaction of amount CAD798192 has been r...             C
# 5   The transaction 261522 is taking too long to b...             B
# 6   Please find the details of your account 517858...             D
# 7   Due to unknown technical errors, your transact...             A
# 8    Payment 492712 will be completed within two days             B
# 9   Kindly provide the details for Acc no.243358 a...             D
# 10  We have received your request and will be send...             D
# 11   Payment 929435 will be completed within two days             B
# 12  Fund transfer for ACC No. 567488 has partially...             B
# 13  The transaction 666759 is taking too long to b...             B
# 14  Due to lack of funds, cheque no. 8865981712688...             A
# 15  Due to server overflow transaction 583399 will...             B
# 16  Fund transfer for ACC No. 774214 has partially...             B
# 17  Due to server overflow transaction 365727 will...             B
# 18  The transaction 724187 is taking too long to b...             B
# 19  Due to server overflow transaction 713658 will...             B

# %%
import datetime

# %%
start_date = datetime.date(2018, 12, 1)
end_date = datetime.date(2020, 5, 31)

time_between_dates = end_date - start_date
days_between_dates = time_between_dates.days
date_column_data = [start_date + datetime.timedelta(days=random.randrange(days_between_dates)) for i in range(len(data2))]
#print(date_column_data)

# %%
df['Payment Date'] = date_column_data

# %%
df.head(100)
# Out:
#                            From                              To  \
# 0                          None                            None
# 1            Spike@JPMorgan.com        Anthony@CitiBankPune.com
# 2       Adam@CitiBankLondon.com       Shai@CitiBankHingKong.com
# 3                Stacy@HSBC.com       Shai@CitiBankHingKong.com
# 4            Adam@BNYMellon.com       Isabella@CitiBankPune.com
# 5     Spike@CitiBankNewYork.com      Shai@CitiBankSingapore.com
# 6     Stacy@CitiBankNewYork.com     Anthony@CitiBankNewYork.com
# 7            Mike@BNYMellon.com         Shai@CitiBankLondon.com
# 8        Jason@DEUTSCHEBANK.com       Shai@CitiBankHingKong.com
# 9           Morgan@JPMorgan.com     Anthony@CitiBankNewYork.com
# 10     Spike@CitiBankLondon.com   Isabella@CitiBankHingKong.com
# 96          Jason@BNYMellon.com  Isabella@CitiBankSingapore.com
# 97     Adam@CitiBankNewYork.com         Dipesh@CitiBankPune.com
# 98           Spike@JPMorgan.com        Shai@CitiBankNewYork.com
# 99           Spike@JPMorgan.com        Anthony@CitiBankPune.com
#
#                                          Subject  \
# 0                                           None
# 1                     Payment Received for599587
# 2                   Transaction Failed for298195
# 3              Payment is in progress for 391874
# 4                     Payment Received for261685
# 5                              Acc 745639 Update
# 6   Urgent : need transaction details for 493685
# 7                      Payment Failed for 891873
# 8                           Update on Acc 128993
# 9   Urgent : need transaction details for 629611
# 10           Update on payment request for349737
# 11         Waiting for amount pending for 243645
# 12                          Update on Acc 925148
# 13         Waiting for amount pending for 918266
# 14                  Transaction Failed for428878
# 15             Payment is in progress for 872525
# 16                Payment in Progress Acc 889452
# 17             Payment is in progress for 528324
# 18             Payment is in progress for 683366
# 19                Payment in Progress Acc 237372
# 20                Payment in Progress Acc 843689
# 21  Urgent : need transaction details for 225736
# 22                Payment in Progress Acc 994535
# 23                Payment in Progress Acc 561377
# 24                     Payment Status for 731312
# 25  Urgent : need transaction details for 522152
# 26         Waiting for amount pending for 863477
# 27                             Acc 991879 Update
# 28                Payment in Progress Acc 965367
# 29         Waiting for amount pending for 522154
# ..                                           ...
# 70                             Acc 145286 Update
# 71                     Payment Failed for 278186
# 72                    Payment Received for521723
# 73  Urgent : need transaction details for 118778
# 74                     Payment Status for 293793
# 75           Update on payment request for145446
# 76                          Update on Acc 832468
# 77                     Payment Status for 679376
# 78             Payment is in progress for 675254
# 79                             Acc 327215 Update
# 80                          Update on Acc 962662
# 81                Payment in Progress Acc 662953
# 82             Payment is in progress for 459271
# 83         Transaction is in progress for 486552
# 84                     Payment Status for 729342
# 85         Transaction is in progress for 611179
# 86           Update on payment request for111645
# 87                     Payment Status for 229817
# 88  Urgent : need transaction details for 897534
# 89                          Update on Acc 613271
# 90  Urgent : need transaction details for 567941
# 91                     Payment Status for 798277
# 92         Transaction is in progress for 188869
# 93           Update on payment request for129875
# 94                          Update on Acc 828979
# 95                          Update on Acc 263396
# 96                    Payment Received for496187
# 97         Transaction is in progress for 675871
# 98                     Payment Failed for 235189
# 99               Transaction Complete for 145892
#
#                                                  Body Class(output)  \
# 0                                                None          None
# 1   Full payment for amount CAD281814 has been suc...             C
# 2   Due to unknown technical errors, your transact...             A
# 3   Fund transfer for ACC No. 411679 has partially...             B
# 4   The transaction of amount CAD798192 has been r...             C
# 5   The transaction 261522 is taking too long to b...             B
# 6   Please find the details of your account 517858...             D
# 7   Due to unknown technical errors, your transact...             A
# 8    Payment 492712 will be completed within two days             B
# 9   Kindly provide the details for Acc no.243358 a...             D
# 10  We have received your request and will be send...             D
# 11   Payment 929435 will be completed within two days             B
# 12  Fund transfer for ACC No. 567488 has partially...             B
# 13  The transaction 666759 is taking too long to b...             B
# 14  Due to lack of funds, cheque no. 8865981712688...             A
# 15  Due to server overflow transaction 583399 will...             B
# 16  Fund transfer for ACC No. 774214 has partially...             B
# 17  Due to server overflow transaction 365727 will...             B
# 18  The transaction 724187 is taking too long to b...             B
# 19  Due to server overflow transaction 713658 will...             B
# 20   Payment 993638 will be completed within two days             B
# 21  We have received your request and will be send...             D
# 22  Fund transfer for ACC No. 137616 has partially...             B
# 23  The transaction 954696 is taking too long to b...             B
# 24  Kindly provide the details for Acc no.749588 a...             D
# 25  We have received your request and will be send...             D
# 26  Due to server overflow transaction 167773 will...             B
# 27  Fund transfer for ACC No. 565821 has partially...             B
# 28  The transaction 355548 is taking too long to b...             B
# 29  Due to server overflow transaction 835225 will...             B
# ..                                                ...           ...
# 70  The transaction 278543 is taking too long to b...             B
# 71  Due to lack of funds, cheque no. 2647181649737...             A
# 72  The transaction of amount GBP458988 has been r...             C
# 73  Please find the details of your account 234238...             D
# 74  Please find the details of your account 445999...             D
# 75  Kindly provide the details for Acc no.178973 a...             D
# 76  Due to server overflow transaction 437794 will...             B
# 77  Kindly provide the details for Acc no.495251 a...             D
# 78   Payment 634171 will be completed within two days             B
# 79  Due to server overflow transaction 331793 will...             B
# 80   Payment 576613 will be completed within two days             B
# 81  Due to server overflow transaction 633784 will...             B
# 82  Due to server overflow transaction 619167 will...             B
# 83  Fund transfer for ACC No. 493319 has partially...             B
# 84  We have received your request and will be send...             D
# 85  Fund transfer for ACC No. 695621 has partially...             B
# 86  We have received your request and will be send...             D
# 87  Kindly provide the details for Acc no.164739 a...             D
# 88  Please find the details of your account 366771...             D
# 89   Payment 216934 will be completed within two days             B
# 90  Please find the details of your account 397876...             D
# 91  Please find the details of your account 972278...             D
# 92  Due to server overflow transaction 283919 will...             B
# 93  We have received your request and will be send...             D
# 94  Fund transfer for ACC No. 792838 has partially...             B
# 95   Payment 569536 will be completed within two days             B
# 96  Full payment for amount EUR757328 has been suc...             C
# 97  Fund transfer for ACC No. 423729 has partially...             B
# 98  Due to unknown technical errors, your transact...             A
# 99  The transaction for amount GBP487352 related t...             C
#
#    Payment Date
# 0    2019-02-18
# 1    2019-09-09
# 2    2019-12-22
# 3    2020-02-14
# 4    2018-12-28
# 5    2020-05-23
# 6    2019-01-25
# 7    2020-05-07
# 8    2020-05-10
# 9    2019-01-26
# 10   2019-04-27
# 11   2019-03-22
# 12   2019-08-26
# 13   2019-11-19
# 14   2020-03-29
# 15   2019-12-19
# 16   2020-02-07
# 17   2019-12-21
# 18   2019-09-16
# 19   2019-02-24
# 20   2019-11-14
# 21   2020-03-14
# 22   2019-02-24
# 23   2019-04-08
# 24   2020-02-18
# 25   2020-02-06
# 26   2018-12-20
# 27   2020-04-05
# 28   2019-08-18
# 29   2019-03-30
# ..          ...
# 70   2019-08-06
# 71   2020-05-10
# 72   2020-04-05
# 73   2019-01-06
# 74   2020-03-22
# 75   2019-03-25
# 76   2019-08-14
# 77   2019-02-04
# 78   2020-02-24
# 79   2020-02-04
# 80   2020-05-29
# 81   2020-03-11
# 82   2019-09-15
# 83   2020-05-06
# 84   2019-10-06
# 85   2019-01-12
# 86   2019-07-23
# 87   2019-05-21
# 88   2019-04-10
# 89   2020-03-03
# 90   2019-05-14
# 91   2018-12-03
# 92   2019-02-08
# 93   2019-03-02
# 94   2020-01-27
# 95   2019-12-08
# 96   2019-03-18
# 97   2019-12-15
# 98   2019-10-08
# 99   2019-10-06
#
# [100 rows x 6 columns]

# %%
df.to_csv(r'emaildataset.csv', index = False)
