# %%
import pandas as pd
import numpy as np

# %%
From1=['@JPMorgan.com','@DEUTSCHEBANK.com','@BNYMellon.com','@HSBC.com','@CitiBankNewYork.com','@CitiBankLondon.com']

To2=['@CitiBankNewYork.com','@CitiBankLondon.com','@CitiBankPune.com','@CitiBankSingapore.com','@CitiBankHingKong.com']

Subject2=['Update on payment request', 'Payment Status', 'Urgent: need transaction details','Transaction Complete','Transaction is in progress','Payment Failed','Payment is in progress','Waiting for amount pending','Transaction Failed','Payment Received']

name1=['Phillip','Mike','Jason','Adam','Morgan','Spike','Stacy']
name2=['Shai','Dipesh','Anthony','Isabella']
currency = ['USD','GBP','CAD','EUR']

# %%
data1=[[]]

# %%
import random
from random import randint

# %%
transacC=['The transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' related to investment funds has been successfully completed.',
'The transaction ' +''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' have been received.',
'Full payment for update ' +''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' is successfully received.']

transacP=['The transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' is taking too long to be completed',
'Fund transfer for ACC No. ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has partially stopped due to unknown technical error. We regret the inconvenience.',
'Due to server overflow transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' will be completed within seven to ten working days',
'Payment ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' will be completed within two days']

transacF=['Due to an unknown technical error, your transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' have been cancelled.',
'Payment ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' have been cancelled as per your request.',
'Lack of funds, check no. ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 24)]) + ' has been bounced.']

transacR=[
    'Kindly provide the details for Acc no.'+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ ' at the earliest',
    'Please find the details of your account '+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ ' attached',
    'We have received your request and will be sending you the details of acc '+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ 'soon.'
]

# %%
for i in range(len(From1)):
            for j in range(len(To2)):
                for k in range(len(Subject2)):
                    s1=random.choice(name1)+random.choice(From1)
                    s2=random.choice(name2)+random.choice(To2)
                    s3=random.choice(Subject2)
                    s4=""
                    s5=""
                    words = s3.split()
                    if(words[-1]=='Failed'):
                        s4=random.choice(transacF)
                        s5='A'
                    elif(words[-1]=='pending' or words[-1]=='progress'):
                        s4=random.choice(transacP)
                        s5='B'
                    elif(words[-1]=='Complete' or words[-1]=='Received'):
                        s4=random.choice(transacC)
                        s5='C'
                    elif(words[-1]=='Status' or words[-1]=='request' or words[-1]=='details'):
                        s4=random.choice(transacR)
                        s5='D'
                    m=[s1,s2,s3,s4,s5]
                    data1.append(m)

# %%
df1 = pd.DataFrame(data1, columns = ['From', 'To','Subject','Body','Class(output)'])

# %%
df1.head(100)
# Out:
#                            From                              To  \
# 0                          None                            None
# 86    Spike@CitiBankNewYork.com       Shai@CitiBankHingKong.com
# 87   Morgan@CitiBankNewYork.com        Anthony@CitiBankPune.com
# 88          Stacy@BNYMellon.com      Dipesh@CitiBankNewYork.com
# 89           Spike@JPMorgan.com       Shai@CitiBankHingKong.com
# 90         Phillip@JPMorgan.com     Dipesh@CitiBankHingKong.com
# 91             Phillip@HSBC.com      Shai@CitiBankSingapore.com
# 92          Spike@BNYMellon.com  Isabella@CitiBankSingapore.com
# 93              Morgan@HSBC.com     Isabella@CitiBankLondon.com
# 94         Morgan@BNYMellon.com       Isabella@CitiBankPune.com
# 95     Adam@CitiBankNewYork.com      Shai@CitiBankSingapore.com
# 96                Adam@HSBC.com         Shai@CitiBankLondon.com
# 97               Stacy@HSBC.com     Dipesh@CitiBankHingKong.com
# 98      Morgan@DEUTSCHEBANK.com     Anthony@CitiBankNewYork.com
# 99     Stacy@CitiBankLondon.com         Dipesh@CitiBankPune.com
#
#                              Subject  \
# 0                               None
# 1                   Payment Received
# 2                 Transaction Failed
# 3               Transaction Complete
# 4         Waiting for amount pending
# 5                     Payment Failed
# 6                     Payment Status
# 7                     Payment Status
# 8                   Payment Received
# 9               Transaction Complete
# 10         Update on payment request
# 11                Transaction Failed
# 12                Transaction Failed
# 13              Transaction Complete
# 14            Payment is in progress
# 15                    Payment Status
# 16         Update on payment request
# 17                Transaction Failed
# 18              Transaction Complete
# 19                    Payment Status
# 20                  Payment Received
# 21        Transaction is in progress
# 22  Urgent: need transaction details
# 23                Transaction Failed
# 24                Transaction Failed
# 25              Transaction Complete
# 26              Transaction Complete
# 27                    Payment Failed
# 28         Update on payment request
# 29                    Payment Failed
# ..                               ...
# 70                    Payment Status
# 71                    Payment Status
# 72                    Payment Status
# 73                    Payment Status
# 74        Transaction is in progress
# 75                Transaction Failed
# 76            Payment is in progress
# 77        Transaction is in progress
# 78  Urgent: need transaction details
# 79         Update on payment request
# 80                  Payment Received
# 81                Transaction Failed
# 82                    Payment Status
# 83            Payment is in progress
# 84            Payment is in progress
# 85         Update on payment request
# 86                    Payment Status
# 87                    Payment Failed
# 88        Transaction is in progress
# 89                    Payment Failed
# 90         Update on payment request
# 91         Update on payment request
# 92                    Payment Status
# 93                    Payment Status
# 94        Transaction is in progress
# 95              Transaction Complete
# 96         Update on payment request
# 97  Urgent: need transaction details
# 98                  Payment Received
# 99                  Payment Received
#
#                                                  Body Class(output)
# 0                                                None          None
# 1          The transaction 594853 have been received.             C
# 2   Due to an unknown technical error, your transa...             A
# 3          The transaction 594853 have been received.             C
# 4   Due to server overflow transaction 815545 will...             B
# 5   Due to an unknown technical error, your transa...             A
# 6   We have received your request and will be send...             D
# 7   Please find the details of your account 396246...             D
# 8   The transaction 926191 related to investment f...             C
# 9   Full payment for update 616218 is successfully...             C
# 10  Kindly provide the details for Acc no.594288 a...             D
# 11  Lack of funds, check no. 812824712929491822397...             A
# 12  Lack of funds, check no. 812824712929491822397...             A
# 13  Full payment for update 616218 is successfully...             C
# 14  Due to server overflow transaction 815545 will...             B
# 15  Kindly provide the details for Acc no.594288 a...             D
# 16  Please find the details of your account 396246...             D
# 17  Lack of funds, check no. 812824712929491822397...             A
# 18         The transaction 594853 have been received.             C
# 19  Kindly provide the details for Acc no.594288 a...             D
# 20         The transaction 594853 have been received.             C
# 21   Payment 263712 will be completed within two days             B
# 22  Please find the details of your account 396246...             D
# 23  Payment 194133 have been cancelled as per your...             A
# 24  Lack of funds, check no. 812824712929491822397...             A
# 25  The transaction 926191 related to investment f...             C
# 26         The transaction 594853 have been received.             C
# 27  Due to an unknown technical error, your transa...             A
# 28  Kindly provide the details for Acc no.594288 a...             D
# 29  Payment 194133 have been cancelled as per your...             A
# ..                                                ...           ...
# 70  We have received your request and will be send...             D
# 71  We have received your request and will be send...             D
# 72  Kindly provide the details for Acc no.594288 a...             D
# 73  We have received your request and will be send...             D
# 74  The transaction 131813 is taking too long to b...             B
# 75  Payment 194133 have been cancelled as per your...             A
# 76  Fund transfer for ACC No. 658579 has partially...             B
# 77  The transaction 131813 is taking too long to b...             B
# 78  Please find the details of your account 396246...             D
# 79  Kindly provide the details for Acc no.594288 a...             D
# 80         The transaction 594853 have been received.             C
# 81  Due to an unknown technical error, your transa...             A
# 82  Please find the details of your account 396246...             D
# 83  The transaction 131813 is taking too long to b...             B
# 84  Fund transfer for ACC No. 658579 has partially...             B
# 85  Kindly provide the details for Acc no.594288 a...             D
# 86  Please find the details of your account 396246...             D
# 87  Lack of funds, check no. 812824712929491822397...             A
# 88  Fund transfer for ACC No. 658579 has partially...             B
# 89  Lack of funds, check no. 812824712929491822397...             A
# 90  Kindly provide the details for Acc no.594288 a...             D
# 91  We have received your request and will be send...             D
# 92  Please find the details of your account 396246...             D
# 93  Kindly provide the details for Acc no.594288 a...             D
# 94  Due to server overflow transaction 815545 will...             B
# 95  Full payment for update 616218 is successfully...             C
# 96  Kindly provide the details for Acc no.594288 a...             D
# 97  Please find the details of your account 396246...             D
# 98         The transaction 594853 have been received.             C
# 99  The transaction 926191 related to investment f...             C
#
# [100 rows x 5 columns]

# %%
#Whenever you need to join a digit put->  ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ ' sdjvbksd')  part in there

# %%
#BELOW IS THE CODE FOR A NUMBER IN SUBJECT AND BODY

# %%
def numbergen(n):
    return ''.join(["{}".format(randint(1, 9)) for num in range(0, n)])

# %%
def sub(s):
    subject=[' Acc ' + s + ' Update','Payment in Progress Acc ' + s,'Update on Acc '+ s,'Update on payment request for' + s ,'Payment Status for ' + s,'Urgent : need transaction details for ' + s,'Transaction Complete for ' + s,'Transaction is in progress for ' + s,'Payment Failed for ' + s,'Payment is in progress for ' + s,'Waiting for amount pending for '+ s,'Transaction Failed for' + s,'Payment Received for' + s]
    return random.choice(subject)

# %%
def transac(n,s):
    
    transacC=['The transaction for amount ' + random.choice(currency)+ ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' related to investment funds has been successfully completed.',
    'The transaction of amount ' +random.choice(currency)+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has been received successfully.',
    'Full payment for amount ' +random.choice(currency)+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has been successfully received.']

    transacP=['The transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' is taking too long to be completed',
    'Fund transfer for ACC No. ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has partially stopped due to unknown technical error. We regret the inconvenience.',
    'Due to server overflow transaction ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' will be completed within seven to ten working days',
    'Payment ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' will be completed within two days']

    transacF=['Due to unknown technical errors, your transaction for amount' + random.choice(currency)+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has been cancelled.',
    'Payment of ' + random.choice(currency)+ ''.join(["{}".format(randint(1, 9)) for num in range(0, 6)]) + ' has been cancelled as per your request.',
    'Due to lack of funds, cheque no. ' + ''.join(["{}".format(randint(1, 9)) for num in range(0, 24)]) + ' has bounced. Kindly ensure that you have enough funds and then submit a new cheque at the earliest.']

    transacR=['Kindly provide the details for Acc no.'+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ ' at the earliest',
    'Please find the details of your account '+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ ' attached',
    'We have received your request and will be sending you the details of acc '+''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])+ 'soon.']
    if(n==1):
        return random.choice(transacC)
    elif n==2:
        return random.choice(transacP)
    elif n==3:
        return random.choice(transacF)
    elif n==4:
        return random.choice(transacR)

# %%
data2=[[]]

# %%
for i in range(len(From1)):
            for j in range(len(To2)):
                for k in range(len(Subject2)):
                    temp=''.join(["{}".format(randint(1, 9)) for num in range(0, 6)])
                    s1=random.choice(name1)+random.choice(From1)
                    s2=random.choice(name2)+random.choice(To2)
                    s3=sub(temp)
                    s4=""
                    s5=""
                    words = s3.split()
                    for word in words:
                        word=word.lower()
                        if(word=='failed'):
                            s4=transac(3,temp)
                            s5='A'
                        elif(word=='pending' or word=='progress' or word=='update'):
                            s4=transac(2,temp)
                            s5='B'
                        elif(word=='complete' or word=='received'):
                            s4=transac(1,temp)
                            s5='C'
                        elif(word=='status' or word=='request' or word=='details'):
                            s4=transac(4,temp)
                            s5='D'
                    m=[s1,s2,s3,s4,s5]
                    data2.append(m)

# %%
df = pd.DataFrame(data2, columns = ['From', 'To','Subject','Body','Class(output)'])

# %%
df.head(20)
# Out:
#                            From                            To  \
# 0                          None                          None
# 1             Mike@JPMorgan.com   Isabella@CitiBankLondon.com
# 2         Mike@DEUTSCHEBANK.com     Dipesh@CitiBankLondon.com
# 3          Phillip@JPMorgan.com  Isabella@CitiBankNewYork.com
# 4       Morgan@DEUTSCHEBANK.com  Anthony@CitiBankHingKong.com
# 5         Mike@DEUTSCHEBANK.com       Dipesh@CitiBankPune.com
# 6                Stacy@HSBC.com      Anthony@CitiBankPune.com
# 7       Morgan@DEUTSCHEBANK.com  Anthony@CitiBankHingKong.com
# 8      Jason@CitiBankLondon.com     Dipesh@CitiBankLondon.com
# 9            Stacy@JPMorgan.com    Dipesh@CitiBankNewYork.com
# 10  Phillip@CitiBankNewYork.com       Shai@CitiBankLondon.com
# 11          Stacy@BNYMellon.com   Anthony@CitiBankNewYork.com
# 12    Stacy@CitiBankNewYork.com    Shai@CitiBankSingapore.com
# 13                Adam@HSBC.com     Shai@CitiBankHingKong.com
# 14            Mike@JPMorgan.com     Dipesh@CitiBankLondon.com
# 15              Morgan@HSBC.com      Shai@CitiBankNewYork.com
# 16               Jason@HSBC.com         Shai@CitiBankPune.com
# 17          Jason@BNYMellon.com     Shai@CitiBankHingKong.com
# 18                Adam@HSBC.com       Shai@CitiBankLondon.com
# 19                Adam@HSBC.com   Isabella@CitiBankLondon.com
#
#                                   Subject  \
# 0                                    None
# 1                    Update on Acc 928598
# 2            Transaction Failed for149718
# 3               Payment Status for 237865
# 4            Transaction Failed for575566
# 5     Update on payment request for355869
# 6   Waiting for amount pending for 223474
# 7       Payment is in progress for 218631
# 8   Transaction is in progress for 162937
# 9            Transaction Failed for314883
# 10              Payment Status for 984164
# 11                   Update on Acc 125793
# 12  Transaction is in progress for 173797
# 13                   Update on Acc 447881
# 14      Payment is in progress for 721644
# 15    Update on payment request for466629
# 16      Payment is in progress for 673257
# 17         Payment in Progress Acc 346326
# 18      Payment is in progress for 219676
# 19              Payment Failed for 725413
#
#                                                  Body Class(output)
# 0                                                None          None
# 1    Payment 287361 will be completed within two days             B
# 2   Payment of CAD251696 has been cancelled as per...             A
# 3   We have received your request and will be send...             D
# 4   Payment of USD455338 has been cancelled as per...             A
# 5   Please find the details of your account 261959...             D
# 6   Due to server overflow transaction 188932 will...             B
# 7   The transaction 324464 is taking too long to b...             B
# 8   The transaction 981883 is taking too long to b...             B
# 9   Payment of CAD848931 has been cancelled as per...             A
# 10  Kindly provide the details for Acc no.824663 a...             D
# 11  Due to server overflow transaction 689368 will...             B
# 12  Due to server overflow transaction 972319 will...             B
# 13  Fund transfer for ACC No. 772798 has partially...             B
# 14   Payment 815345 will be completed within two days             B
# 15  We have received your request and will be send...             D
# 16   Payment 429836 will be completed within two days             B
# 17   Payment 255888 will be completed within two days             B
# 18  The transaction 775984 is taking too long to b...             B
# 19  Due to lack of funds, cheque no. 6168328486836...             A

# %%
import datetime

# %%
start_date = datetime.date(2018, 12, 1)
end_date = datetime.date(2020, 5, 31)

time_between_dates = end_date - start_date
days_between_dates = time_between_dates.days
date_column_data = [start_date + datetime.timedelta(days=random.randrange(days_between_dates)) for i in range(len(data2))]
#print(date_column_data)

# %%
df['Payment Date'] = date_column_data

# %%
df.head(100)
# Out:
#                            From                              To  \
# 0                          None                            None
# 1             Mike@JPMorgan.com     Isabella@CitiBankLondon.com
# 2         Mike@DEUTSCHEBANK.com       Dipesh@CitiBankLondon.com
# 3          Phillip@JPMorgan.com    Isabella@CitiBankNewYork.com
# 4       Morgan@DEUTSCHEBANK.com    Anthony@CitiBankHingKong.com
# 5         Mike@DEUTSCHEBANK.com         Dipesh@CitiBankPune.com
# 6                Stacy@HSBC.com        Anthony@CitiBankPune.com
# 7       Morgan@DEUTSCHEBANK.com    Anthony@CitiBankHingKong.com
# 8      Jason@CitiBankLondon.com       Dipesh@CitiBankLondon.com
# 9            Stacy@JPMorgan.com      Dipesh@CitiBankNewYork.com
# 10  Phillip@CitiBankNewYork.com         Shai@CitiBankLondon.com
# 11          Stacy@BNYMellon.com     Anthony@CitiBankNewYork.com
# 97      Mike@CitiBankLondon.com       Dipesh@CitiBankLondon.com
# 98  Phillip@CitiBankNewYork.com   Anthony@CitiBankSingapore.com
# 99    Stacy@CitiBankNewYork.com    Isabella@CitiBankNewYork.com
#
#                                          Subject  \
# 0                                           None
# 1                           Update on Acc 928598
# 2                   Transaction Failed for149718
# 3                      Payment Status for 237865
# 4                   Transaction Failed for575566
# 5            Update on payment request for355869
# 6          Waiting for amount pending for 223474
# 7              Payment is in progress for 218631
# 8          Transaction is in progress for 162937
# 9                   Transaction Failed for314883
# 10                     Payment Status for 984164
# 11                          Update on Acc 125793
# 12         Transaction is in progress for 173797
# 13                          Update on Acc 447881
# 14             Payment is in progress for 721644
# 15           Update on payment request for466629
# 16             Payment is in progress for 673257
# 17                Payment in Progress Acc 346326
# 18             Payment is in progress for 219676
# 19                     Payment Failed for 725413
# 20                    Payment Received for233327
# 21         Transaction is in progress for 489984
# 22         Transaction is in progress for 821227
# 23                  Transaction Failed for837461
# 24  Urgent : need transaction details for 657431
# 25                     Payment Status for 291914
# 26                     Payment Failed for 522878
# 27         Transaction is in progress for 292953
# 28           Update on payment request for791522
# 29  Urgent : need transaction details for 673912
# ..                                           ...
# 70           Update on payment request for129794
# 71         Transaction is in progress for 558139
# 72         Transaction is in progress for 916465
# 73                    Payment Received for523173
# 74           Update on payment request for282384
# 75                Payment in Progress Acc 218932
# 76                    Payment Received for461841
# 77                  Transaction Failed for196511
# 78                          Update on Acc 389415
# 79                             Acc 933947 Update
# 80                Payment in Progress Acc 512956
# 81                     Payment Failed for 313391
# 82                     Payment Status for 555918
# 83                Payment in Progress Acc 911284
# 84                             Acc 711779 Update
# 85             Payment is in progress for 647747
# 86               Transaction Complete for 181973
# 87  Urgent : need transaction details for 977913
# 88               Transaction Complete for 516437
# 89         Waiting for amount pending for 323782
# 90           Update on payment request for193728
# 91         Transaction is in progress for 414282
# 92  Urgent : need transaction details for 833891
# 93                Payment in Progress Acc 247787
# 94                    Payment Received for877238
# 95         Waiting for amount pending for 871262
# 96           Update on payment request for281713
# 97             Payment is in progress for 919774
# 98                     Payment Failed for 348583
# 99  Urgent : need transaction details for 999951
#
#                                                  Body Class(output)  \
# 0                                                None          None
# 1    Payment 287361 will be completed within two days             B
# 2   Payment of CAD251696 has been cancelled as per...             A
# 3   We have received your request and will be send...             D
# 4   Payment of USD455338 has been cancelled as per...             A
# 5   Please find the details of your account 261959...             D
# 6   Due to server overflow transaction 188932 will...             B
# 7   The transaction 324464 is taking too long to b...             B
# 8   The transaction 981883 is taking too long to b...             B
# 9   Payment of CAD848931 has been cancelled as per...             A
# 10  Kindly provide the details for Acc no.824663 a...             D
# 11  Due to server overflow transaction 689368 will...             B
# 12  Due to server overflow transaction 972319 will...             B
# 13  Fund transfer for ACC No. 772798 has partially...             B
# 14   Payment 815345 will be completed within two days             B
# 15  We have received your request and will be send...             D
# 16   Payment 429836 will be completed within two days             B
# 17   Payment 255888 will be completed within two days             B
# 18  The transaction 775984 is taking too long to b...             B
# 19  Due to lack of funds, cheque no. 6168328486836...             A
# 20  The transaction of amount GBP561431 has been r...             C
# 21   Payment 536344 will be completed within two days             B
# 22  Due to server overflow transaction 188385 will...             B
# 23  Due to lack of funds, cheque no. 1753544178155...             A
# 24  Please find the details of your account 166867...             D
# 25  We have received your request and will be send...             D
# 26  Payment of USD291645 has been cancelled as per...             A
# 27   Payment 791342 will be completed within two days             B
# 28  Please find the details of your account 497772...             D
# 29  We have received your request and will be send...             D
# ..                                                ...           ...
# 70  We have received your request and will be send...             D
# 71  Fund transfer for ACC No. 845887 has partially...             B
# 72  The transaction 487649 is taking too long to b...             B
# 73  The transaction for amount EUR587663 related t...             C
# 74  Please find the details of your account 325965...             D
# 75  Due to server overflow transaction 349422 will...             B
# 76  The transaction for amount GBP817991 related t...             C
# 77  Due to lack of funds, cheque no. 9566745513832...             A
# 78  Fund transfer for ACC No. 731148 has partially...             B
# 79  The transaction 331419 is taking too long to b...             B
# 80   Payment 544492 will be completed within two days             B
# 81  Payment of GBP738883 has been cancelled as per...             A
# 82  We have received your request and will be send...             D
# 83   Payment 891495 will be completed within two days             B
# 84  Fund transfer for ACC No. 972224 has partially...             B
# 85  Fund transfer for ACC No. 315353 has partially...             B
# 86  Full payment for amount USD734573 has been suc...             C
# 87  Please find the details of your account 356185...             D
# 88  Full payment for amount CAD519683 has been suc...             C
# 89  The transaction 677285 is taking too long to b...             B
# 90  We have received your request and will be send...             D
# 91  Due to server overflow transaction 754965 will...             B
# 92  We have received your request and will be send...             D
# 93  The transaction 798626 is taking too long to b...             B
# 94  The transaction for amount CAD757834 related t...             C
# 95  The transaction 678275 is taking too long to b...             B
# 96  Please find the details of your account 254298...             D
# 97  The transaction 597217 is taking too long to b...             B
# 98  Due to lack of funds, cheque no. 6781431174843...             A
# 99  Please find the details of your account 917542...             D
#
#    Payment Date
# 0    2020-05-24
# 1    2019-12-14
# 2    2019-11-25
# 3    2019-09-16
# 4    2019-02-02
# 5    2019-04-27
# 6    2019-11-30
# 7    2020-02-15
# 8    2020-04-03
# 9    2019-04-09
# 10   2020-03-04
# 11   2019-08-18
# 12   2018-12-04
# 13   2019-03-11
# 14   2019-03-07
# 15   2020-02-22
# 16   2019-04-04
# 17   2019-06-16
# 18   2019-06-26
# 19   2020-03-20
# 20   2020-03-02
# 21   2020-04-23
# 22   2019-02-19
# 23   2019-04-08
# 24   2019-03-20
# 25   2019-04-15
# 26   2019-01-24
# 27   2019-06-05
# 28   2019-12-31
# 29   2019-09-11
# ..          ...
# 70   2020-03-27
# 71   2019-11-10
# 72   2019-06-05
# 73   2019-09-10
# 74   2019-10-23
# 75   2019-08-19
# 76   2020-01-16
# 77   2020-05-23
# 78   2019-07-23
# 79   2019-04-01
# 80   2019-03-13
# 81   2019-10-01
# 82   2020-04-29
# 83   2019-08-30
# 84   2019-03-09
# 85   2019-07-12
# 86   2020-01-22
# 87   2019-11-23
# 88   2019-03-20
# 89   2018-12-18
# 90   2020-05-13
# 91   2020-04-20
# 92   2020-04-23
# 93   2019-12-16
# 94   2019-06-24
# 95   2020-01-24
# 96   2020-04-01
# 97   2020-05-03
# 98   2019-02-27
# 99   2020-04-17
#
# [100 rows x 6 columns]

# %%
df.to_csv(r'emaildataset.csv', index = False)
